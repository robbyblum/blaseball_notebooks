# %% [markdown]
# # Season 12 Election Notes
#
# >**FORBIDDEN KNOWLEDGE WARNING**
# >
# >This document contains some information that is not currently present on the main site and may be considered spoilers.
# >Continue at your own discretion. Some information in this document cannot be shared on the Discord without spoiler tags.
#
# Notes:
# * Welcome back, Pies! The Election Notes have a new format! Let me know if you find any bugs or issues.
# * Anaylsis of election items are generally based on how those items or similar items worked in previous seasons. However due to the number of changes over the Grand Siesta it is possible this is less accurate than normal.

# %%
# %matplotlib inline
from blaseball_mike.models import *
import plotly.express as plot
import plotly.io as _pio
import plotly.subplots as subplot

import os
import sys
pdir = os.path.abspath(os.path.join(os.path.dirname(''), os.path.pardir))
sys.path.append(pdir)
from display import *
from blessings import *
sys.path.remove(pdir)

_pio.renderers.default = "notebook_connected"

pies = Team.load_by_name("Philly Pies")

# %%
sim = SimulationData.load()
print(f"Last Updated Season {sim.season}, Day {sim.day}")
# Out:
# Last Updated Season 12, Day 56

# %% [markdown]
# ---
# ## Decrees
#
# Decrees are chosen by majority votes across all teams. `1` decree will pass this season.

# %% [markdown]
# ### Title Belt
# **Win the Championship to claim the Belt, then Defend it in Title Matches next Season. The Holder of the Belt is
# protected from Steals and Swaps and guaranteed a Postseason Birth. Should the Holder win the Championship, they will
# claim a Title.**
#
# This decree would benefit from teams that consistently perform well and will win Championships often. It is unknown what
# a "Title" or "Title Matches" are.

# %% [markdown]
# ### Pennants
# **The Champion of each season will play the following season under Pennants, starting every game at a severe
# disadvantage. Win the Internet Series under Pennants in order to Repent.**
#
# This decree would act as a counterbalance against teams that win the championship, and would benefit teams that perform
# poorly.

# %% [markdown]
# ### Based Evolution
# **Every Third Championship a Team wins will cause the Team and its Players to Evolve. Players that round the phylogenic
# Bases will get to go Home.**
#
# Evolution, "the phylogenic Bases", and "Home" in this case are unknown. The Pies would be very close to achieving this
# if it passed as the team already has 2 Championship wins.

# %% [markdown]
# ___
# ## Wills
#
# Will are selected for each team by raffle. Each team will draw `2` random wills, where wills with more votes are more
# likely to be selected.

# %% [markdown]
# ### Plunder
# **Steal a Player from the Idols board. Send a random Player from your Team back.**
#
# Due to the random nature of the target on our team, this tests the best case (swapping the Best Player on the Idol Board
# for a position with our worst player in that position) and the worst case (swaping the Best Player on the Idol Board for
# a position with our best player in that position.
#
# **Best Case Swap:**

# %%
idols = [x.player for x in Idol.load().values()]

idols.sort(key=lambda x: x.batting_rating, reverse=True)
best_batting_idol = idols[0]
idols.sort(key=lambda x: x.pitching_rating, reverse=True)
best_pitching_idol = idols[0]


worst_batter = sort_lineup(pies, 1)[0]
print(f"Batting: Swap {best_batting_idol.name} for {worst_batter.name}")

pandas.DataFrame(replace_player(pies, worst_batter, bat_star=best_batting_idol.batting_stars, run_star=best_batting_idol.baserunning_stars, def_star=best_batting_idol.defense_stars))
# Out:
# Batting: Swap Nagomi Mcdaniel for Farrell Seagull
#                          Pies
# batting_change      +11.3406%
# pitching_change      +0.0000%
# baserunning_change   +7.9750%
# defense_change       +8.5640%

# %%
worst_pitcher = sort_rotation(pies, 1)[0]
print(f"Pitching: Swap {best_pitching_idol.name} for {worst_pitcher.name}")

pandas.DataFrame(replace_player(pies, worst_pitcher, pitch_star=best_pitching_idol.pitching_stars))
# Out:
# Pitching: Swap Nagomi Mcdaniel for Bright Zimmerman
#                          Pies
# batting_change       +0.0000%
# pitching_change     +19.6431%
# baserunning_change   +0.0000%
# defense_change       +0.0000%

# %% [markdown]
# **Worst Case Swap:**

# %%
best_batter = sort_lineup(pies, 1, order="best")[0]
print(f"Batting: Swap {best_batting_idol.name} for {best_batter.name}")

pandas.DataFrame(replace_player(pies, best_batter, bat_star=best_batting_idol.batting_stars, run_star=best_batting_idol.baserunning_stars, def_star=best_batting_idol.defense_stars))
# Out:
# Batting: Swap Nagomi Mcdaniel for Jaxon Buckley
#                         Pies
# batting_change      +1.2015%
# pitching_change     +0.0000%
# baserunning_change  +6.3892%
# defense_change      +6.9881%

# %%
best_pitcher = sort_rotation(pies, 1, order="best")[0]
print(f"Pitching: Swap {best_pitching_idol.name} for {best_pitcher.name}")

pandas.DataFrame(replace_player(pies, best_pitcher, pitch_star=best_pitching_idol.pitching_stars))
# Out:
# Pitching: Swap Nagomi Mcdaniel for Elvis Figueroa
#                         Pies
# batting_change      +0.0000%
# pitching_change     +7.0067%
# baserunning_change  +0.0000%
# defense_change      +0.0000%

# %% [markdown]
# ### Exchange
# **Swap a Player from a Team in the opposite Subleague with a Player from your Team.**
#
# There are 139 possible Wild League players to swap with our 12 existing players, which is too many permuations for me to list here. Instead, here's the list of the top 10 players available to choose from by star rating. For maximum impact it is recommended we swap the player with the worst batter or pitcher respectively.
#
# Note that position does not matter for the swap, so a player that is currently batting can still be added as a pitcher and vice-versa.

# %% [markdown]
# **Best Batter options and Pies worst Batter:**

# %%
wild = Subleague.load("aabc11a1-81af-4036-9f18-229c759ca8a9")
all_wild = []
for team in wild.teams.values():
    all_wild.extend(team.lineup + team.rotation)
    
all_wild.sort(key=lambda x: x.batting_rating, reverse=True)
set_heatmap(get_batting_stlats(all_wild[0:10]), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_29515_row0_col0,#T_29515_row0_col2,#T_29515_row0_col3,#T_29515_row0_col4,#T_29515_row0_col6,#T_29515_row1_col0,#T_29515_row1_col2,#T_29515_row1_col8,#T_29515_row2_col0,#T_29515_row2_col1,#T_29515_row2_col3,#T_29515_row2_col4,#T_29515_row3_col0,#T_29515_row3_col1,#T_29515_row3_col2,#T_29515_row3_col4,#T_29515_row4_col0,#T_29515_row4_col1,#T_29515_row4_col8,#T_29515_row5_col0,#T_29515_row5_col2,#T_29515_row5_col3,#T_29515_row5_col4,#T_29515_row6_col0,#T_29515_row6_col2,#T_29515_row6_col3,#T_29515_row6_col4,#T_29515_row6_col6,#T_29515_row7_col1,#T_29515_row7_col3,#T_29515_row7_col6,#T_29515_row7_col8,#T_29515_row8_col2,#T_29515_row8_col4,#T_29515_row9_col1,#T_29515_row9_col2,#T_29515_row9_col6{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_29515_row0_col1,#T_29515_row1_col6,#T_29515_row7_col0{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_29515_row0_col5{
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#             background-color:  #108647;
#             color:  #000000;
#         }#T_29515_row0_col7,#T_29515_row1_col7,#T_29515_row2_col7,#T_29515_row3_col7,#T_29515_row4_col7,#T_29515_row5_col7,#T_29515_row7_col7,#T_29515_row8_col7,#T_29515_row9_col7{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             background-color:  #199750;
#             color:  #000000;
#         }#T_29515_row0_col8{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_29515_row1_col1{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_29515_row1_col3{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_29515_row1_col4,#T_29515_row5_col6{
#             background-color:  #016a38;
#             color:  #f1f1f1;
#         }#T_29515_row1_col5{
#             background-color:  #fee695;
#             color:  #000000;
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_29515_row2_col2{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_29515_row2_col5{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_29515_row2_col6{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_29515_row2_col8{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_29515_row3_col3,#T_29515_row9_col4{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_29515_row3_col5{
#             background-color:  #f67f4b;
#             color:  #000000;
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_29515_row3_col6{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_29515_row3_col8{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_29515_row4_col2{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_29515_row4_col3{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_29515_row4_col4{
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_29515_row4_col5{
#             background-color:  #fa9656;
#             color:  #000000;
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_29515_row4_col6{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }#T_29515_row5_col1{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_29515_row5_col5{
#             background-color:  #f57547;
#             color:  #000000;
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_29515_row5_col8{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_29515_row6_col1,#T_29515_row6_col8{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_29515_row6_col5{
#             background-color:  #f7fcb4;
#             color:  #000000;
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_29515_row6_col7{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_29515_row7_col2{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_29515_row7_col4{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_29515_row7_col5{
#             background-color:  #feca79;
#             color:  #000000;
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_29515_row8_col0{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_29515_row8_col1{
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_29515_row8_col3{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_29515_row8_col5{
#             background-color:  #feeb9d;
#             color:  #000000;
#             background-color:  #e6f59d;
#             color:  #000000;
#         }#T_29515_row8_col6{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_29515_row8_col8{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_29515_row9_col0{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_29515_row9_col3{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_29515_row9_col5{
#             background-color:  #bfe47a;
#             color:  #000000;
#             background-color:  #fdc776;
#             color:  #000000;
#         }#T_29515_row9_col8{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }</style><table id="T_29515_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_29515_level0_row0" class="row_heading level0 row0" >Valentine Games</th>
#                         <td id="T_29515_row0_col0" class="data row0 col0" >1.095505</td>
#                         <td id="T_29515_row0_col1" class="data row0 col1" >0.968938</td>
#                         <td id="T_29515_row0_col2" class="data row0 col2" >1.152424</td>
#                         <td id="T_29515_row0_col3" class="data row0 col3" >1.572270</td>
#                         <td id="T_29515_row0_col4" class="data row0 col4" >1.233125</td>
#                         <td id="T_29515_row0_col5" class="data row0 col5" >0.064032</td>
#                         <td id="T_29515_row0_col6" class="data row0 col6" >1.441402</td>
#                         <td id="T_29515_row0_col7" class="data row0 col7" >0.100000</td>
#                         <td id="T_29515_row0_col8" class="data row0 col8" >0.989459</td>
#             </tr>
#             <tr>
#                         <th id="T_29515_level0_row1" class="row_heading level0 row1" >Fitzgerald Blackburn</th>
#                         <td id="T_29515_row1_col0" class="data row1 col0" >1.044396</td>
#                         <td id="T_29515_row1_col1" class="data row1 col1" >0.819049</td>
#                         <td id="T_29515_row1_col2" class="data row1 col2" >1.554827</td>
#                         <td id="T_29515_row1_col3" class="data row1 col3" >0.855190</td>
#                         <td id="T_29515_row1_col4" class="data row1 col4" >0.993876</td>
#                         <td i

# %%
set_heatmap(get_batting_stlats(sort_lineup(pies, 1)), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_cb74a_row0_col0{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_cb74a_row0_col1{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_cb74a_row0_col2{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_cb74a_row0_col3{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_cb74a_row0_col4{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_cb74a_row0_col5{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_cb74a_row0_col6{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_cb74a_row0_col7{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_cb74a_row0_col8{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }</style><table id="T_cb74a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cb74a_level0_row0" class="row_heading level0 row0" >Farrell Seagull</th>
#                         <td id="T_cb74a_row0_col0" class="data row0 col0" >0.406156</td>
#                         <td id="T_cb74a_row0_col1" class="data row0 col1" >0.623806</td>
#                         <td id="T_cb74a_row0_col2" class="data row0 col2" >0.235514</td>
#                         <td id="T_cb74a_row0_col3" class="data row0 col3" >0.069620</td>
#                         <td id="T_cb74a_row0_col4" class="data row0 col4" >0.768254</td>
#                         <td id="T_cb74a_row0_col5" class="data row0 col5" >0.126134</td>
#                         <td id="T_cb74a_row0_col6" class="data row0 col6" >0.860282</td>
#                         <td id="T_cb74a_row0_col7" class="data row0 col7" >0.036873</td>
#                         <td id="T_cb74a_row0_col8" class="data row0 col8" >0.542776</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Best Pitchers options and Pies worst Pitcher:**

# %%
all_wild.sort(key=lambda x: x.pitching_rating, reverse=True)
set_heatmap(get_pitching_stlats(all_wild[0:10]), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_2c024_row0_col0,#T_2c024_row0_col1,#T_2c024_row0_col2,#T_2c024_row1_col0,#T_2c024_row1_col1,#T_2c024_row1_col2,#T_2c024_row1_col3,#T_2c024_row1_col4,#T_2c024_row2_col0,#T_2c024_row2_col2,#T_2c024_row2_col3,#T_2c024_row2_col5,#T_2c024_row2_col6,#T_2c024_row3_col0,#T_2c024_row3_col1,#T_2c024_row3_col2,#T_2c024_row3_col4,#T_2c024_row3_col5,#T_2c024_row4_col2,#T_2c024_row4_col3,#T_2c024_row4_col4,#T_2c024_row4_col5,#T_2c024_row4_col6,#T_2c024_row5_col1,#T_2c024_row5_col2,#T_2c024_row7_col1,#T_2c024_row7_col2,#T_2c024_row9_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_2c024_row0_col3{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_2c024_row0_col4{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_2c024_row0_col5{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_2c024_row0_col6{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_2c024_row1_col5{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_2c024_row1_col6{
#             background-color:  #e5f49b;
#             color:  #000000;
#         }#T_2c024_row2_col1{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_2c024_row2_col4,#T_2c024_row9_col6{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }#T_2c024_row3_col3{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_2c024_row3_col6{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_2c024_row4_col0{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_2c024_row4_col1{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_2c024_row5_col0,#T_2c024_row7_col5,#T_2c024_row9_col2{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_2c024_row5_col3{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_2c024_row5_col4{
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_2c024_row5_col5{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_2c024_row5_col6{
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_2c024_row6_col0{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_2c024_row6_col1{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_2c024_row6_col2,#T_2c024_row6_col3{
#             background-color:  #04703b;
#             color:  #f1f1f1;
#         }#T_2c024_row6_col4{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_2c024_row6_col5{
#             background-color:  #fee491;
#             color:  #000000;
#         }#T_2c024_row6_col6{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_2c024_row7_col0{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_2c024_row7_col3{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_2c024_row7_col4{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_2c024_row7_col6{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_2c024_row8_col0{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_2c024_row8_col1{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_2c024_row8_col2{
#             background-color:  #08773f;
#             color:  #f1f1f1;
#         }#T_2c024_row8_col3{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_2c024_row8_col4{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_2c024_row8_col5{
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#         }#T_2c024_row8_col6{
#             background-color:  #e24731;
#             color:  #f1f1f1;
#         }#T_2c024_row9_col0{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_2c024_row9_col1{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_2c024_row9_col4{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_2c024_row9_col5{
#             background-color:  #fed07e;
#             color:  #000000;
#         }</style><table id="T_2c024_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2c024_level0_row0" class="row_heading level0 row0" >Burke Gonzales</th>
#                         <td id="T_2c024_row0_col0" class="data row0 col0" >1.176989</td>
#                         <td id="T_2c024_row0_col1" class="data row0 col1" >1.171639</td>
#                         <td id="T_2c024_row0_col2" class="data row0 col2" >1.341412</td>
#                         <td id="T_2c024_row0_col3" class="data row0 col3" >0.879956</td>
#                         <td id="T_2c024_row0_col4" class="data row0 col4" >0.870391</td>
#                         <td id="T_2c024_row0_col5" class="data row0 col5" >0.973638</td>
#                         <td id="T_2c024_row0_col6" class="data row0 col6" >0.789646</td>
#             </tr>
#             <tr>
#                         <th id="T_2c024_level0_row1" class="row_heading level0 row1" >Qais Dogwalker</th>
#                         <td id="T_2c024_row1_col0" class="data row1 col0" >1.105839</td>
#                         <td id="T_2c024_row1_col1" class="data row1 col1" >1.031425</td>
#                         <td id="T_2c024_row1_col2" class="data row1 col2" >1.097700</td>
#                         <td id="T_2c024_row1_col3" class="data row1 col3" >1.318705</td>
#                         <td id="T_2c024_row1_col4" class="data row1 col4" >1.112111</td>
#                         <td id="T_2c024_row1_col5" class="data row1 col5" >0.842765</td>
#                         <td id="T_2c024_row1_col6" class="data row1 col6" >0.570121</td>
#             </tr>
#             <tr>
#                         <th id="T_2c024_level0_row2" class="row_heading level0 row2" >Wyatt Pothos</th>
#                         <td id="T_2c024_row2_col0" class="data row2 col0" >1.082505</td>
#                         <td id="T_2c024_row2_col1" class="data row2 col1" >0.901425</td>
#                         <td id="T_2c024_row2_col2" class="data row2 col2" >1.263023</td>
#                         <td id="T_2c024_row2_col3" class="data row2 col3" >1.332335</td>
#                         <td id="T_2c024_row2_col4" class="data row2 col4" >0.891922</td>
#                         <td id="T_2c024_row2_col5" class="data row2 col5" >1.279506</td>
#                         <td id="T_2c024_row2_col6" class="data row2 col6" >0.999864</td>
#             </tr>
#             <tr>
#                         <th id="T_2c024_level0_row3" class="row_heading level0 row3" >Castillo Turner</th>
#                         <td id="T_2c024_row3_col0" class="data row3 col0" >1.041304</td>
#                         <td id="T_2c024_row3_col1" class="data row3 col1" >1.074010</td>
#                         <td id="T_2c024_row3_col2" class="data row3 col2" >1.093904</td>
#                         <td id="T_2c024_row3_col3" class="data row3 col3" >0.653783</td>
#                         <td id="T_2c024_row3_col4" class="data row3 col4" >1.291590</td>
#                         <td id="T_2c024_row3_col5" class="data row3 col5" >1.324847</td>
#                         <td id="T_2c024_row3_col6" class="data

# %%
set_heatmap(get_pitching_stlats(sort_rotation(pies, 1)), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_20f22_row0_col0{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_20f22_row0_col1{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_20f22_row0_col2{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_20f22_row0_col3{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_20f22_row0_col4{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_20f22_row0_col5{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_20f22_row0_col6{
#             background-color:  #30a356;
#             color:  #000000;
#         }</style><table id="T_20f22_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20f22_level0_row0" class="row_heading level0 row0" >Bright Zimmerman</th>
#                         <td id="T_20f22_row0_col0" class="data row0 col0" >0.317847</td>
#                         <td id="T_20f22_row0_col1" class="data row0 col1" >0.207882</td>
#                         <td id="T_20f22_row0_col2" class="data row0 col2" >0.511157</td>
#                         <td id="T_20f22_row0_col3" class="data row0 col3" >0.852666</td>
#                         <td id="T_20f22_row0_col4" class="data row0 col4" >0.679224</td>
#                         <td id="T_20f22_row0_col5" class="data row0 col5" >0.303950</td>
#                         <td id="T_20f22_row0_col6" class="data row0 col6" >0.870961</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Foreshadow
# **Swap a Player from your Shadows to your active roster.**
#
# There are 13 shadows players to swap with our 12 existing players. Below is a breakdown comparing the best shadows
# players with the worst player in the particular position.
#
# Note that position does not matter for the swap: any shadows player can bat or pitch.

# %% [markdown]
# **Batting:**

# %%
shadows = pies.bullpen + pies.bench
shadows.sort(key=lambda x: x.batting_rating, reverse=True)
best_batting_shadows = shadows[0:3]
worst_batter = sort_lineup(pies, 1)[0]

get_stars(best_batting_shadows + [worst_batter])
# Out:
#                  Batting  Pitching  Baserunning  Defense
# Haruta Byrd          3.5       2.5          2.5      1.5
# Javier Lotus         3.5       1.0          3.5      4.0
# August Obrien        3.5       1.0          3.5      2.0
# Farrell Seagull      2.0       2.0          2.5      1.5

# %%
set_heatmap(get_batting_stlats(best_batting_shadows + [worst_batter]), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_316f2_row0_col0{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_316f2_row0_col1{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_316f2_row0_col2{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_316f2_row0_col3{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_316f2_row0_col4{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_316f2_row0_col5{
#             background-color:  #4bb05c;
#             color:  #000000;
#             background-color:  #ea5739;
#             color:  #000000;
#         }#T_316f2_row0_col6{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_316f2_row0_col7,#T_316f2_row1_col7,#T_316f2_row2_col7{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             background-color:  #199750;
#             color:  #000000;
#         }#T_316f2_row0_col8{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }#T_316f2_row1_col0,#T_316f2_row2_col0{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_316f2_row1_col1{
#             background-color:  #0f8446;
#             color:  #f1f1f1;
#         }#T_316f2_row1_col2{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_316f2_row1_col3{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_316f2_row1_col4{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_316f2_row1_col5{
#             background-color:  #f47044;
#             color:  #000000;
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_316f2_row1_col6{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_316f2_row1_col8{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_316f2_row2_col1{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_316f2_row2_col2{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_316f2_row2_col3{
#             background-color:  #16914d;
#             color:  #000000;
#         }#T_316f2_row2_col4{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_316f2_row2_col5{
#             background-color:  #138c4a;
#             color:  #000000;
#             background-color:  #ca2427;
#             color:  #f1f1f1;
#         }#T_316f2_row2_col6{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_316f2_row2_col8{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_316f2_row3_col0{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_316f2_row3_col1{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_316f2_row3_col2{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_316f2_row3_col3{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_316f2_row3_col4{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_316f2_row3_col5{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_316f2_row3_col6{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_316f2_row3_col7{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_316f2_row3_col8{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }</style><table id="T_316f2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_316f2_level0_row0" class="row_heading level0 row0" >Haruta Byrd</th>
#                         <td id="T_316f2_row0_col0" class="data row0 col0" >0.724391</td>
#                         <td id="T_316f2_row0_col1" class="data row0 col1" >0.721433</td>
#                         <td id="T_316f2_row0_col2" class="data row0 col2" >0.917077</td>
#                         <td id="T_316f2_row0_col3" class="data row0 col3" >0.853010</td>
#                         <td id="T_316f2_row0_col4" class="data row0 col4" >0.585921</td>
#                         <td id="T_316f2_row0_col5" class="data row0 col5" >0.832203</td>
#                         <td id="T_316f2_row0_col6" class="data row0 col6" >0.169263</td>
#                         <td id="T_316f2_row0_col7" class="data row0 col7" >0.100000</td>
#                         <td id="T_316f2_row0_col8" class="data row0 col8" >0.124161</td>
#             </tr>
#             <tr>
#                         <th id="T_316f2_level0_row1" class="row_heading level0 row1" >Javier Lotus</th>
#                         <td id="T_316f2_row1_col0" class="data row1 col0" >0.682621</td>
#                         <td id="T_316f2_row1_col1" class="data row1 col1" >0.938964</td>
#                         <td id="T_316f2_row1_col2" class="data row1 col2" >0.386700</td>
#                         <td id="T_316f2_row1_col3" class="data row1 col3" >0.901328</td>
#                         <td id="T_316f2_row1_col4" class="data row1 col4" >0.942211</td>
#                         <td id="T_316f2_row1_col5" class="data row1 col5" >0.205027</td>
#                         <td id="T_316f2_row1_col6" class="data row1 col6" >0.884526</td>
#                         <td id="T_316f2_row1_col7" class="data row1 col7" >0.100000</td>
#                         <td id="T_316f2_row1_col8" class="data row1 col8" >0.815592</td>
#             </tr>
#             <tr>
#                         <th id="T_316f2_level0_row2" class="row_heading level0 row2" >August Obrien</th>
#                         <td id="T_316f2_row2_col0" class="data row2 col0" >0.681669</td>
#                         <td id="T_316f2_row2_col1" class="data row2 col1" >0.641217</td>
#                         <td id="T_316f2_row2_col2" class="data row2 col2" >0.927569</td>
#                         <td id="T_316f2_row2_col3" class="data row2 col3" >0.913891</td>
#                         <td id="T_316f2_row2_col4" class="data row2 col4" >0.492708</td>
#                         <td id="T_316f2_row2_col5" class="data row2 col5" >0.923854</td>
#                         <td id="T_316f2_row2_col6" class="data row2 col6" >0.556849</td>
#                         <td id="T_316f2_row2_col7" class="data row2 col7" >0.100000</td>
#                         <td id="T_316f2_row2_col8" class="data row2 col8" >0.463958</td>
#             </tr>
#             <tr>
#                         <th id="T_316f2_level0_row3" class="row_heading level0 row3" >Farrell Seagull</th>
#                         <td id="T_316f2_row3_col0" class="data row3 col0" >0.406156</td>
#                         <td id="T_316f2_row3_col1" class="data row3 col1" >0.623806</td>
#                         <td id="T_316f2_row3_col2" class="data row3 col2" >0.235514</td>
#                         <td id="T_316f2_row3_col3" class="data row3 col3" >0.069620</td>
#                         <td id="T_316f2_row3_col4" class="data row3 col4" >0.768254</td>
#                         <td id="T_316f2_row3_col5" class="data row3 col5" >0.126134</td>
#                         <td id="T_316f2_row3_col6" class="data row3 col6" >0.860282</td>
#                         <td id="T_316f2_row3_col7"

# %% [markdown]
# **Pitching:**

# %%
shadows.sort(key=lambda x: x.pitching_rating, reverse=True)
best_pitching_shadows = shadows[0:3]
worst_pitcher = sort_rotation(pies, 1)[0]

get_stars(best_pitching_shadows + [worst_pitcher])
# Out:
#                     Batting  Pitching  Baserunning  Defense
# Twofurious Puddles      2.5       3.5          2.0      3.5
# Case Lancaster          0.0       3.5          2.0      3.0
# Tiana Takahashi         1.0       3.0          2.5      3.0
# Bright Zimmerman        3.5       1.5          1.0      3.0

# %%
set_heatmap(get_pitching_stlats(best_pitching_shadows + [worst_pitcher]), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_509fd_row0_col0{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_509fd_row0_col1{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_509fd_row0_col2{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_509fd_row0_col3{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_509fd_row0_col4,#T_509fd_row2_col3{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_509fd_row0_col5{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_509fd_row0_col6{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_509fd_row1_col0{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_509fd_row1_col1{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_509fd_row1_col2{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_509fd_row1_col3{
#             background-color:  #f16640;
#             color:  #000000;
#         }#T_509fd_row1_col4{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_509fd_row1_col5,#T_509fd_row3_col6{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_509fd_row1_col6{
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }#T_509fd_row2_col0{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_509fd_row2_col1{
#             background-color:  #17934e;
#             color:  #000000;
#         }#T_509fd_row2_col2{
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_509fd_row2_col4{
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }#T_509fd_row2_col5{
#             background-color:  #daf08d;
#             color:  #000000;
#         }#T_509fd_row2_col6{
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_509fd_row3_col0{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_509fd_row3_col1{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_509fd_row3_col2{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_509fd_row3_col3{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_509fd_row3_col4{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_509fd_row3_col5{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }</style><table id="T_509fd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_509fd_level0_row0" class="row_heading level0 row0" >Twofurious Puddles</th>
#                         <td id="T_509fd_row0_col0" class="data row0 col0" >0.694922</td>
#                         <td id="T_509fd_row0_col1" class="data row0 col1" >0.811110</td>
#                         <td id="T_509fd_row0_col2" class="data row0 col2" >0.650034</td>
#                         <td id="T_509fd_row0_col3" class="data row0 col3" >0.807712</td>
#                         <td id="T_509fd_row0_col4" class="data row0 col4" >0.718615</td>
#                         <td id="T_509fd_row0_col5" class="data row0 col5" >0.416240</td>
#                         <td id="T_509fd_row0_col6" class="data row0 col6" >0.725894</td>
#             </tr>
#             <tr>
#                         <th id="T_509fd_level0_row1" class="row_heading level0 row1" >Case Lancaster</th>
#                         <td id="T_509fd_row1_col0" class="data row1 col0" >0.658365</td>
#                         <td id="T_509fd_row1_col1" class="data row1 col1" >0.867044</td>
#                         <td id="T_509fd_row1_col2" class="data row1 col2" >0.829197</td>
#                         <td id="T_509fd_row1_col3" class="data row1 col3" >0.190119</td>
#                         <td id="T_509fd_row1_col4" class="data row1 col4" >0.825333</td>
#                         <td id="T_509fd_row1_col5" class="data row1 col5" >0.868251</td>
#                         <td id="T_509fd_row1_col6" class="data row1 col6" >0.082117</td>
#             </tr>
#             <tr>
#                         <th id="T_509fd_level0_row2" class="row_heading level0 row2" >Tiana Takahashi</th>
#                         <td id="T_509fd_row2_col0" class="data row2 col0" >0.618850</td>
#                         <td id="T_509fd_row2_col1" class="data row2 col1" >0.910065</td>
#                         <td id="T_509fd_row2_col2" class="data row2 col2" >0.961592</td>
#                         <td id="T_509fd_row2_col3" class="data row2 col3" >0.716677</td>
#                         <td id="T_509fd_row2_col4" class="data row2 col4" >0.028954</td>
#                         <td id="T_509fd_row2_col5" class="data row2 col5" >0.596122</td>
#                         <td id="T_509fd_row2_col6" class="data row2 col6" >0.945940</td>
#             </tr>
#             <tr>
#                         <th id="T_509fd_level0_row3" class="row_heading level0 row3" >Bright Zimmerman</th>
#                         <td id="T_509fd_row3_col0" class="data row3 col0" >0.317847</td>
#                         <td id="T_509fd_row3_col1" class="data row3 col1" >0.207882</td>
#                         <td id="T_509fd_row3_col2" class="data row3 col2" >0.511157</td>
#                         <td id="T_509fd_row3_col3" class="data row3 col3" >0.852666</td>
#                         <td id="T_509fd_row3_col4" class="data row3 col4" >0.679224</td>
#                         <td id="T_509fd_row3_col5" class="data row3 col5" >0.303950</td>
#                         <td id="T_509fd_row3_col6" class="data row3 col6" >0.870961</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Infuse
# **Boost a Player on your Team by 15% to 30%.**
#
# See below for how this would affect various team members at the 2 extreme percentages. This will only affect one player.
#
# **15% Change:**

# %%
infuse_lineup_table, _, _ = improve_team_batting_table(pies, 0.15)
infuse_lineup_table
# Out:
#                  old_batting_stars  new_batting_stars  change_in_batting_stars
# Farrell Seagull           2.030782           2.902552                 0.871770
# Yusef Puddles             2.147811           3.068746                 0.920935
# Beasley Day               2.695709           3.559653                 0.863944
# Lang Richardson           2.914378           3.671442                 0.757064
# Eduardo Woodman           4.165300           4.885272                 0.719972
# Jode Preston              4.238300           4.953990                 0.715690
# Jaxon Buckley             5.579461           6.233656                 0.654195

# %%
set_heatmap(get_batting_stlats(improve_team_batting(pies, 0.15)), maxVal=1.0)
# Out:
# <style  type="text/css" >
# #T_ac746_row0_col0{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_ac746_row0_col1{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_ac746_row0_col2{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_ac746_row0_col3{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_ac746_row0_col4,#T_ac746_row3_col1{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_ac746_row0_col5,#T_ac746_row0_col7,#T_ac746_row1_col7,#T_ac746_row2_col7,#T_ac746_row3_col7,#T_ac746_row4_col7,#T_ac746_row5_col5,#T_ac746_row5_col7,#T_ac746_row6_col5,#T_ac746_row6_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_ac746_row0_col6,#T_ac746_row1_col1,#T_ac746_row1_col8,#T_ac746_row3_col4,#T_ac746_row4_col1,#T_ac746_row4_col2,#T_ac746_row5_col1,#T_ac746_row5_col2,#T_ac746_row5_col6,#T_ac746_row6_col0,#T_ac746_row6_col1,#T_ac746_row6_col2,#T_ac746_row6_col3,#T_ac746_row6_col4,#T_ac746_row6_col6,#T_ac746_row6_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_ac746_row0_col8{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_ac746_row1_col0{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_ac746_row1_col2{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_ac746_row1_col3{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_ac746_row1_col4{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_ac746_row1_col5{
#             background-color:  #fffab6;
#             color:  #000000;
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_ac746_row1_col6{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_ac746_row2_col0{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_ac746_row2_col1{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_ac746_row2_col2{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_ac746_row2_col3{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_ac746_row2_col4{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_ac746_row2_col5{
#             background-color:  #fdb768;
#             color:  #000000;
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_ac746_row2_col6{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_ac746_row2_col8{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_ac746_row3_col0{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_ac746_row3_col2{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_ac746_row3_col3{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_ac746_row3_col5{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_ac746_row3_col6{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_ac746_row3_col8{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_ac746_row4_col0{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_ac746_row4_col3{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_ac746_row4_col4,#T_ac746_row4_col6{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_ac746_row4_col5{
#             background-color:  #feefa3;
#             color:  #000000;
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_ac746_row4_col8{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_ac746_row5_col0{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_ac746_row5_col3{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_ac746_row5_col4{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_ac746_row5_col8{
#             background-color:  #fdb768;
#             color:  #000000;
#         }</style><table id="T_ac746_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac746_level0_row0" class="row_heading level0 row0" >Farrell Seagull</th>
#                         <td id="T_ac746_row0_col0" class="data row0 col0" >0.580510</td>
#                         <td id="T_ac746_row0_col1" class="data row0 col1" >0.773806</td>
#                         <td id="T_ac746_row0_col2" class="data row0 col2" >0.385514</td>
#                         <td id="T_ac746_row0_col3" class="data row0 col3" >0.219620</td>
#                         <td id="T_ac746_row0_col4" class="data row0 col4" >0.918254</td>
#                         <td id="T_ac746_row0_col5" class="data row0 col5" >0.010000</td>
#                         <td id="T_ac746_row0_col6" class="data row0 col6" >1.010282</td>
#                         <td id="T_ac746_row0_col7" class="data row0 col7" >0.010000</td>
#                         <td id="T_ac746_row0_col8" class="data row0 col8" >0.692776</td>
#             </tr>
#             <tr>
#                         <th id="T_ac746_level0_row1" class="row_heading level0 row1" >Yusef Puddles</th>
#                         <td id="T_ac746_row1_col0" class="data row1 col0" >0.613749</td>
#                         <td id="T_ac746_row1_col1" class="data row1 col1" >1.183698</td>
#                         <td id="T_ac746_row1_col2" class="data row1 col2" >0.334577</td>
#                         <td id="T_ac746_row1_col3" class="data row1 col3" >0.825196</td>
#                         <td id="T_ac746_row1_col4" class="data row1 col4" >0.301908</td>
#                         <td id="T_ac746_row1_col5" class="data row1 col5" >0.480778</td>
#                         <td id="T_ac746_row1_col6" class="data row1 col6" >0.260821</td>
#                         <td id="T_ac746_row1_col7" class="data row1 col7" >0.010000</td>
#                         <td id="T_ac746_row1_col8" class="data row1 col8" >1.160015</td>
#             </tr>
#             <tr>
#                         <th id="T_ac746_level0_row2" class="row_heading level0 row2" >Beasley Day</th>
#                         <td id="T_ac746_row2_col0" class="data row2 col0" >0.711931</td>
#                         <td id="T_ac746_row2_col1" class="data row2 col1" >0.835000</td>
#                         <td id="T_ac746_row2_col2" class="data row2 col2" >0.838801</td>
#                         <td id="T_ac746_row2_col3" class="data row2 col3" >0.227669</td>
#                         <td id="T_ac746_row2_col4" class="data row2 col4" >0.358479</td>
#                         <td id="T_ac746_row2_col5" class="data row2 col5" >0.318964</td>
#                         <td id="T_ac746_row2_col6" class="data row2 col6" >0.673706</td>
#                         <td id="T_ac746_row2_col7" class="data row2 col7" >0.010000</td>
#                         <td id="T_ac746_row2_col8" class="data row2 col8" >0.903672</td>
#             </tr>
#             <tr>

# %%
infuse_rotation_table, _, _ = improve_team_pitching_table(pies, 0.15)
infuse_rotation_table
# Out:
#                   old_pitching_stars  new_pitching_stars  \
# Bright Zimmerman            1.589235            2.440212
# Henry Marshallow            2.143457            3.080575
# Ruslan Greatness            2.425975            3.254199
# Nicholas Mora               2.832423            3.761138
# Elvis Figueroa              4.748317            5.651779
#
#                   change_in_pitching_stars
# Bright Zimmerman                  0.850976
# Henry Marshallow                  0.937118
# Ruslan Greatness                  0.828224
# Nicholas Mora                     0.928715
# Elvis Figueroa                    0.903462

# %%
set_heatmap(get_pitching_stlats(improve_team_pitching(pies, 0.15)), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_4c1d4_row0_col0{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_4c1d4_row0_col1{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_4c1d4_row0_col2{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_4c1d4_row0_col3,#T_4c1d4_row0_col6,#T_4c1d4_row1_col2,#T_4c1d4_row1_col3,#T_4c1d4_row2_col3,#T_4c1d4_row2_col6,#T_4c1d4_row3_col1,#T_4c1d4_row4_col0,#T_4c1d4_row4_col1,#T_4c1d4_row4_col2,#T_4c1d4_row4_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_4c1d4_row0_col4{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_4c1d4_row0_col5{
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_4c1d4_row1_col0{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_4c1d4_row1_col1{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_4c1d4_row1_col4,#T_4c1d4_row2_col1{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_4c1d4_row1_col5{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_4c1d4_row1_col6{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_4c1d4_row2_col0{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_4c1d4_row2_col2,#T_4c1d4_row3_col5{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_4c1d4_row2_col4{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_4c1d4_row2_col5{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_4c1d4_row3_col0{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_4c1d4_row3_col2{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_4c1d4_row3_col3{
#             background-color:  #a2d76a;
#             color:  #000000;
#         }#T_4c1d4_row3_col4{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_4c1d4_row3_col6{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_4c1d4_row4_col4{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_4c1d4_row4_col5{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_4c1d4_row4_col6{
#             background-color:  #89cc67;
#             color:  #000000;
#         }</style><table id="T_4c1d4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c1d4_level0_row0" class="row_heading level0 row0" >Bright Zimmerman</th>
#                         <td id="T_4c1d4_row0_col0" class="data row0 col0" >0.488042</td>
#                         <td id="T_4c1d4_row0_col1" class="data row0 col1" >0.357882</td>
#                         <td id="T_4c1d4_row0_col2" class="data row0 col2" >0.661157</td>
#                         <td id="T_4c1d4_row0_col3" class="data row0 col3" >1.002666</td>
#                         <td id="T_4c1d4_row0_col4" class="data row0 col4" >0.829224</td>
#                         <td id="T_4c1d4_row0_col5" class="data row0 col5" >0.453950</td>
#                         <td id="T_4c1d4_row0_col6" class="data row0 col6" >1.020961</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d4_level0_row1" class="row_heading level0 row1" >Henry Marshallow</th>
#                         <td id="T_4c1d4_row1_col0" class="data row1 col0" >0.616115</td>
#                         <td id="T_4c1d4_row1_col1" class="data row1 col1" >0.383266</td>
#                         <td id="T_4c1d4_row1_col2" class="data row1 col2" >1.032016</td>
#                         <td id="T_4c1d4_row1_col3" class="data row1 col3" >1.273135</td>
#                         <td id="T_4c1d4_row1_col4" class="data row1 col4" >0.634581</td>
#                         <td id="T_4c1d4_row1_col5" class="data row1 col5" >0.721587</td>
#                         <td id="T_4c1d4_row1_col6" class="data row1 col6" >0.806728</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d4_level0_row2" class="row_heading level0 row2" >Ruslan Greatness</th>
#                         <td id="T_4c1d4_row2_col0" class="data row2 col0" >0.650840</td>
#                         <td id="T_4c1d4_row2_col1" class="data row2 col1" >0.634582</td>
#                         <td id="T_4c1d4_row2_col2" class="data row2 col2" >0.631892</td>
#                         <td id="T_4c1d4_row2_col3" class="data row2 col3" >1.094604</td>
#                         <td id="T_4c1d4_row2_col4" class="data row2 col4" >0.876276</td>
#                         <td id="T_4c1d4_row2_col5" class="data row2 col5" >0.470791</td>
#                         <td id="T_4c1d4_row2_col6" class="data row2 col6" >1.235039</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d4_level0_row3" class="row_heading level0 row3" >Nicholas Mora</th>
#                         <td id="T_4c1d4_row3_col0" class="data row3 col0" >0.752228</td>
#                         <td id="T_4c1d4_row3_col1" class="data row3 col1" >1.290948</td>
#                         <td id="T_4c1d4_row3_col2" class="data row3 col2" >0.493723</td>
#                         <td id="T_4c1d4_row3_col3" class="data row3 col3" >0.703609</td>
#                         <td id="T_4c1d4_row3_col4" class="data row3 col4" >0.517345</td>
#                         <td id="T_4c1d4_row3_col5" class="data row3 col5" >0.632330</td>
#                         <td id="T_4c1d4_row3_col6" class="data row3 col6" >0.581032</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d4_level0_row4" class="row_heading level0 row4" >Elvis Figueroa</th>
#                         <td id="T_4c1d4_row4_col0" class="data row4 col0" >1.130356</td>
#                         <td id="T_4c1d4_row4_col1" class="data row4 col1" >1.186387</td>
#                         <td id="T_4c1d4_row4_col2" class="data row4 col2" >1.165972</td>
#                         <td id="T_4c1d4_row4_col3" class="data row4 col3" >1.080460</td>
#                         <td id="T_4c1d4_row4_col4" class="data row4 col4" >0.839138</td>
#                         <td id="T_4c1d4_row4_col5" class="data row4 col5" >0.478725</td>
#                         <td id="T_4c1d4_row4_col6" class="data row4 col6" >0.742661</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **30% Change:**

# %%
infuse_lineup_table, _, _ = improve_team_batting_table(pies, 0.30)
infuse_lineup_table
# Out:
#                  old_batting_stars  new_batting_stars  change_in_batting_stars
# Farrell Seagull           2.030782           3.653884                 1.623103
# Yusef Puddles             2.147811           3.885398                 1.737587
# Beasley Day               2.695709           4.319837                 1.624128
# Lang Richardson           2.914378           4.386193                 1.471815
# Eduardo Woodman           4.165300           5.585918                 1.420618
# Jode Preston              4.238300           5.631545                 1.393245
# Jaxon Buckley             5.579461           6.873935                 1.294474

# %%
set_heatmap(get_batting_stlats(improve_team_batting(pies, 0.30)), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_6589e_row0_col0{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_6589e_row0_col1{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_6589e_row0_col2{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_6589e_row0_col3{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_6589e_row0_col4,#T_6589e_row0_col6,#T_6589e_row1_col1,#T_6589e_row1_col8,#T_6589e_row2_col8,#T_6589e_row3_col1,#T_6589e_row3_col4,#T_6589e_row4_col0,#T_6589e_row4_col1,#T_6589e_row4_col2,#T_6589e_row4_col8,#T_6589e_row5_col0,#T_6589e_row5_col1,#T_6589e_row5_col2,#T_6589e_row5_col6,#T_6589e_row6_col0,#T_6589e_row6_col1,#T_6589e_row6_col2,#T_6589e_row6_col3,#T_6589e_row6_col4,#T_6589e_row6_col6,#T_6589e_row6_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_6589e_row0_col5,#T_6589e_row0_col7,#T_6589e_row1_col7,#T_6589e_row2_col7,#T_6589e_row3_col5,#T_6589e_row3_col7,#T_6589e_row4_col7,#T_6589e_row5_col5,#T_6589e_row5_col7,#T_6589e_row6_col5,#T_6589e_row6_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_6589e_row0_col8{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_6589e_row1_col0{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_6589e_row1_col2{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_6589e_row1_col3{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_6589e_row1_col4{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_6589e_row1_col5{
#             background-color:  #fdbd6d;
#             color:  #000000;
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_6589e_row1_col6{
#             background-color:  #fee491;
#             color:  #000000;
#         }#T_6589e_row2_col0{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_6589e_row2_col1{
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_6589e_row2_col2{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_6589e_row2_col3{
#             background-color:  #fed481;
#             color:  #000000;
#         }#T_6589e_row2_col4{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_6589e_row2_col5{
#             background-color:  #eb5a3a;
#             color:  #000000;
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_6589e_row2_col6{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_6589e_row3_col0,#T_6589e_row4_col4{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_6589e_row3_col2{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_6589e_row3_col3{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_6589e_row3_col6{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_6589e_row3_col8{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_6589e_row4_col3{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_6589e_row4_col5{
#             background-color:  #fcaa5f;
#             color:  #000000;
#             background-color:  #a2d76a;
#             color:  #000000;
#         }#T_6589e_row4_col6{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_6589e_row5_col3{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_6589e_row5_col4{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_6589e_row5_col8{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }</style><table id="T_6589e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6589e_level0_row0" class="row_heading level0 row0" >Farrell Seagull</th>
#                         <td id="T_6589e_row0_col0" class="data row0 col0" >0.730777</td>
#                         <td id="T_6589e_row0_col1" class="data row0 col1" >0.923806</td>
#                         <td id="T_6589e_row0_col2" class="data row0 col2" >0.535514</td>
#                         <td id="T_6589e_row0_col3" class="data row0 col3" >0.369620</td>
#                         <td id="T_6589e_row0_col4" class="data row0 col4" >1.068254</td>
#                         <td id="T_6589e_row0_col5" class="data row0 col5" >0.010000</td>
#                         <td id="T_6589e_row0_col6" class="data row0 col6" >1.160282</td>
#                         <td id="T_6589e_row0_col7" class="data row0 col7" >0.010000</td>
#                         <td id="T_6589e_row0_col8" class="data row0 col8" >0.842776</td>
#             </tr>
#             <tr>
#                         <th id="T_6589e_level0_row1" class="row_heading level0 row1" >Yusef Puddles</th>
#                         <td id="T_6589e_row1_col0" class="data row1 col0" >0.777080</td>
#                         <td id="T_6589e_row1_col1" class="data row1 col1" >1.333698</td>
#                         <td id="T_6589e_row1_col2" class="data row1 col2" >0.484577</td>
#                         <td id="T_6589e_row1_col3" class="data row1 col3" >0.975196</td>
#                         <td id="T_6589e_row1_col4" class="data row1 col4" >0.451908</td>
#                         <td id="T_6589e_row1_col5" class="data row1 col5" >0.330778</td>
#                         <td id="T_6589e_row1_col6" class="data row1 col6" >0.410821</td>
#                         <td id="T_6589e_row1_col7" class="data row1 col7" >0.010000</td>
#                         <td id="T_6589e_row1_col8" class="data row1 col8" >1.310015</td>
#             </tr>
#             <tr>
#                         <th id="T_6589e_level0_row2" class="row_heading level0 row2" >Beasley Day</th>
#                         <td id="T_6589e_row2_col0" class="data row2 col0" >0.863967</td>
#                         <td id="T_6589e_row2_col1" class="data row2 col1" >0.985000</td>
#                         <td id="T_6589e_row2_col2" class="data row2 col2" >0.988801</td>
#                         <td id="T_6589e_row2_col3" class="data row2 col3" >0.377669</td>
#                         <td id="T_6589e_row2_col4" class="data row2 col4" >0.508479</td>
#                         <td id="T_6589e_row2_col5" class="data row2 col5" >0.168964</td>
#                         <td id="T_6589e_row2_col6" class="data row2 col6" >0.823706</td>
#                         <td id="T_6589e_row2_col7" class="data row2 col7" >0.010000</td>
#                         <td id="T_6589e_row2_col8" class="data row2 col8" >1.053672</td>
#             </tr>
#             <tr>
#                         <th id="T_6589e_level0_row3" class="row_heading level0 row3" >Lang Richardson</th>
#                         <td id="T_6589e_row3_col0" class="data row3 col0" >0.877239</td>
#                         <td id="T_6589e_row3_col1" class="data row3 col1" >1.070859</td>
#                         <td id="T_6589e_row3_col2" class="data row3 col2" >0.653631</td>
#                         <td id="T_6589e_row3_col3" class="data row3 col3" >0.858549</td>
#                         <td id="T_6589e_row3_col4" class="data row3 col4" >1.178068</td>

# %%
infuse_rotation_table, _, _ = improve_team_pitching_table(pies, 0.30)
infuse_rotation_table
# Out:
#                   old_pitching_stars  new_pitching_stars  \
# Bright Zimmerman            1.589235            3.298846
# Henry Marshallow            2.143457            4.003592
# Ruslan Greatness            2.425975            4.109154
# Nicholas Mora               2.832423            4.690645
# Elvis Figueroa              4.748317            6.571009
#
#                   change_in_pitching_stars
# Bright Zimmerman                  1.709611
# Henry Marshallow                  1.860134
# Ruslan Greatness                  1.683179
# Nicholas Mora                     1.858222
# Elvis Figueroa                    1.822692

# %%
set_heatmap(get_pitching_stlats(improve_team_pitching(pies, 0.30)), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_8ced1_row0_col0{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_8ced1_row0_col1{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_8ced1_row0_col2{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_8ced1_row0_col3,#T_8ced1_row0_col6,#T_8ced1_row1_col2,#T_8ced1_row1_col3,#T_8ced1_row2_col3,#T_8ced1_row2_col4,#T_8ced1_row2_col6,#T_8ced1_row3_col1,#T_8ced1_row4_col0,#T_8ced1_row4_col1,#T_8ced1_row4_col2,#T_8ced1_row4_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_8ced1_row0_col4{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_8ced1_row0_col5{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_8ced1_row1_col0{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_8ced1_row1_col1{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_8ced1_row1_col4,#T_8ced1_row2_col1,#T_8ced1_row2_col2,#T_8ced1_row3_col5{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_8ced1_row1_col5{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_8ced1_row1_col6{
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_8ced1_row2_col0{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_8ced1_row2_col5{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_8ced1_row3_col0{
#             background-color:  #0f8446;
#             color:  #f1f1f1;
#         }#T_8ced1_row3_col2{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_8ced1_row3_col3{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_8ced1_row3_col4{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_8ced1_row3_col6{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_8ced1_row4_col4{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_8ced1_row4_col5{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_8ced1_row4_col6{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }</style><table id="T_8ced1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ced1_level0_row0" class="row_heading level0 row0" >Bright Zimmerman</th>
#                         <td id="T_8ced1_row0_col0" class="data row0 col0" >0.659769</td>
#                         <td id="T_8ced1_row0_col1" class="data row0 col1" >0.507882</td>
#                         <td id="T_8ced1_row0_col2" class="data row0 col2" >0.811157</td>
#                         <td id="T_8ced1_row0_col3" class="data row0 col3" >1.152666</td>
#                         <td id="T_8ced1_row0_col4" class="data row0 col4" >0.979224</td>
#                         <td id="T_8ced1_row0_col5" class="data row0 col5" >0.603950</td>
#                         <td id="T_8ced1_row0_col6" class="data row0 col6" >1.170961</td>
#             </tr>
#             <tr>
#                         <th id="T_8ced1_level0_row1" class="row_heading level0 row1" >Henry Marshallow</th>
#                         <td id="T_8ced1_row1_col0" class="data row1 col0" >0.800718</td>
#                         <td id="T_8ced1_row1_col1" class="data row1 col1" >0.533266</td>
#                         <td id="T_8ced1_row1_col2" class="data row1 col2" >1.182016</td>
#                         <td id="T_8ced1_row1_col3" class="data row1 col3" >1.423135</td>
#                         <td id="T_8ced1_row1_col4" class="data row1 col4" >0.784581</td>
#                         <td id="T_8ced1_row1_col5" class="data row1 col5" >0.871587</td>
#                         <td id="T_8ced1_row1_col6" class="data row1 col6" >0.956728</td>
#             </tr>
#             <tr>
#                         <th id="T_8ced1_level0_row2" class="row_heading level0 row2" >Ruslan Greatness</th>
#                         <td id="T_8ced1_row2_col0" class="data row2 col0" >0.821831</td>
#                         <td id="T_8ced1_row2_col1" class="data row2 col1" >0.784582</td>
#                         <td id="T_8ced1_row2_col2" class="data row2 col2" >0.781892</td>
#                         <td id="T_8ced1_row2_col3" class="data row2 col3" >1.244604</td>
#                         <td id="T_8ced1_row2_col4" class="data row2 col4" >1.026276</td>
#                         <td id="T_8ced1_row2_col5" class="data row2 col5" >0.620791</td>
#                         <td id="T_8ced1_row2_col6" class="data row2 col6" >1.385039</td>
#             </tr>
#             <tr>
#                         <th id="T_8ced1_level0_row3" class="row_heading level0 row3" >Nicholas Mora</th>
#                         <td id="T_8ced1_row3_col0" class="data row3 col0" >0.938129</td>
#                         <td id="T_8ced1_row3_col1" class="data row3 col1" >1.440948</td>
#                         <td id="T_8ced1_row3_col2" class="data row3 col2" >0.643723</td>
#                         <td id="T_8ced1_row3_col3" class="data row3 col3" >0.853609</td>
#                         <td id="T_8ced1_row3_col4" class="data row3 col4" >0.667345</td>
#                         <td id="T_8ced1_row3_col5" class="data row3 col5" >0.782330</td>
#                         <td id="T_8ced1_row3_col6" class="data row3 col6" >0.731032</td>
#             </tr>
#             <tr>
#                         <th id="T_8ced1_level0_row4" class="row_heading level0 row4" >Elvis Figueroa</th>
#                         <td id="T_8ced1_row4_col0" class="data row4 col0" >1.314202</td>
#                         <td id="T_8ced1_row4_col1" class="data row4 col1" >1.336387</td>
#                         <td id="T_8ced1_row4_col2" class="data row4 col2" >1.315972</td>
#                         <td id="T_8ced1_row4_col3" class="data row4 col3" >1.230460</td>
#                         <td id="T_8ced1_row4_col4" class="data row4 col4" >0.989138</td>
#                         <td id="T_8ced1_row4_col5" class="data row4 col5" >0.628725</td>
#                         <td id="T_8ced1_row4_col6" class="data row4 col6" >0.892661</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Trust
# **Receive a mystery Benefit for one of your Teams' Players.**
#
# The Benifit here is unknown. It is likely either a stat increase or an unknown Modification.

# %% [markdown]
# ### Alternate
# **Call in an Alternate for a Player on your Team.**
#
# Alternates are when players stats are randomized. Below shows the change in Team Average Stars from rerolling our worst
# player, assuming they would be replaced with the Statistically Average player.

# %%
worst_pie = sort_overall(pies, 1)[0]

print(f"Rerolling {worst_pie.name}")
pandas.DataFrame(replace_player(pies, worst_pie, NEW_PLAYER["batting"], NEW_PLAYER["pitching"], NEW_PLAYER["baserunning"], NEW_PLAYER["defense"]))
# Out:
# Rerolling Bright Zimmerman
#                         Pies
# batting_change      -3.4899%
# pitching_change     -0.3569%
# baserunning_change  -1.5031%
# defense_change      -0.0834%

# %% [markdown]
# ### Revoke
# **Revoke a Player from your roster.**
#
# This will cause our other players to play more often, increasing our average team performance if we chose the worst
# player. See below for analysis of removing our worst Batter or Pitcher.
#
# **Batting:**

# %%
print(f'Removing {worst_batter.name}')
pandas.DataFrame(remove_player(pies, worst_batter))
# Out:
# Removing Farrell Seagull
#                         Pies
# batting_change      +4.5506%
# pitching_change     +0.0000%
# baserunning_change  +1.3083%
# defense_change      +3.4359%

# %% [markdown]
# **Pitching:**

# %%
print(f'Removing {worst_pitcher.name}')
pandas.DataFrame(remove_player(pies, worst_pitcher))
# Out:
# Removing Bright Zimmerman
#                         Pies
# batting_change      +0.0000%
# pitching_change     +5.7932%
# baserunning_change  +0.0000%
# defense_change      +0.0000%

# %% [markdown]
# ### Enrich
# **Pick a modification for your Team next season.**
#
# This will gives the option of choosing between
# * The Fourth Strike: Those with the Fourth Strike will get an extra strike in each at bat.
# * Home Field Advantage: Teams with Home Field Advantage will start each home game with one run.
# * Shame Donor: A Team or Player who adds Unruns to a Shamed opponents' future pile.
#
# Seasonal Modifications have been mixed in the past. For Fourth Strike Analysis, see the appropriate
# [SIBR Paper](https://research.blaseball-reference.com/Fourth_Strike.pdf).

# %% [markdown]
# ___
# ## Blessings
#
# Blessings are selected by raffle across all teams. Each blessing will be awarded to a random team, where teams with more
# votes are more likely to be selected.

# %% [markdown]
# ### Organ Replacements
# **Re-rolls your Team's 3 worst pitchers.**
#
# This will attempt to reroll the following pitchers, in order. Players are rerolled in order, so if a player is rerolled
# to be worse they will be rerolled again, as they are still the worst pitcher.
# For reference, the Statistical Average player has 1.5 pitching stars.

# %%
worst_pitchers = sort_rotation(pies, 3)
get_stars(worst_pitchers)
# Out:
#                   Batting  Pitching  Baserunning  Defense
# Bright Zimmerman      3.5       1.5          1.0      3.0
# Henry Marshallow      2.0       2.0          1.5      3.5
# Ruslan Greatness      3.5       2.5          3.5      4.0

# %% [markdown]
# ### Uncle Indemnity & The Big Sip
# **Recruit the Hardboiled Uncle Plasma to your Team.**
#
# **Recruit the Hardboiled Liquid Friend to your Team.**
#
# Uncle Plasma and Liquid Friend are from the team BC Noir which debuted in the Coffee Cup. Liquid Friend is a batter and
# Uncle Plasma is a pitcher. See below for their stats.

# %%
uncle_plasma = Player.load_one("fedbceb8-e2aa-4868-ac35-74cd0445893f")
liquid_friend = Player.load_one("d1a198d6-b05a-47cf-ab8e-39a6fa1ed831")

get_stars([uncle_plasma, liquid_friend])
# Out:
#                Batting  Pitching  Baserunning  Defense
# Uncle Plasma       3.5       4.0          4.0      4.5
# Liquid Friend      3.0       2.5          2.5      3.5

# %%
set_heatmap(get_batting_stlats(liquid_friend), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_1b3c7_row0_col0{
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_1b3c7_row0_col1{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_1b3c7_row0_col2{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_1b3c7_row0_col3{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_1b3c7_row0_col4{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_1b3c7_row0_col5{
#             background-color:  #fdc574;
#             color:  #000000;
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_1b3c7_row0_col6{
#             background-color:  #fee797;
#             color:  #000000;
#         }#T_1b3c7_row0_col7{
#             background-color:  #f26841;
#             color:  #000000;
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_1b3c7_row0_col8{
#             background-color:  #fff1a8;
#             color:  #000000;
#         }</style><table id="T_1b3c7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b3c7_level0_row0" class="row_heading level0 row0" >Liquid Friend</th>
#                         <td id="T_1b3c7_row0_col0" class="data row0 col0" >0.559806</td>
#                         <td id="T_1b3c7_row0_col1" class="data row0 col1" >0.779530</td>
#                         <td id="T_1b3c7_row0_col2" class="data row0 col2" >0.301551</td>
#                         <td id="T_1b3c7_row0_col3" class="data row0 col3" >0.678601</td>
#                         <td id="T_1b3c7_row0_col4" class="data row0 col4" >0.952236</td>
#                         <td id="T_1b3c7_row0_col5" class="data row0 col5" >0.347098</td>
#                         <td id="T_1b3c7_row0_col6" class="data row0 col6" >0.422958</td>
#                         <td id="T_1b3c7_row0_col7" class="data row0 col7" >0.191860</td>
#                         <td id="T_1b3c7_row0_col8" class="data row0 col8" >0.456044</td>
#             </tr>
#     </tbody></table>

# %%
set_heatmap(get_pitching_stlats(uncle_plasma), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_d55d6_row0_col0{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_d55d6_row0_col1{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_d55d6_row0_col2{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_d55d6_row0_col3{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_d55d6_row0_col4{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_d55d6_row0_col5{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_d55d6_row0_col6{
#             background-color:  #f57748;
#             color:  #000000;
#         }</style><table id="T_d55d6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d55d6_level0_row0" class="row_heading level0 row0" >Uncle Plasma</th>
#                         <td id="T_d55d6_row0_col0" class="data row0 col0" >0.768994</td>
#                         <td id="T_d55d6_row0_col1" class="data row0 col1" >0.679041</td>
#                         <td id="T_d55d6_row0_col2" class="data row0 col2" >1.098939</td>
#                         <td id="T_d55d6_row0_col3" class="data row0 col3" >0.717495</td>
#                         <td id="T_d55d6_row0_col4" class="data row0 col4" >0.599173</td>
#                         <td id="T_d55d6_row0_col5" class="data row0 col5" >0.791192</td>
#                         <td id="T_d55d6_row0_col6" class="data row0 col6" >0.218080</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Summoning Circle
# **Re-roll your Team's 3 worst hitters.**
#
# This will attempt to reroll the following batters, in order. Players are rerolled in order, so if a player is rerolled
# to be worse they will be rerolled again, as they are still the worst hitter.
# For reference, the Statistical Average player has 2 batting stars, 2.5 baseruning stars, and 2.5 defense stars.

# %%
worst_batters = sort_lineup(pies, 3)
get_stars(worst_batters)
# Out:
#                  Batting  Pitching  Baserunning  Defense
# Farrell Seagull      2.0       2.0          2.5      1.5
# Yusef Puddles        2.0       2.5          3.0      3.5
# Beasley Day          2.5       1.5          2.5      1.5

# %% [markdown]
# ### Earlybirds & Late to the Party
# **Your Team will play 20% better during next Season's Earlseason.**
#
# **Your Team will play 20% better during next Season's Lateseason.**
#
# Both of these blessings will make our team play better in either the first 27 games (Earlseason) or last 27 games
# (Lateseason). This 20% is therefore distributed across ~27% of the season, resulting in an average improvement of ~5%.
# See below for how the team would look with a 20% performance boost.

# %%
earlybird_lineup_table, _, _ = improve_team_batting_table(pies, 0.2)
earlybird_lineup_table
# Out:
#                  old_batting_stars  new_batting_stars  change_in_batting_stars
# Farrell Seagull           2.030782           3.159816                 1.129034
# Yusef Puddles             2.147811           3.348481                 1.200670
# Beasley Day               2.695709           3.818814                 1.123105
# Lang Richardson           2.914378           3.916701                 1.002323
# Eduardo Woodman           4.165300           5.120266                 0.954966
# Jode Preston              4.238300           5.182973                 0.944673
# Jaxon Buckley             5.579461           6.448488                 0.869026

# %%
set_heatmap(get_batting_stlats(improve_team_batting(pies, 0.2)), maxVal=1.0)
# Out:
# <style  type="text/css" >
# #T_6cb6d_row0_col0{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_6cb6d_row0_col1{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_6cb6d_row0_col2{
#             background-color:  #feeb9d;
#             color:  #000000;
#         }#T_6cb6d_row0_col3{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_6cb6d_row0_col4{
#             background-color:  #08773f;
#             color:  #f1f1f1;
#         }#T_6cb6d_row0_col5,#T_6cb6d_row0_col7,#T_6cb6d_row1_col7,#T_6cb6d_row2_col7,#T_6cb6d_row3_col7,#T_6cb6d_row4_col7,#T_6cb6d_row5_col5,#T_6cb6d_row5_col7,#T_6cb6d_row6_col5,#T_6cb6d_row6_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_6cb6d_row0_col6,#T_6cb6d_row1_col1,#T_6cb6d_row1_col8,#T_6cb6d_row3_col4,#T_6cb6d_row4_col0,#T_6cb6d_row4_col1,#T_6cb6d_row4_col2,#T_6cb6d_row5_col0,#T_6cb6d_row5_col1,#T_6cb6d_row5_col2,#T_6cb6d_row5_col6,#T_6cb6d_row6_col0,#T_6cb6d_row6_col1,#T_6cb6d_row6_col2,#T_6cb6d_row6_col3,#T_6cb6d_row6_col4,#T_6cb6d_row6_col6,#T_6cb6d_row6_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_6cb6d_row0_col8{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_6cb6d_row1_col0{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_6cb6d_row1_col2{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_6cb6d_row1_col3{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_6cb6d_row1_col4{
#             background-color:  #fec877;
#             color:  #000000;
#         }#T_6cb6d_row1_col5{
#             background-color:  #feea9b;
#             color:  #000000;
#             background-color:  #e5f49b;
#             color:  #000000;
#         }#T_6cb6d_row1_col6{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_6cb6d_row2_col0{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_6cb6d_row2_col1{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_6cb6d_row2_col2{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_6cb6d_row2_col3{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_6cb6d_row2_col4{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_6cb6d_row2_col5{
#             background-color:  #fa9857;
#             color:  #000000;
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_6cb6d_row2_col6{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_6cb6d_row2_col8{
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_6cb6d_row3_col0{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_6cb6d_row3_col1{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_6cb6d_row3_col2{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_6cb6d_row3_col3{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_6cb6d_row3_col5{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_6cb6d_row3_col6{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_6cb6d_row3_col8{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_6cb6d_row4_col3{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_6cb6d_row4_col4,#T_6cb6d_row4_col6{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_6cb6d_row4_col5{
#             background-color:  #fede89;
#             color:  #000000;
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_6cb6d_row4_col8{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_6cb6d_row5_col3{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_6cb6d_row5_col4{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_6cb6d_row5_col8{
#             background-color:  #fed07e;
#             color:  #000000;
#         }</style><table id="T_6cb6d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6cb6d_level0_row0" class="row_heading level0 row0" >Farrell Seagull</th>
#                         <td id="T_6cb6d_row0_col0" class="data row0 col0" >0.631963</td>
#                         <td id="T_6cb6d_row0_col1" class="data row0 col1" >0.823806</td>
#                         <td id="T_6cb6d_row0_col2" class="data row0 col2" >0.435514</td>
#                         <td id="T_6cb6d_row0_col3" class="data row0 col3" >0.269620</td>
#                         <td id="T_6cb6d_row0_col4" class="data row0 col4" >0.968254</td>
#                         <td id="T_6cb6d_row0_col5" class="data row0 col5" >0.010000</td>
#                         <td id="T_6cb6d_row0_col6" class="data row0 col6" >1.060282</td>
#                         <td id="T_6cb6d_row0_col7" class="data row0 col7" >0.010000</td>
#                         <td id="T_6cb6d_row0_col8" class="data row0 col8" >0.742776</td>
#             </tr>
#             <tr>
#                         <th id="T_6cb6d_level0_row1" class="row_heading level0 row1" >Yusef Puddles</th>
#                         <td id="T_6cb6d_row1_col0" class="data row1 col0" >0.669696</td>
#                         <td id="T_6cb6d_row1_col1" class="data row1 col1" >1.233698</td>
#                         <td id="T_6cb6d_row1_col2" class="data row1 col2" >0.384577</td>
#                         <td id="T_6cb6d_row1_col3" class="data row1 col3" >0.875196</td>
#                         <td id="T_6cb6d_row1_col4" class="data row1 col4" >0.351908</td>
#                         <td id="T_6cb6d_row1_col5" class="data row1 col5" >0.430778</td>
#                         <td id="T_6cb6d_row1_col6" class="data row1 col6" >0.310821</td>
#                         <td id="T_6cb6d_row1_col7" class="data row1 col7" >0.010000</td>
#                         <td id="T_6cb6d_row1_col8" class="data row1 col8" >1.210015</td>
#             </tr>
#             <tr>
#                         <th id="T_6cb6d_level0_row2" class="row_heading level0 row2" >Beasley Day</th>
#                         <td id="T_6cb6d_row2_col0" class="data row2 col0" >0.763763</td>
#                         <td id="T_6cb6d_row2_col1" class="data row2 col1" >0.885000</td>
#                         <td id="T_6cb6d_row2_col2" class="data row2 col2" >0.888801</td>
#                         <td id="T_6cb6d_row2_col3" class="data row2 col3" >0.277669</td>
#                         <td id="T_6cb6d_row2_col4" class="data row2 col4" >0.408479</td>
#                         <td id="T_6cb6d_row2_col5" class="data row2 col5" >0.268964</td>
#                         <td id="T_6cb6d_row2_col6" class="data row2 col6" >0.723706</td>
#                         <td id="T_6cb6d_row2_col7" class="data row2 col7" >0.010000</td>
#                         <td id="T_6cb6d_row2_col8" class="data row2 col8" >0.953672</td>
#             </tr>
#             <tr>
#                         <th id="T_6cb6d_level0_row3" class="row_heading level0 row3" >Lang Richar

# %%
earlybird_rotation_table, _, _ = improve_team_pitching_table(pies, 0.2)
earlybird_rotation_table
# Out:
#                   old_pitching_stars  new_pitching_stars  \
# Bright Zimmerman            1.589235            2.724812
# Henry Marshallow            2.143457            3.388508
# Ruslan Greatness            2.425975            3.536370
# Nicholas Mora               2.832423            4.070368
# Elvis Figueroa              4.748317            5.956382
#
#                   change_in_pitching_stars
# Bright Zimmerman                  1.135577
# Henry Marshallow                  1.245051
# Ruslan Greatness                  1.110394
# Nicholas Mora                     1.237946
# Elvis Figueroa                    1.208065

# %%
set_heatmap(get_pitching_stlats(improve_team_pitching(pies, 0.2)), maxVal=1)
# Out:
# <style  type="text/css" >
# #T_e215b_row0_col0,#T_e215b_row3_col2{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_e215b_row0_col1{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_e215b_row0_col2{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_e215b_row0_col3,#T_e215b_row0_col6,#T_e215b_row1_col2,#T_e215b_row1_col3,#T_e215b_row2_col3,#T_e215b_row2_col6,#T_e215b_row3_col1,#T_e215b_row4_col0,#T_e215b_row4_col1,#T_e215b_row4_col2,#T_e215b_row4_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_e215b_row0_col4{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_e215b_row0_col5{
#             background-color:  #fdfebc;
#             color:  #000000;
#         }#T_e215b_row1_col0{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_e215b_row1_col1{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_e215b_row1_col4,#T_e215b_row2_col1{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_e215b_row1_col5{
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_e215b_row1_col6{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_e215b_row2_col0{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_e215b_row2_col2,#T_e215b_row3_col5{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_e215b_row2_col4{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_e215b_row2_col5{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_e215b_row3_col0{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_e215b_row3_col3{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_e215b_row3_col4{
#             background-color:  #e5f49b;
#             color:  #000000;
#         }#T_e215b_row3_col6{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_e215b_row4_col4{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_e215b_row4_col5{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_e215b_row4_col6{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }</style><table id="T_e215b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e215b_level0_row0" class="row_heading level0 row0" >Bright Zimmerman</th>
#                         <td id="T_e215b_row0_col0" class="data row0 col0" >0.544962</td>
#                         <td id="T_e215b_row0_col1" class="data row0 col1" >0.407882</td>
#                         <td id="T_e215b_row0_col2" class="data row0 col2" >0.711157</td>
#                         <td id="T_e215b_row0_col3" class="data row0 col3" >1.052666</td>
#                         <td id="T_e215b_row0_col4" class="data row0 col4" >0.879224</td>
#                         <td id="T_e215b_row0_col5" class="data row0 col5" >0.503950</td>
#                         <td id="T_e215b_row0_col6" class="data row0 col6" >1.070961</td>
#             </tr>
#             <tr>
#                         <th id="T_e215b_level0_row1" class="row_heading level0 row1" >Henry Marshallow</th>
#                         <td id="T_e215b_row1_col0" class="data row1 col0" >0.677702</td>
#                         <td id="T_e215b_row1_col1" class="data row1 col1" >0.433266</td>
#                         <td id="T_e215b_row1_col2" class="data row1 col2" >1.082016</td>
#                         <td id="T_e215b_row1_col3" class="data row1 col3" >1.323135</td>
#                         <td id="T_e215b_row1_col4" class="data row1 col4" >0.684581</td>
#                         <td id="T_e215b_row1_col5" class="data row1 col5" >0.771587</td>
#                         <td id="T_e215b_row1_col6" class="data row1 col6" >0.856728</td>
#             </tr>
#             <tr>
#                         <th id="T_e215b_level0_row2" class="row_heading level0 row2" >Ruslan Greatness</th>
#                         <td id="T_e215b_row2_col0" class="data row2 col0" >0.707274</td>
#                         <td id="T_e215b_row2_col1" class="data row2 col1" >0.684582</td>
#                         <td id="T_e215b_row2_col2" class="data row2 col2" >0.681892</td>
#                         <td id="T_e215b_row2_col3" class="data row2 col3" >1.144604</td>
#                         <td id="T_e215b_row2_col4" class="data row2 col4" >0.926276</td>
#                         <td id="T_e215b_row2_col5" class="data row2 col5" >0.520791</td>
#                         <td id="T_e215b_row2_col6" class="data row2 col6" >1.285039</td>
#             </tr>
#             <tr>
#                         <th id="T_e215b_level0_row3" class="row_heading level0 row3" >Nicholas Mora</th>
#                         <td id="T_e215b_row3_col0" class="data row3 col0" >0.814074</td>
#                         <td id="T_e215b_row3_col1" class="data row3 col1" >1.340948</td>
#                         <td id="T_e215b_row3_col2" class="data row3 col2" >0.543723</td>
#                         <td id="T_e215b_row3_col3" class="data row3 col3" >0.753609</td>
#                         <td id="T_e215b_row3_col4" class="data row3 col4" >0.567345</td>
#                         <td id="T_e215b_row3_col5" class="data row3 col5" >0.682330</td>
#                         <td id="T_e215b_row3_col6" class="data row3 col6" >0.631032</td>
#             </tr>
#             <tr>
#                         <th id="T_e215b_level0_row4" class="row_heading level0 row4" >Elvis Figueroa</th>
#                         <td id="T_e215b_row4_col0" class="data row4 col0" >1.191276</td>
#                         <td id="T_e215b_row4_col1" class="data row4 col1" >1.236387</td>
#                         <td id="T_e215b_row4_col2" class="data row4 col2" >1.215972</td>
#                         <td id="T_e215b_row4_col3" class="data row4 col3" >1.130460</td>
#                         <td id="T_e215b_row4_col4" class="data row4 col4" >0.889138</td>
#                         <td id="T_e215b_row4_col5" class="data row4 col5" >0.528725</td>
#                         <td id="T_e215b_row4_col6" class="data row4 col6" >0.792661</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Tag Team Pitching
# **Improve your team's pitching by 10%. The last place team in the opposite subleague also gets +10% team pitching.**
#
# See below for analysis. It is impossible to know the last place team in the opposing subleague until the regular season
# is complete.

# %%
table, total, avg = improve_team_pitching_table(pies, 0.10)
print("Change in Total stars: " + str(total["change_in_pitching_stars"]))
print("Change in Average stars: " + str(avg["change_in_pitching_stars"]))
table
# Out:
# Change in Total stars: 2.9647092884055164
# Change in Average stars: 0.5929418576811033
#                   old_pitching_stars  new_pitching_stars  \
# Bright Zimmerman            1.589235            2.156695
# Henry Marshallow            2.143457            2.771380
# Ruslan Greatness            2.425975            2.974996
# Nicholas Mora               2.832423            3.452093
# Elvis Figueroa              4.748317            5.348954
#
#                   change_in_pitching_stars
# Bright Zimmerman                  0.567459
# Henry Marshallow                  0.627923
# Ruslan Greatness                  0.549020
# Nicholas Mora                     0.619670
# Elvis Figueroa                    0.600637

# %% [markdown]
# ### Tag Team Hitting
# **Improve your team's hitting by 10%. The last place team in the opposite subleague also gets +10% team hitting.**
#
#
# See below for analysis. It is impossible to know the last place team in the opposing subleague until the regular season
# is complete.

# %%
table, total, avg = improve_team_batting_table(pies, 0.10)
print("Change in Total stars: " + str(total["change_in_batting_stars"]))
print("Change in Average stars: " + str(avg["change_in_batting_stars"]))
table
# Out:
# Change in Total stars: 3.7414256749426684
# Change in Average stars: 0.5344893821346669
#                  old_batting_stars  new_batting_stars  change_in_batting_stars
# Farrell Seagull           2.030782           2.633148                 0.602366
# Yusef Puddles             2.147811           2.778538                 0.630727
# Beasley Day               2.695709           3.291428                 0.595719
# Lang Richardson           2.914378           3.423157                 0.508779
# Eduardo Woodman           4.165300           4.648604                 0.483305
# Jode Preston              4.238300           4.721003                 0.482703
# Jaxon Buckley             5.579461           6.017289                 0.437827

# %% [markdown]
# ### Wind Spirits
# **Run. +15% Team Baserunning**
#
# See below for analysis.

# %%
table, total, avg = improve_team_baserunning_table(pies, 0.15)
print("Change in Total stars: " + str(total["change_in_baserunning_stars"]))
print("Change in Average stars: " + str(avg["change_in_baserunning_stars"]))
table
# Out:
# Change in Total stars: 5.10018427737668
# Change in Average stars: 0.7285977539109544
#                  old_baserunning_stars  new_baserunning_stars  \
# Farrell Seagull               2.708760               3.454453
# Yusef Puddles                 2.817447               3.570209
# Beasley Day                   2.470609               3.215127
# Lang Richardson               3.241335               3.966644
# Eduardo Woodman               3.519368               4.224525
# Jode Preston                  3.687356               4.395570
# Jaxon Buckley                 3.263785               3.982316
#
#                  change_in_baserunning_stars
# Farrell Seagull                     0.745694
# Yusef Puddles                       0.752762
# Beasley Day                         0.744518
# Lang Richardson                     0.725309
# Eduardo Woodman                     0.705157
# Jode Preston                        0.708214
# Jaxon Buckley                       0.718531

# %% [markdown]
# ### The Rack
# **\[cartilage and bone snapping\] +15% Team Defense**
#
# See below for analysis

# %%
table, total, avg = improve_team_defense_table(pies, 0.15)
print("Change in Total stars: " + str(total["change_in_defense_stars"]))
print("Change in Average stars: " + str(avg["change_in_defense_stars"]))
table
# Out:
# Change in Total stars: 8.256794144259008
# Change in Average stars: 0.6880661786882506
#                   old_defense_stars  new_defense_stars  \
# Farrell Seagull            1.502597           2.383884
# Yusef Puddles              3.596398           4.226222
# Beasley Day                1.617475           2.487640
# Lang Richardson            3.451126           4.109060
# Eduardo Woodman            3.554369           4.179197
# Jode Preston               1.957512           2.759375
# Jaxon Buckley              2.054179           2.822311
# Bright Zimmerman           3.151142           3.771084
# Henry Marshallow           3.576140           4.251613
# Ruslan Greatness           3.909111           4.493714
# Nicholas Mora              4.746472           5.286120
# Elvis Figueroa             3.740164           4.343257
#
#                   change_in_defense_stars
# Farrell Seagull                  0.881287
# Yusef Puddles                    0.629824
# Beasley Day                      0.870164
# Lang Richardson                  0.657934
# Eduardo Woodman                  0.624829
# Jode Preston                     0.801864
# Jaxon Buckley                    0.768132
# Bright Zimmerman                 0.619942
# Henry Marshallow                 0.675474
# Ruslan Greatness                 0.584603
# Nicholas Mora                    0.539648
# Elvis Figueroa                   0.603093

# %% [markdown]
# ### The Best Defense
# **Is good offense. Swap your best hitting pitcher into your lineup.**
#
# This will make our worst batter pitch, see below for affected players and Team Average Star changes.

# %%
tbd_pitcher = best_hitting_pitcher(pies)
tbd_batter = sort_lineup(pies, 1)[0]

print(f"Swap {tbd_pitcher.name} for {tbd_batter.name}")
pandas.DataFrame(swap_players(pies, player_lineup=tbd_pitcher, player_rotation=tbd_batter))
# Out:
# Swap Nicholas Mora for Farrell Seagull
#                         Pies
# batting_change      +7.3949%
# pitching_change     -2.8629%
# baserunning_change  +4.7181%
# defense_change      +9.2682%

# %% [markdown]
# ### The Best Offense
# **Is good defense. Swap your best pitching hitter into your rotation.**
#
# This will make our worst pitcher bat, see below for affected players and Team Average Star changes.

# %%
tbo_batter = best_pitching_hitter(pies)
tbo_pitcher = sort_rotation(pies, 1)[0]

print(f"Swap {tbo_batter.name} for {tbo_pitcher.name}")
pandas.DataFrame(swap_players(pies, player_lineup=tbo_pitcher, player_rotation=tbo_batter))
# Out:
# Swap Jaxon Buckley for Bright Zimmerman
#                         Pies
# batting_change      -5.7703%
# pitching_change     +3.2320%
# baserunning_change  -6.6995%
# defense_change      +3.1342%

# %% [markdown]
# ---
# ## Appendix
# * [Description of Attributes](https://www.blaseball.wiki/w/FK:Player_Attributes)
# * [Stlat Viewer](https://slavfox.space/abslve/?foreboding-kaleidoscope#PHIL)
# * [Historical Player Graphs](http://yoori.space/hloroscopes/)
