# %% [markdown]
# # Season 21 Election Notes
#
# >**FORBIDDEN KNOWLEDGE WARNING**
# >
# >This document contains some information that is not currently present on the main site and may be considered spoilers.
# >Continue at your own discretion. Some information in this document cannot be shared on the Discord without spoiler tags.

# %%
import pandas
# %matplotlib inline
from blaseball_mike.models import *
from blaseball_mike.tables import StatType
import plotly.express as plot
import plotly.io as _pio
import plotly.subplots as subplot
from IPython.display import display, Markdown
from copy import deepcopy

import os
import sys
pdir = os.path.abspath(os.path.join(os.path.dirname(''), os.path.pardir))
sys.path.append(pdir)
from display import *
from blessings import *
sys.path.remove(pdir)

_pio.renderers.default = "notebook_connected"

pies = Team.load_by_name("Philly Pies")

# Fix Attractors
real_pies = deepcopy(pies)
for p in real_pies.lineup + real_pies.rotation:
    p.batting_rating = None
    p.pitching_rating = None
    p.baserunning_rating = None
    p.defense_rating = None

sim = SimulationData.load()
display(Markdown(f"**Last Updated Season {sim.season}, Day {sim.day}**"))
# Out:
# **Last Updated Season 21, Day 7**

# %% [markdown]
# ---
# ## Decrees
#
# Decrees are chosen by majority votes across all teams. `1` decrees will pass this season.

# %% [markdown]
# ### Sum Sun, Sun 90, & Sun .1
#
# **Weather. Each successive scoring play by a Team within a half inning is worth an additional Run.**
#
# **Weather. Scoring Plays will earn an additional Run for each out.**
#
# **Weather. Each Run scored is worth .1 more per Inning.**
#
# These weathers increase the number of runs scored in certain instances when the weather is in effect.

# %% [markdown]
# ___
# ## Wills
#
# Will are selected for each team by raffle. Each team will draw `2` random wills. The bottom 4 teams in the league by
# standings will draw `3`. The chosen wills are random, but wills with more votes are more likely to be selected.

# %% [markdown]
# ### Equivalent Exchange
# **Swap a Player from a Team in the League with an Equivalent (within 2 Stars) Player on your Team.**
#
# See below for the 20 best swap candidates for a particular player, sorted by highest stats in the applicable position.

# %%
league = League.load()
all_teams = list(league.teams.values())
all_active = []
for team in all_teams:
    if team.id != pies.id:
        all_active.extend(team.lineup + team.rotation)
all_total_stars = get_total_stars(all_active)

# %%
for player in pies.lineup:
    total_stars = get_total_stars(player)[player.id]
    valid_total_stars = {k: v for k, v in all_total_stars.items() if total_stars-2 < v < total_stars+2}
    player_matches = [x for x in all_active if x.id in valid_total_stars.keys()]
    player_matches.sort(key=lambda x: x.batting_rating, reverse=True)
    display(Markdown(f"####{player.name}"))
    display(get_stars([player] + player_matches[0:20], include_team=True))
    display(set_heatmap(get_batting_stlats([player] + player_matches[0:20]), maxVal=1.5))
# Out:
# ####Eduardo Woodman
#                                     Combined  Batting  Pitching  Baserunning  \
#                      Team
# Eduardo Woodman      Pies               14.3      5.6       1.8          3.7
# Howell Franklin      Sunbeams           13.2      6.3       1.5          2.6
# Jacob Haynes         Flowers            13.0      5.6       2.9          2.5
# Baby Triumphant      Firefighters       16.0      5.6       3.0          3.4
# Agan Harrison        Shoe Thieves       13.5      5.5       2.0          3.7
# Alston Cerveza       Crabs              14.2      5.5       3.0          2.6
# Dudley Mueller       Tigers             16.2      5.4       3.1          3.3
# Rai Spliff           Steaks             15.3      5.2       2.4          3.7
# Fish Summer          Tacos              12.8      5.2       1.8          3.6
# Basilio Mason        Tacos              16.3      5.2       2.6          4.5
# Zephyr McCloud       Steaks             13.3      5.1       1.9          2.6
# Gia Holbrook         Mechanics          14.0      5.1       3.8          2.4
# Eugenia Garbage      Moist Talkers      14.5      4.9       4.7          2.3
# Fitzgerald Blackburn Spies              15.2      4.9       3.5          2.4
# Lotus Mango          Garages            14.7      4.9       3.4          3.1
# Comfort Septemberish Sunbeams           13.7      4.9       1.2          4.9
# Avila Guzman         Crabs              16.1      4.8       1.6          5.5
# Mira Lemma           Mechanics          15.6      4.7       3.2          3.6
# Randy Dennis         Moist Talkers      16.0      4.7       2.2          4.5
# August Sky           Jazz Hands         14.8      4.7       4.3          2.7
# Scores Baserunner    Flowers            12.9      4.7       1.2          2.9
#
#                                     Defense
#                      Team
# Eduardo Woodman      Pies               3.3
# Howell Franklin      Sunbeams           2.7
# Jacob Haynes         Flowers            1.9
# Baby Triumphant      Firefighters       4.0
# Agan Harrison        Shoe Thieves       2.3
# Alston Cerveza       Crabs              3.1
# Dudley Mueller       Tigers             4.5
# Rai Spliff           Steaks             4.0
# Fish Summer          Tacos              2.3
# Basilio Mason        Tacos              4.1
# Zephyr McCloud       Steaks             3.6
# Gia Holbrook         Mechanics          2.8
# Eugenia Garbage      Moist Talkers      2.5
# Fitzgerald Blackburn Spies              4.5
# Lotus Mango          Garages            3.3
# Comfort Septemberish Sunbeams           2.6
# Avila Guzman         Crabs              4.4
# Mira Lemma           Mechanics          4.0
# Randy Dennis         Moist Talkers      4.6
# August Sky           Jazz Hands         3.0
# Scores Baserunner    Flowers            4.0
# <style  type="text/css" >
# #T_6f372_row0_col0,#T_6f372_row2_col0{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_6f372_row0_col1{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_6f372_row0_col2,#T_6f372_row7_col2,#T_6f372_row9_col3{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_6f372_row0_col3{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_6f372_row0_col4,#T_6f372_row8_col3,#T_6f372_row11_col6{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_6f372_row0_col5{
#             background-color:  #f16640;
#             color:  #000000;
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_6f372_row0_col6{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_6f372_row0_col7,#T_6f372_row1_col5,#T_6f372_row1_col7,#T_6f372_row2_col5,#T_6f372_row3_col5,#T_6f372_row3_col7,#T_6f372_row6_col7,#T_6f372_row7_col5,#T_6f372_row7_col7,#T_6f372_row8_col5,#T_6f372_row8_col7,#T_6f372_row9_col7,#T_6f372_row10_col5,#T_6f372_row11_col7,#T_6f372_row12_col5,#T_6f372_row12_col7,#T_6f372_row14_col7,#T_6f372_row16_col7,#T_6f372_row18_col7,#T_6f372_row19_col7{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_6f372_row0_col8,#T_6f372_row2_col2,#T_6f372_row6_col4,#T_6f372_row6_col6,#T_6f372_row10_col1{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_6f372_row1_col0,#T_6f372_row12_col6,#T_6f372_row18_col8{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_6f372_row1_col1,#T_6f372_row20_col1{
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_6f372_row1_col2{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_6f372_row1_col3,#T_6f372_row6_col1,#T_6f372_row6_col8,#T_6f372_row9_col4,#T_6f372_row9_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_6f372_row1_col4,#T_6f372_row16_col2{
#             background-color:  #04703b;
#             color:  #f1f1f1;
#         }#T_6f372_row1_col6,#T_6f372_row4_col8,#T_6f372_row9_col6,#T_6f372_row14_col2{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_6f372_row1_col8{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_6f372_row2_col1{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_6f372_row2_col3,#T_6f372_row3_col1,#T_6f372_row17_col3{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_6f372_row2_col4,#T_6f372_row4_col2{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_6f372_row2_col6{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_6f372_row2_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_6f372_row2_col8{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_6f372_row3_col0{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_6f372_row3_col2{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_6f372_row3_col3,#T_6f372_row15_col8{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_6f372_row3_col4{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_6f372_row3_col6{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_6f372_row3_col8,#T_6f372_row7_col1{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_6f372_row4_col0,#T_6f372_row5_col0,#T_6f372_row15_col6{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_6f372_row4_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_6f372_row4_col3,#T_6f372_row13_col6,#T_6f372_row19_col2{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_6f372_row4_col4,#T_6f372_row10_col8{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_6f372_row4_col5{
#             background-color:  #fdc574;
#             color:  #000000;
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_6f372_row4_col6{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_6f372_row4_col7,#T_6f372_row5_col7{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             background-color:  #199750;
#             color:  #000000;
#         }#T_6f372_row5_col1{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_6f372_row5_col2,#T_6f372_row14_col1{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_6f372_row5_col3,#T_6f372_row16_col3{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_6f372_row5_col4,#T_6f372_row11_col8,#T_6f372_row17_col1{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_6f372_row5_col5{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_6f372_row5_col6{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_6f372_row5_col8{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_6f372_row6_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_6f372_row6_col2,#T_6f372_row8_col6{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_6f372_row6_col3{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_6f372_row6_col5{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_6f372_row7_col0,#T_6f372_row8_col0{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_6f372_row7_col3{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_6f372_row7_col4,#T_6f372_row14_col4{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_6f372_row7_col6{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_6f372_row7_col8{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_6f372_row8_col1,#T_6f372_row10_col3{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_6f372_row8_col2{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_6f372_row8_col4,#T_6f372_row11_col4{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_6f372_row8_col8{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_6f372_row9_col0{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_6f372_row9_col1{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_6f372_row9_col2{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_6f372_row9_col5{
#             background-color:  #e44c34;
#             color:  #000000;
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_6f372_row10_col0,#T_6f372_row10_col6,#T_6f372_row11_col0{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_6f372_row10_col2{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_6f372_row10_col4{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_6f372_row10_col7,#T_6f372_row20_col5{
#             background-color:  #be1827;
#             color:  #f1f1f1;
#             background-color:  #0d8044;
# ####Beasley Day
#                                  Combined  Batting  Pitching  Baserunning  \
#                    Team
# Beasley Day        Pies              17.8      5.4       4.1          4.4
# Nagomi Nava        Sunbeams          17.6      6.3       3.0          4.9
# Thomas Dracaena    Millennials       19.1      6.3       3.4          4.8
# Vessalius Sundae   Worms             17.5      5.9       3.7          4.3
# Gerund Pantheocide Lift              17.8      5.7       4.1          3.4
# Margarito Nava     Flowers           17.5      5.6       4.1          4.7
# Cannonball Sports  Mechanics         16.7      5.6       2.1          4.4
# Baby Triumphant    Firefighters      16.0      5.6       3.0          3.4
# Baby Doyle         Jazz Hands        17.0      5.5       2.9          3.7
# Lenny Spruce       Flowers           18.7      5.5       2.8          5.4
# Jordan Hildebert   Shoe Thieves      19.0      5.4       4.2          4.8
# Dudley Mueller     Tigers            16.2      5.4       3.1          3.3
# En-d -arlow        Crabs             19.2      5.4       4.0          5.5
# Hahn Fox           Sunbeams          17.0      5.2       3.6          4.9
# Basilio Mason      Tacos             16.3      5.2       2.6          4.5
# Mint Shupe         Lovers            16.6      5.1       3.1          4.2
# Silvaire Roadhouse Flowers           18.4      5.1       3.9          4.4
# Mindy Kugel        Mechanics         18.3      5.0       5.7          4.0
# Con--r Hale-       Crabs             16.7      5.0       3.1          5.1
# Brock Watson       Wild Wings        18.6      5.0       4.0          4.8
# Sam Scandal        Steaks            17.8      4.9       5.9          4.2
#
#                                  Defense
#                    Team
# Beasley Day        Pies              3.9
# Nagomi Nava        Sunbeams          3.5
# Thomas Dracaena    Millennials       4.7
# Vessalius Sundae   Worms             3.7
# Gerund Pantheocide Lift              4.6
# Margarito Nava     Flowers           3.0
# Cannonball Sports  Mechanics         4.6
# Baby Triumphant    Firefighters      4.0
# Baby Doyle         Jazz Hands        4.8
# Lenny Spruce       Flowers           5.0
# Jordan Hildebert   Shoe Thieves      4.6
# Dudley Mueller     Tigers            4.5
# En-d -arlow        Crabs             4.3
# Hahn Fox           Sunbeams          3.3
# Basilio Mason      Tacos             4.1
# Mint Shupe         Lovers            4.1
# Silvaire Roadhouse Flowers           5.1
# Mindy Kugel        Mechanics         3.5
# Con--r Hale-       Crabs             3.6
# Brock Watson       Wild Wings        4.9
# Sam Scandal        Steaks            2.8
# <style  type="text/css" >
# #T_2f2e5_row0_col0,#T_2f2e5_row12_col0{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_2f2e5_row0_col1,#T_2f2e5_row14_col6{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_2f2e5_row0_col2,#T_2f2e5_row10_col0{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_2f2e5_row0_col3,#T_2f2e5_row13_col6{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_2f2e5_row0_col4{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_2f2e5_row0_col5{
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_2f2e5_row0_col6,#T_2f2e5_row20_col4{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_2f2e5_row0_col7,#T_2f2e5_row1_col7,#T_2f2e5_row2_col5,#T_2f2e5_row2_col7,#T_2f2e5_row3_col5,#T_2f2e5_row3_col7,#T_2f2e5_row4_col7,#T_2f2e5_row5_col7,#T_2f2e5_row6_col7,#T_2f2e5_row7_col5,#T_2f2e5_row7_col7,#T_2f2e5_row9_col7,#T_2f2e5_row11_col7,#T_2f2e5_row12_col5,#T_2f2e5_row13_col7,#T_2f2e5_row14_col7,#T_2f2e5_row16_col5,#T_2f2e5_row16_col7,#T_2f2e5_row17_col7,#T_2f2e5_row19_col7,#T_2f2e5_row20_col7{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_2f2e5_row0_col8,#T_2f2e5_row4_col2{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_2f2e5_row1_col0{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_2f2e5_row1_col1,#T_2f2e5_row1_col8,#T_2f2e5_row11_col3,#T_2f2e5_row20_col0{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_2f2e5_row1_col2,#T_2f2e5_row1_col4,#T_2f2e5_row3_col2,#T_2f2e5_row5_col4,#T_2f2e5_row11_col1,#T_2f2e5_row11_col8,#T_2f2e5_row14_col4,#T_2f2e5_row14_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_2f2e5_row1_col3,#T_2f2e5_row14_col2{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_2f2e5_row1_col5{
#             background-color:  #af0926;
#             color:  #f1f1f1;
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_2f2e5_row1_col6{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_2f2e5_row2_col0,#T_2f2e5_row6_col8{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_2f2e5_row2_col1,#T_2f2e5_row19_col2{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_2f2e5_row2_col2{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_2f2e5_row2_col3,#T_2f2e5_row16_col6{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_2f2e5_row2_col4,#T_2f2e5_row17_col1{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_2f2e5_row2_col6{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_2f2e5_row2_col8{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_2f2e5_row3_col0{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_2f2e5_row3_col1,#T_2f2e5_row18_col0,#T_2f2e5_row19_col0{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_2f2e5_row3_col3,#T_2f2e5_row4_col4{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_2f2e5_row3_col4,#T_2f2e5_row4_col1,#T_2f2e5_row17_col2{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_2f2e5_row3_col6{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_2f2e5_row3_col8{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_2f2e5_row4_col0{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_2f2e5_row4_col3,#T_2f2e5_row6_col3{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_2f2e5_row4_col5{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_2f2e5_row4_col6{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_2f2e5_row4_col8{
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_2f2e5_row5_col0,#T_2f2e5_row18_col1{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_2f2e5_row5_col1,#T_2f2e5_row7_col4{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_2f2e5_row5_col2{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_2f2e5_row5_col3,#T_2f2e5_row8_col3{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_2f2e5_row5_col5{
#             background-color:  #f98e52;
#             color:  #000000;
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_2f2e5_row5_col6,#T_2f2e5_row13_col1{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_2f2e5_row5_col8{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_2f2e5_row6_col0,#T_2f2e5_row6_col2,#T_2f2e5_row7_col0{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_2f2e5_row6_col1{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_2f2e5_row6_col4,#T_2f2e5_row8_col2,#T_2f2e5_row13_col0,#T_2f2e5_row18_col6{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_2f2e5_row6_col5{
#             background-color:  #cc2627;
#             color:  #f1f1f1;
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_2f2e5_row6_col6{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_2f2e5_row7_col1{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_2f2e5_row7_col2{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_2f2e5_row7_col3{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_2f2e5_row7_col6{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_2f2e5_row7_col8{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_2f2e5_row8_col0,#T_2f2e5_row9_col1,#T_2f2e5_row15_col1{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_2f2e5_row8_col1{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_2f2e5_row8_col4{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_2f2e5_row8_col5{
#             background-color:  #e54e35;
#             color:  #000000;
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_2f2e5_row8_col6,#T_2f2e5_row20_col3{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_2f2e5_row8_col7{
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_2f2e5_row8_col8{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_2f2e5_row9_col0{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_2f2e5_row9_col2{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_2f2e5_row9_col3{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_2f2e5_row9_col4,#T_2f2e5_row17_col0{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_2f2e5_row9_col5{
#             background-color:  #c82227;
#             color:  #f1f1f1;
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_2f2e5_row9_col6{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_2f
# ####Huber Frumple
#                                     Combined  Batting  Pitching  Baserunning  \
#                      Team
# Huber Frumple        Pies               14.9      4.8       2.4          4.4
# Howell Franklin      Sunbeams           13.2      6.3       1.5          2.6
# Jacob Haynes         Flowers            13.0      5.6       2.9          2.5
# Cannonball Sports    Mechanics          16.7      5.6       2.1          4.4
# Baby Triumphant      Firefighters       16.0      5.6       3.0          3.4
# Agan Harrison        Shoe Thieves       13.5      5.5       2.0          3.7
# Alston Cerveza       Crabs              14.2      5.5       3.0          2.6
# Dudley Mueller       Tigers             16.2      5.4       3.1          3.3
# Rai Spliff           Steaks             15.3      5.2       2.4          3.7
# Basilio Mason        Tacos              16.3      5.2       2.6          4.5
# Mint Shupe           Lovers             16.6      5.1       3.1          4.2
# Zephyr McCloud       Steaks             13.3      5.1       1.9          2.6
# Gia Holbrook         Mechanics          14.0      5.1       3.8          2.4
# Con--r Hale-         Crabs              16.7      5.0       3.1          5.1
# Eugenia Garbage      Moist Talkers      14.5      4.9       4.7          2.3
# Fitzgerald Blackburn Spies              15.2      4.9       3.5          2.4
# Lotus Mango          Garages            14.7      4.9       3.4          3.1
# Comfort Septemberish Sunbeams           13.7      4.9       1.2          4.9
# Avila Guzman         Crabs              16.1      4.8       1.6          5.5
# Ephraim Ladd         Worms              16.9      4.8       4.7          3.3
# Mira Lemma           Mechanics          15.6      4.7       3.2          3.6
#
#                                     Defense
#                      Team
# Huber Frumple        Pies               3.4
# Howell Franklin      Sunbeams           2.7
# Jacob Haynes         Flowers            1.9
# Cannonball Sports    Mechanics          4.6
# Baby Triumphant      Firefighters       4.0
# Agan Harrison        Shoe Thieves       2.3
# Alston Cerveza       Crabs              3.1
# Dudley Mueller       Tigers             4.5
# Rai Spliff           Steaks             4.0
# Basilio Mason        Tacos              4.1
# Mint Shupe           Lovers             4.1
# Zephyr McCloud       Steaks             3.6
# Gia Holbrook         Mechanics          2.8
# Con--r Hale-         Crabs              3.6
# Eugenia Garbage      Moist Talkers      2.5
# Fitzgerald Blackburn Spies              4.5
# Lotus Mango          Garages            3.3
# Comfort Septemberish Sunbeams           2.6
# Avila Guzman         Crabs              4.4
# Ephraim Ladd         Worms              4.2
# Mira Lemma           Mechanics          4.0
# <style  type="text/css" >
# #T_38f3d_row0_col0{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_38f3d_row0_col1{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_38f3d_row0_col2{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_38f3d_row0_col3,#T_38f3d_row8_col0{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_38f3d_row0_col4{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_38f3d_row0_col5{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_38f3d_row0_col6,#T_38f3d_row17_col4{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_38f3d_row0_col7,#T_38f3d_row1_col5,#T_38f3d_row1_col7,#T_38f3d_row2_col5,#T_38f3d_row3_col7,#T_38f3d_row4_col5,#T_38f3d_row4_col7,#T_38f3d_row7_col7,#T_38f3d_row8_col5,#T_38f3d_row8_col7,#T_38f3d_row9_col7,#T_38f3d_row11_col5,#T_38f3d_row12_col7,#T_38f3d_row14_col5,#T_38f3d_row14_col7,#T_38f3d_row16_col7,#T_38f3d_row18_col7,#T_38f3d_row19_col5,#T_38f3d_row19_col7{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_38f3d_row0_col8,#T_38f3d_row17_col1{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_38f3d_row1_col0,#T_38f3d_row14_col6{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_38f3d_row1_col1{
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_38f3d_row1_col2{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_38f3d_row1_col3,#T_38f3d_row7_col1,#T_38f3d_row7_col8,#T_38f3d_row9_col4,#T_38f3d_row9_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_38f3d_row1_col4,#T_38f3d_row18_col2{
#             background-color:  #04703b;
#             color:  #f1f1f1;
#         }#T_38f3d_row1_col6,#T_38f3d_row5_col8,#T_38f3d_row9_col6,#T_38f3d_row16_col2{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_38f3d_row1_col8{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_38f3d_row2_col0,#T_38f3d_row13_col1{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_38f3d_row2_col1{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_38f3d_row2_col2,#T_38f3d_row7_col4,#T_38f3d_row7_col6,#T_38f3d_row11_col1{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_38f3d_row2_col3,#T_38f3d_row4_col1,#T_38f3d_row20_col3{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_38f3d_row2_col4,#T_38f3d_row5_col2{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_38f3d_row2_col6{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_38f3d_row2_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_38f3d_row2_col8{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_38f3d_row3_col0,#T_38f3d_row3_col2,#T_38f3d_row4_col0{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_38f3d_row3_col1{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_38f3d_row3_col3,#T_38f3d_row11_col0,#T_38f3d_row11_col6,#T_38f3d_row12_col0{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_38f3d_row3_col4,#T_38f3d_row13_col6{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_38f3d_row3_col5{
#             background-color:  #cc2627;
#             color:  #f1f1f1;
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_38f3d_row3_col6{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_38f3d_row3_col8,#T_38f3d_row6_col4,#T_38f3d_row12_col8,#T_38f3d_row20_col1{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_38f3d_row4_col2{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_38f3d_row4_col3,#T_38f3d_row17_col8{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_38f3d_row4_col4{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_38f3d_row4_col6{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_38f3d_row4_col8,#T_38f3d_row8_col1{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_38f3d_row5_col0,#T_38f3d_row6_col0,#T_38f3d_row17_col6{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_38f3d_row5_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_38f3d_row5_col3,#T_38f3d_row15_col6{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_38f3d_row5_col4,#T_38f3d_row11_col8{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_38f3d_row5_col5{
#             background-color:  #fdc574;
#             color:  #000000;
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_38f3d_row5_col6{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_38f3d_row5_col7,#T_38f3d_row6_col7{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             background-color:  #199750;
#             color:  #000000;
#         }#T_38f3d_row6_col1{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_38f3d_row6_col2,#T_38f3d_row16_col1{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_38f3d_row6_col3,#T_38f3d_row18_col3{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_38f3d_row6_col5{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_38f3d_row6_col6{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_38f3d_row6_col8{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_38f3d_row7_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_38f3d_row7_col2{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_38f3d_row7_col3{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_38f3d_row7_col5{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_38f3d_row8_col2,#T_38f3d_row9_col3{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_38f3d_row8_col3{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_38f3d_row8_col4,#T_38f3d_row16_col4{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_38f3d_row8_col6{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_38f3d_row8_col8{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_38f3d_row9_col0,#T_38f3d_row10_col0{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_38f3d_row9_col1,#T_38f3d_row19_col1{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_38f3d_row9_col2{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_38f3d_row9_col5{
#             background-color:  #e44c34;
#             color:  #000000;
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_38f3d_row10_col1{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_38f3d_row10_col2{
# ####Ruslan Greatness
#                                  Combined  Batting  Pitching  Baserunning  \
#                    Team
# Ruslan Greatness   Pies              19.0      4.8       4.1          5.1
# Commissioner Vapor Spies             20.5      6.4       4.5          5.5
# Nagomi Nava        Sunbeams          17.6      6.3       3.0          4.9
# Thomas Dracaena    Millennials       19.1      6.3       3.4          4.8
# Vessalius Sundae   Worms             17.5      5.9       3.7          4.3
# Gerund Pantheocide Lift              17.8      5.7       4.1          3.4
# Margarito Nava     Flowers           17.5      5.6       4.1          4.7
# Lenny Spruce       Flowers           18.7      5.5       2.8          5.4
# Jordan Hildebert   Shoe Thieves      19.0      5.4       4.2          4.8
# En-d -arlow        Crabs             19.2      5.4       4.0          5.5
# Kennedy Loser      Crabs             20.5      5.2       5.5          4.7
# Silvaire Roadhouse Flowers           18.4      5.1       3.9          4.4
# Mindy Kugel        Mechanics         18.3      5.0       5.7          4.0
# Brock Watson       Wild Wings        18.6      5.0       4.0          4.8
# Sam Scandal        Steaks            17.8      4.9       5.9          4.2
# Franci-co Preston  Magic             17.1      4.9       3.7          4.5
# Richmond Harrison  Dale              19.2      4.9       3.2          5.1
# Mcdowell Mason     Tacos             18.0      4.8       2.9          5.0
# Yurts Buttercup    Georgias          18.3      4.8       5.0          4.0
# Peanutiel Duffy    Firefighters      17.2      4.8       5.0          3.2
# Scratch Deleuze    Worms             18.1      4.8       3.1          6.0
#
#                                  Defense
#                    Team
# Ruslan Greatness   Pies              5.1
# Commissioner Vapor Spies             4.1
# Nagomi Nava        Sunbeams          3.5
# Thomas Dracaena    Millennials       4.7
# Vessalius Sundae   Worms             3.7
# Gerund Pantheocide Lift              4.6
# Margarito Nava     Flowers           3.0
# Lenny Spruce       Flowers           5.0
# Jordan Hildebert   Shoe Thieves      4.6
# En-d -arlow        Crabs             4.3
# Kennedy Loser      Crabs             5.0
# Silvaire Roadhouse Flowers           5.1
# Mindy Kugel        Mechanics         3.5
# Brock Watson       Wild Wings        4.9
# Sam Scandal        Steaks            2.8
# Franci-co Preston  Magic             3.9
# Richmond Harrison  Dale              6.1
# Mcdowell Mason     Tacos             5.2
# Yurts Buttercup    Georgias          4.4
# Peanutiel Duffy    Firefighters      4.2
# Scratch Deleuze    Worms             4.3
# <style  type="text/css" >
# #T_1032f_row0_col0,#T_1032f_row3_col3,#T_1032f_row11_col6,#T_1032f_row19_col0,#T_1032f_row20_col0{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_1032f_row0_col1{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_1032f_row0_col2,#T_1032f_row5_col0{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_1032f_row0_col3,#T_1032f_row1_col4,#T_1032f_row2_col2,#T_1032f_row2_col4,#T_1032f_row4_col2,#T_1032f_row6_col4,#T_1032f_row20_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_1032f_row0_col4{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_1032f_row0_col5,#T_1032f_row0_col7,#T_1032f_row1_col5,#T_1032f_row1_col7,#T_1032f_row2_col7,#T_1032f_row3_col5,#T_1032f_row3_col7,#T_1032f_row4_col5,#T_1032f_row4_col7,#T_1032f_row5_col7,#T_1032f_row6_col7,#T_1032f_row7_col7,#T_1032f_row9_col5,#T_1032f_row10_col5,#T_1032f_row10_col7,#T_1032f_row11_col5,#T_1032f_row11_col7,#T_1032f_row12_col7,#T_1032f_row13_col7,#T_1032f_row14_col7,#T_1032f_row15_col7,#T_1032f_row16_col7,#T_1032f_row17_col5,#T_1032f_row17_col7,#T_1032f_row19_col7,#T_1032f_row20_col5{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_1032f_row0_col6{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_1032f_row0_col8{
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_1032f_row1_col0,#T_1032f_row18_col3{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_1032f_row1_col1,#T_1032f_row20_col4{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_1032f_row1_col2,#T_1032f_row14_col3{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_1032f_row1_col3,#T_1032f_row16_col0,#T_1032f_row17_col0{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_1032f_row1_col6{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_1032f_row1_col8,#T_1032f_row17_col3{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_1032f_row2_col0{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_1032f_row2_col1,#T_1032f_row2_col8,#T_1032f_row14_col0,#T_1032f_row15_col0{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_1032f_row2_col3{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_1032f_row2_col5{
#             background-color:  #af0926;
#             color:  #f1f1f1;
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_1032f_row2_col6{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_1032f_row3_col0{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_1032f_row3_col1,#T_1032f_row13_col2{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_1032f_row3_col2{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_1032f_row3_col4,#T_1032f_row12_col1{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_1032f_row3_col6{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_1032f_row3_col8{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_1032f_row4_col0,#T_1032f_row19_col1{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_1032f_row4_col1,#T_1032f_row13_col0{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_1032f_row4_col3,#T_1032f_row5_col4{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_1032f_row4_col4,#T_1032f_row5_col1,#T_1032f_row12_col2{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_1032f_row4_col6{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_1032f_row4_col8{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_1032f_row5_col2{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_1032f_row5_col3{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_1032f_row5_col5{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_1032f_row5_col6,#T_1032f_row16_col4{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_1032f_row5_col8,#T_1032f_row16_col8{
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_1032f_row6_col0{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_1032f_row6_col1,#T_1032f_row15_col3{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_1032f_row6_col2,#T_1032f_row10_col2{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_1032f_row6_col3{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_1032f_row6_col5,#T_1032f_row18_col7{
#             background-color:  #f98e52;
#             color:  #000000;
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_1032f_row6_col6{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_1032f_row6_col8{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_1032f_row7_col0{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_1032f_row7_col1{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_1032f_row7_col2,#T_1032f_row18_col8{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_1032f_row7_col3{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_1032f_row7_col4,#T_1032f_row12_col0{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_1032f_row7_col5{
#             background-color:  #c82227;
#             color:  #f1f1f1;
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_1032f_row7_col6{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_1032f_row7_col8,#T_1032f_row9_col2{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_1032f_row8_col0{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_1032f_row8_col1,#T_1032f_row20_col1{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_1032f_row8_col2,#T_1032f_row16_col2{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_1032f_row8_col3,#T_1032f_row14_col6{
#             background-color:  #e5f49b;
#             color:  #000000;
#         }#T_1032f_row8_col4{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_1032f_row8_col5{
#             background-color:  #f67c4a;
#             color:  #000000;
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_1032f_row8_col6,#T_1032f_row19_col2{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_1032f_row8_col7{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_1032f_row8_col8{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_1032f_row9_col0{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_1032f_row9_col1,#T_1032f_row12_col4,#T_1032f_row19_col3{
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_1032f_row9_col3{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_1032f_row9_col4,#
# ####Jaxon Buckley
#                                  Combined  Batting  Pitching  Baserunning  \
#                    Team
# Jaxon Buckley      Pies              19.4      7.1       4.4          4.0
# Commissioner Vapor Spies             20.5      6.4       4.5          5.5
# Nagomi Nava        Sunbeams          17.6      6.3       3.0          4.9
# Thomas Dracaena    Millennials       19.1      6.3       3.4          4.8
# Vessalius Sundae   Worms             17.5      5.9       3.7          4.3
# Ronan Jaylee       Steaks            21.2      5.8       4.0          5.4
# Gerund Pantheocide Lift              17.8      5.7       4.1          3.4
# Margarito Nava     Flowers           17.5      5.6       4.1          4.7
# Lenny Spruce       Flowers           18.7      5.5       2.8          5.4
# Jordan Hildebert   Shoe Thieves      19.0      5.4       4.2          4.8
# En-d -arlow        Crabs             19.2      5.4       4.0          5.5
# Kennedy Loser      Crabs             20.5      5.2       5.5          4.7
# Silvaire Roadhouse Flowers           18.4      5.1       3.9          4.4
# Mindy Kugel        Mechanics         18.3      5.0       5.7          4.0
# Brock Watson       Wild Wings        18.6      5.0       4.0          4.8
# Sam Scandal        Steaks            17.8      4.9       5.9          4.2
# Rigby Friedrich    Georgias          21.1      4.9       6.0          5.3
# Richmond Harrison  Dale              19.2      4.9       3.2          5.1
# Mcdowell Mason     Tacos             18.0      4.8       2.9          5.0
# Yurts Buttercup    Georgias          18.3      4.8       5.0          4.0
# Scratch Deleuze    Worms             18.1      4.8       3.1          6.0
#
#                                  Defense
#                    Team
# Jaxon Buckley      Pies              3.8
# Commissioner Vapor Spies             4.1
# Nagomi Nava        Sunbeams          3.5
# Thomas Dracaena    Millennials       4.7
# Vessalius Sundae   Worms             3.7
# Ronan Jaylee       Steaks            6.1
# Gerund Pantheocide Lift              4.6
# Margarito Nava     Flowers           3.0
# Lenny Spruce       Flowers           5.0
# Jordan Hildebert   Shoe Thieves      4.6
# En-d -arlow        Crabs             4.3
# Kennedy Loser      Crabs             5.0
# Silvaire Roadhouse Flowers           5.1
# Mindy Kugel        Mechanics         3.5
# Brock Watson       Wild Wings        4.9
# Sam Scandal        Steaks            2.8
# Rigby Friedrich    Georgias          4.9
# Richmond Harrison  Dale              6.1
# Mcdowell Mason     Tacos             5.2
# Yurts Buttercup    Georgias          4.4
# Scratch Deleuze    Worms             4.3
# <style  type="text/css" >
# #T_f61ad_row0_col0,#T_f61ad_row4_col4,#T_f61ad_row6_col1,#T_f61ad_row13_col2{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_f61ad_row0_col1,#T_f61ad_row0_col3,#T_f61ad_row0_col4,#T_f61ad_row0_col6,#T_f61ad_row0_col8,#T_f61ad_row1_col4,#T_f61ad_row2_col2,#T_f61ad_row2_col4,#T_f61ad_row4_col2,#T_f61ad_row7_col4,#T_f61ad_row20_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_f61ad_row0_col2,#T_f61ad_row6_col2{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_f61ad_row0_col5,#T_f61ad_row0_col7,#T_f61ad_row1_col5,#T_f61ad_row1_col7,#T_f61ad_row2_col7,#T_f61ad_row3_col5,#T_f61ad_row3_col7,#T_f61ad_row4_col5,#T_f61ad_row4_col7,#T_f61ad_row5_col5,#T_f61ad_row5_col7,#T_f61ad_row6_col7,#T_f61ad_row7_col7,#T_f61ad_row8_col7,#T_f61ad_row10_col5,#T_f61ad_row11_col5,#T_f61ad_row11_col7,#T_f61ad_row12_col5,#T_f61ad_row12_col7,#T_f61ad_row13_col7,#T_f61ad_row14_col7,#T_f61ad_row15_col7,#T_f61ad_row16_col5,#T_f61ad_row16_col7,#T_f61ad_row17_col7,#T_f61ad_row18_col5,#T_f61ad_row18_col7,#T_f61ad_row20_col5{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_f61ad_row1_col0,#T_f61ad_row19_col3{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_f61ad_row1_col1,#T_f61ad_row20_col4{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_f61ad_row1_col2,#T_f61ad_row15_col3{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_f61ad_row1_col3,#T_f61ad_row17_col0,#T_f61ad_row18_col0{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_f61ad_row1_col6{
#             background-color:  #118848;
# ...
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_972b2_row2_col8,#T_972b2_row14_col0{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_972b2_row3_col0,#T_972b2_row9_col6{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_972b2_row3_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_972b2_row3_col3{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_972b2_row3_col4,#T_972b2_row5_col8{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_972b2_row3_col5{
#             background-color:  #fdc574;
#             color:  #000000;
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_972b2_row3_col6{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_972b2_row3_col7{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             background-color:  #199750;
#             color:  #000000;
#         }#T_972b2_row4_col0,#T_972b2_row15_col1,#T_972b2_row17_col6{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_972b2_row4_col1,#T_972b2_row5_col3{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_972b2_row4_col2{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_972b2_row4_col3,#T_972b2_row7_col6{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_972b2_row4_col4,#T_972b2_row7_col4,#T_972b2_row8_col4,#T_972b2_row12_col0{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_972b2_row4_col6,#T_972b2_row17_col3{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_972b2_row4_col8{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_972b2_row5_col2{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_972b2_row5_col4,#T_972b2_row6_col8,#T_972b2_row20_col2{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_972b2_row5_col7,#T_972b2_row10_col5,#T_972b2_row12_col5{
#             background-color:  #be1827;
#             color:  #f1f1f1;
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_972b2_row6_col1{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_972b2_row6_col2{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_972b2_row6_col3{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_972b2_row6_col4{
#             background-color:  #fa9857;
#             color:  #000000;
#         }#T_972b2_row6_col6,#T_972b2_row17_col8{
#             background-color:  #daf08d;
#             color:  #000000;
#         }#T_972b2_row7_col1{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_972b2_row7_col2{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_972b2_row7_col3{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_972b2_row7_col5{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_972b2_row7_col8{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_972b2_row8_col0{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_972b2_row8_col1{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_972b2_row8_col2,#T_972b2_row16_col4{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_972b2_row8_col3{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_972b2_row8_col5{
#             background-color:  #af0926;
#             color:  #f1f1f1;
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_972b2_row8_col6{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_972b2_row8_col8{
#             background-color:  #feeb9d;
#             color:  #000000;
#         }#T_972b2_row9_col0{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_972b2_row9_col1{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_972b2_row9_col2{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_972b2_row9_col3,#T_972b2_row10_col8{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_972b2_row9_col4{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_972b2_row9_col5{
#             background-color:  #fee28f;
#             color:  #000000;
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_972b2_row9_col7,#T_972b2_row17_col7,#T_972b2_row18_col5{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#             background-color:  #0a7
# ####Doc Anice
#                                     Combined  Batting  Pitching  Baserunning  \
#                      Team
# Doc Anice            Pies               15.6      4.4       3.7          3.2
# Vessalius Sundae     Worms              17.5      5.9       3.7          4.3
# Margarito Nava       Flowers            17.5      5.6       4.1          4.7
# Cannonball Sports    Mechanics          16.7      5.6       2.1          4.4
# Baby Triumphant      Firefighters       16.0      5.6       3.0          3.4
# Baby Doyle           Jazz Hands         17.0      5.5       2.9          3.7
# Alston Cerveza       Crabs              14.2      5.5       3.0          2.6
# Dudley Mueller       Tigers             16.2      5.4       3.1          3.3
# Hahn Fox             Sunbeams           17.0      5.2       3.6          4.9
# Rai Spliff           Steaks             15.3      5.2       2.4          3.7
# Basilio Mason        Tacos              16.3      5.2       2.6          4.5
# Mint Shupe           Lovers             16.6      5.1       3.1          4.2
# Gia Holbrook         Mechanics          14.0      5.1       3.8          2.4
# Con--r Hale-         Crabs              16.7      5.0       3.1          5.1
# Franci-co Preston    Magic              17.1      4.9       3.7          4.5
# Eugenia Garbage      Moist Talkers      14.5      4.9       4.7          2.3
# Fitzgerald Blackburn Spies              15.2      4.9       3.5          2.4
# Lotus Mango          Garages            14.7      4.9       3.4          3.1
# Comfort Septemberish Sunbeams           13.7      4.9       1.2          4.9
# Peanutiel Duffy      Firefighters       17.2      4.8       5.0          3.2
# Avila Guzman         Crabs              16.1      4.8       1.6          5.5
#
#                                     Defense
#                      Team
# Doc Anice            Pies               4.3
# Vessalius Sundae     Worms              3.7
# Margarito Nava       Flowers            3.0
# Cannonball Sports    Mechanics          4.6
# Baby Triumphant      Firefighters       4.0
# Baby Doyle           Jazz Hands         4.8
# Alston Cerveza       Crabs              3.1
# Dudley Mueller       Tigers             4.5
# Hahn Fox             Sunbeams           3.3
# Rai Spliff           Steaks             4.0
# Basilio Mason        Tacos              4.1
# Mint Shupe           Lovers             4.1
# Gia Holbrook         Mechanics          2.8
# Con--r Hale-         Crabs              3.6
# Franci-co Preston    Magic              3.9
# Eugenia Garbage      Moist Talkers      2.5
# Fitzgerald Blackburn Spies              4.5
# Lotus Mango          Garages            3.3
# Comfort Septemberish Sunbeams           2.6
# Peanutiel Duffy      Firefighters       4.2
# Avila Guzman         Crabs              4.4
# <style  type="text/css" >
# #T_a64d0_row0_col0,#T_a64d0_row12_col6{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_a64d0_row0_col1,#T_a64d0_row0_col8{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_a64d0_row0_col2{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_a64d0_row0_col3{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_a64d0_row0_col4,#T_a64d0_row1_col1,#T_a64d0_row13_col0{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_a64d0_row0_col5,#T_a64d0_row1_col5,#T_a64d0_row1_col7,#T_a64d0_row2_col7,#T_a64d0_row3_col7,#T_a64d0_row4_col5,#T_a64d0_row4_col7,#T_a64d0_row7_col7,#T_a64d0_row8_col7,#T_a64d0_row9_col5,#T_a64d0_row9_col7,#T_a64d0_row10_col7,#T_a64d0_row12_col7,#T_a64d0_row14_col7,#T_a64d0_row15_col5,#T_a64d0_row15_col7,#T_a64d0_row17_col7,#T_a64d0_row19_col7,#T_a64d0_row20_col7{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_a64d0_row0_col6,#T_a64d0_row13_col2{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_a64d0_row0_col7,#T_a64d0_row11_col5{
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#             background-color:  #0f8446;
#             color:  #f1f1f1;
#         }#T_a64d0_row1_col0,#T_a64d0_row19_col1{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_a64d0_row1_col2,#T_a64d0_row2_col4,#T_a64d0_row7_col1,#T_a64d0_row7_col8,#T_a64d0_row10_col4,#T_a64d0_row10_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_a64d0_row1_col3{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_a64d0_row1_col4{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_a64d0_row1_col6{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_a64d0_row1_col8{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_a64d0_row2_col0,#T_a64d0_row13_col1{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_a64d0_row2_col1,#T_a64d0_row4_col4,#T_a64d0_row14_col3{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_a64d0_row2_col2,#T_a64d0_row16_col8{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_a64d0_row2_col3,#T_a64d0_row5_col3{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_a64d0_row2_col5{
#             background-color:  #f98e52;
#             color:  #000000;
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_a64d0_row2_col6,#T_a64d0_row8_col1{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_a64d0_row2_col8{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_a64d0_row3_col0,#T_a64d0_row3_col2,#T_a64d0_row4_col0{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_a64d0_row3_col1{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_a64d0_row3_col3,#T_a64d0_row12_col0{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_a64d0_row3_col4,#T_a64d0_row5_col2,#T_a64d0_row8_col0,#T_a64d0_row13_col6{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_a64d0_row3_col5{
#             background-color:  #cc2627;
#             color:  #f1f1f1;
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_a64d0_row3_col6{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_a64d0_row3_col8,#T_a64d0_row6_col4,#T_a64d0_row12_col8{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_a64d0_row4_col1{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_a64d0_row4_col2{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_a64d0_row4_col3,#T_a64d0_row18_col8{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_a64d0_row4_col6{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_a64d0_row4_col8,#T_a64d0_row9_col1{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_a64d0_row5_col0,#T_a64d0_row11_col1{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_a64d0_row5_col1{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_a64d0_row5_col4{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_a64d0_row5_col5{
#             background-color:  #e54e35;
#             color:  #000000;
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_a64d0_row5_col6,#T_a64d0_row9_col6{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_a64d0_row5_col7{
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_a64d0_row5_col8,#T_a64d0_row6_col6{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_a64d0_row6_col0,#T_a64d0_row8_col2,#T_a64d0_row18_col6{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_a64d0_row6_col1{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_a64d0_row6_col2,#T_a64d0_row17_col1{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_a64d0_row6_col3,#T_a64d0_row20_col3{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_a64d0_row6_col5{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_a64d0_row6_col7{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             background-color:  #199750;
#             color:  #000000;
#         }#T_a64d0_row6_col8{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_a64d0_row7_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_a64d0_row7_col2,#T_a64d0_row8_col4{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_a64d0_row7_col3,#T_a64d0_row14_col0{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_a64d0_row7_col4,#T_a64d0_row7_col6{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_a64d0_row7_col5{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_a64d0_row8_col3,#T_a64d0_row11_col4,#T_a64d0_row20_col6{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_a64d0_row8_col5{
#             background-color:  #fdb365;
#             color:  #000000;
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_a64d0_row8_col6,#T_a64d0_row19_col4{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_a64d0_row8_col8{
#             background-color:  #fed481;
#             color:  #000000;
#         }#T_a64d0_row9_col0{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_a64d0_row9_col2,#T_a64d0_row10_col3{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_a64d0_row9_col3{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_a64d0_row9_col4,#T_a64d0_row17_col4{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_a64d0_row9_col8{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_a64d0_row10_col0,#T_a64d0_row11_col0{
#             background-color:  #addc6f;
#             color:  #000000;

# %%
for player in pies.rotation:
    total_stars = get_total_stars(player)[player.id]
    valid_total_stars = {k: v for k, v in all_total_stars.items() if total_stars-2 < v < total_stars+2}
    player_matches = [x for x in all_active if x.id in valid_total_stars.keys()]
    player_matches.sort(key=lambda x: x.pitching_rating, reverse=True)
    display(Markdown(f"####{player.name}"))
    display(get_stars([player] + player_matches[0:20], include_team=True))
    display(set_heatmap(get_pitching_stlats([player] + player_matches[0:20]), maxVal=1.5))
# Out:
# ####Tiana Takahashi
#                                 Combined  Batting  Pitching  Baserunning  \
#                    Team
# Tiana Takahashi    Pies             16.6      2.7       5.3          4.0
# Montgomery Bullock Crabs            14.8      1.6       6.7          2.4
# Sigmund Castillo   Sunbeams         16.2      3.3       6.4          4.8
# Cell Barajas       Wild Wings       17.1      3.9       6.2          3.3
# Juice Collins      Fridays          16.5      2.8       6.2          4.1
# Howell Rocha       Dale             18.1      4.1       6.0          4.0
# Silvia Rugrat      Wild Wings       15.3      3.7       6.0          2.4
# Sam Scandal        Steaks           17.8      4.9       5.9          4.2
# Mindy Kugel        Mechanics        18.3      5.0       5.7          4.0
# Patty Fox          Millennials      15.1      4.6       5.7          1.6
# Mindy Salad        Lovers           16.4      3.0       5.6          2.9
# Yummy Elliott      Tacos            17.8      4.0       5.6          3.9
# Sandford Garner    Lovers           17.0      4.4       5.5          3.7
# Xandra Pancakes    Worms            18.0      3.2       5.5          4.4
# Penelope Mathews   Garages          17.3      3.1       5.4          4.5
# Zoey Kirchner      Mechanics        15.0      3.2       5.2          4.0
# Lorcan Smaht       Crabs            15.3      3.3       5.2          3.2
# Jacob Winner       Fridays          16.5      3.4       5.1          4.6
# Yurts Buttercup    Georgias         18.3      4.8       5.0          4.0
# Eizabeth Elliott   Magic            16.2      3.2       5.0          5.0
# ------- -------    Georgias         17.8      4.7       5.0          3.5
#
#                                 Defense
#                    Team
# Tiana Takahashi    Pies             4.6
# Montgomery Bullock Crabs            4.0
# Sigmund Castillo   Sunbeams         1.6
# Cell Barajas       Wild Wings       3.6
# Juice Collins      Fridays          3.4
# Howell Rocha       Dale             3.9
# Silvia Rugrat      Wild Wings       3.1
# Sam Scandal        Steaks           2.8
# Mindy Kugel        Mechanics        3.5
# Patty Fox          Millennials      3.2
# Mindy Salad        Lovers           4.9
# Yummy Elliott      Tacos            4.3
# Sandford Garner    Lovers           3.4
# Xandra Pancakes    Worms            4.9
# Penelope Mathews   Garages          4.2
# Zoey Kirchner      Mechanics        2.6
# Lorcan Smaht       Crabs            3.5
# Jacob Winner       Fridays          3.3
# Yurts Buttercup    Georgias         4.4
# Eizabeth Elliott   Magic            3.0
# ------- -------    Georgias         4.6
# <style  type="text/css" >
# #T_48225_row0_col0,#T_48225_row8_col1{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_48225_row0_col1,#T_48225_row9_col0{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_48225_row0_col2{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_48225_row0_col3,#T_48225_row7_col0,#T_48225_row7_col4,#T_48225_row16_col6{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_48225_row0_col4{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_48225_row0_col5,#T_48225_row10_col5,#T_48225_row16_col2{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_48225_row0_col6,#T_48225_row6_col0{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_48225_row1_col0,#T_48225_row10_col2,#T_48225_row14_col4{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_48225_row1_col1,#T_48225_row1_col5,#T_48225_row12_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_48225_row1_col2{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_48225_row1_col3,#T_48225_row17_col2{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_48225_row1_col4,#T_48225_row5_col6{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_48225_row1_col6,#T_48225_row6_col4{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_48225_row2_col0,#T_48225_row11_col3{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_48225_row2_col1,#T_48225_row9_col1{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_48225_row2_col2{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_48225_row2_col3{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_48225_row2_col4{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_48225_row2_col5{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_48225_row2_col6,#T_48225_row10_col3,#T_48225_row13_col0,#T_48225_row14_col2{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_48225_row3_col0{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_48225_row3_col1,#T_48225_row4_col0,#T_48225_row8_col2{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_48225_row3_col2,#T_48225_row11_col2{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_48225_row3_col3,#T_48225_row5_col4,#T_48225_row10_col0,#T_48225_row13_col2,#T_48225_row15_col2,#T_48225_row20_col5{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_48225_row3_col4,#T_48225_row15_col0,#T_48225_row16_col0{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_48225_row3_col5{
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }#T_48225_row3_col6,#T_48225_row10_col6{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_48225_row4_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_48225_row4_col2{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_48225_row4_col3{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_48225_row4_col4{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_48225_row4_col5{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_48225_row4_col6{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_48225_row5_col0,#T_48225_row14_col3{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_48225_row5_col1{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_48225_row5_col2{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_48225_row5_col3,#T_48225_row15_col5{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_48225_row5_col5{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_48225_row6_col1{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_48225_row6_col2{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_48225_row6_col3{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_48225_row6_col5,#T_48225_row19_col1{
#             background-color:  #16914d;
#             color:  #000000;
#         }#T_48225_row6_col6{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_48225_row7_col1,#T_48225_row19_col3{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_48225_row7_col2{
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_48225_row7_col3,#T_48225_row12_col2{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_48225_row7_col5{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_48225_row7_col6,#T_48225_row8_col3,#T_48225_row17_col0{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_48225_row8_col0{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_48225_row8_col4,#T_48225_row20_col4{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_48225_row8_col5,#T_48225_row20_col6{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_48225_row8_col6{
#             background-color:  #fdb163;
#             color:  #000000;
#         }#T_48225_row9_col2,#T_48225_row18_col2{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_48225_row9_col3{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_48225_row9_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_48225_row9_col5{
#             background-color:  #fede89;
#             color:  #000000;
#         }#T_48225_row9_col6,#T_48225_row18_col3{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_48225_row10_col1{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_48225_row10_col4,#T_48225_row19_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_48225_row11_col0{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_48225_row11_col1,#T_48225_row13_col4,#T_48225_row20_col1{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_48225_row11_col4,#T_48225_row16_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_48225_row11_col5,#T_48225_row12_col0{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_48225_row11_col6,#T_48225_row14_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_48225_row12_col1{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_48225_row12_col4,#T_48225_row16_col1{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_48225_row12_col5{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_48225_row12_col6{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_48225_row13_col1,#T_48225_row20_col3{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_48225_row13_col3,#T_48225_row16_col4{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_48225_row13_col5{
#             background-color:  #fed07e;
#             color:  #000000;
# ####Beans McBlase
#                                 Combined  Batting  Pitching  Baserunning  \
#                  Team
# Beans McBlase    Pies               17.0      4.4       4.1          2.8
# Sigmund Castillo Sunbeams           16.2      3.3       6.4          4.8
# Cell Barajas     Wild Wings         17.1      3.9       6.2          3.3
# Juice Collins    Fridays            16.5      2.8       6.2          4.1
# Greer Lott       Moist Talkers      19.0      3.9       6.2          3.9
# Howell Rocha     Dale               18.1      4.1       6.0          4.0
# Silvia Rugrat    Wild Wings         15.3      3.7       6.0          2.4
# Sam Scandal      Steaks             17.8      4.9       5.9          4.2
# Mindy Kugel      Mechanics          18.3      5.0       5.7          4.0
# Patty Fox        Millennials        15.1      4.6       5.7          1.6
# Mindy Salad      Lovers             16.4      3.0       5.6          2.9
# Yummy Elliott    Tacos              17.8      4.0       5.6          3.9
# Sandford Garner  Lovers             17.0      4.4       5.5          3.7
# Xandra Pancakes  Worms              18.0      3.2       5.5          4.4
# Penelope Mathews Garages            17.3      3.1       5.4          4.5
# Arturo Huerta    Garages            18.9      4.2       5.3          5.5
# Lorcan Smaht     Crabs              15.3      3.3       5.2          3.2
# Jacob Winner     Fridays            16.5      3.4       5.1          4.6
# Geraldine Frost  Georgias           18.7      4.5       5.1          3.8
# Yurts Buttercup  Georgias           18.3      4.8       5.0          4.0
# Eizabeth Elliott Magic              16.2      3.2       5.0          5.0
#
#                                 Defense
#                  Team
# Beans McBlase    Pies               5.7
# Sigmund Castillo Sunbeams           1.6
# Cell Barajas     Wild Wings         3.6
# Juice Collins    Fridays            3.4
# Greer Lott       Moist Talkers      5.0
# Howell Rocha     Dale               3.9
# Silvia Rugrat    Wild Wings         3.1
# Sam Scandal      Steaks             2.8
# Mindy Kugel      Mechanics          3.5
# Patty Fox        Millennials        3.2
# Mindy Salad      Lovers             4.9
# Yummy Elliott    Tacos              4.3
# Sandford Garner  Lovers             3.4
# Xandra Pancakes  Worms              4.9
# Penelope Mathews Garages            4.2
# Arturo Huerta    Garages            3.9
# Lorcan Smaht     Crabs              3.5
# Jacob Winner     Fridays            3.3
# Geraldine Frost  Georgias           5.4
# Yurts Buttercup  Georgias           4.4
# Eizabeth Elliott Magic              3.0
# <style  type="text/css" >
# #T_7b63e_row0_col0,#T_7b63e_row10_col4,#T_7b63e_row20_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_7b63e_row0_col1{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_7b63e_row0_col2,#T_7b63e_row5_col6{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_7b63e_row0_col3,#T_7b63e_row12_col1{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_7b63e_row0_col4{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_7b63e_row0_col5{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_7b63e_row0_col6{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_7b63e_row1_col0,#T_7b63e_row11_col3{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_7b63e_row1_col1,#T_7b63e_row9_col1{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_7b63e_row1_col2{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_7b63e_row1_col3{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_7b63e_row1_col4{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_7b63e_row1_col5{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_7b63e_row1_col6,#T_7b63e_row10_col3,#T_7b63e_row13_col0,#T_7b63e_row14_col2{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_7b63e_row2_col0{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_7b63e_row2_col1,#T_7b63e_row3_col0,#T_7b63e_row8_col2{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_7b63e_row2_col2,#T_7b63e_row11_col2{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_7b63e_row2_col3,#T_7b63e_row5_col4,#T_7b63e_row10_col0,#T_7b63e_row13_col2{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_7b63e_row2_col4,#T_7b63e_row16_col0{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_7b63e_row2_col5{
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }#T_7b63e_row2_col6,#T_7b63e_row10_col6{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_7b63e_row3_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_7b63e_row3_col2{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_7b63e_row3_col3{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_7b63e_row3_col4{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_7b63e_row3_col5{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_7b63e_row3_col6{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_7b63e_row4_col0,#T_7b63e_row8_col5{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_7b63e_row4_col1,#T_7b63e_row12_col3,#T_7b63e_row15_col5{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_7b63e_row4_col2,#T_7b63e_row11_col6,#T_7b63e_row14_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_7b63e_row4_col3{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_7b63e_row4_col4{
#             background-color:  #fdbd6d;
#             color:  #000000;
#         }#T_7b63e_row4_col5,#T_7b63e_row11_col5,#T_7b63e_row12_col0{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_7b63e_row4_col6,#T_7b63e_row17_col3{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_7b63e_row5_col0,#T_7b63e_row14_col3{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_7b63e_row5_col1,#T_7b63e_row18_col3{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_7b63e_row5_col2{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_7b63e_row5_col3{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_7b63e_row5_col5{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_7b63e_row6_col0{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_7b63e_row6_col1,#T_7b63e_row15_col3{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_7b63e_row6_col2{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_7b63e_row6_col3{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_7b63e_row6_col4{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_7b63e_row6_col5,#T_7b63e_row20_col1{
#             background-color:  #16914d;
#             color:  #000000;
#         }#T_7b63e_row6_col6{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_7b63e_row7_col0,#T_7b63e_row7_col4,#T_7b63e_row16_col6{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_7b63e_row7_col1,#T_7b63e_row20_col3{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_7b63e_row7_col2,#T_7b63e_row15_col4{
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_7b63e_row7_col3,#T_7b63e_row12_col2{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_7b63e_row7_col5{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_7b63e_row7_col6,#T_7b63e_row8_col3,#T_7b63e_row17_col0{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_7b63e_row8_col0{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_7b63e_row8_col1,#T_7b63e_row15_col0{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_7b63e_row8_col4{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_7b63e_row8_col6{
#             background-color:  #fdb163;
#             color:  #000000;
#         }#T_7b63e_row9_col0{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_7b63e_row9_col2,#T_7b63e_row19_col2{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_7b63e_row9_col3{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_7b63e_row9_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_7b63e_row9_col5{
#             background-color:  #fede89;
#             color:  #000000;
#         }#T_7b63e_row9_col6,#T_7b63e_row19_col3{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_7b63e_row10_col1{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_7b63e_row10_col2,#T_7b63e_row14_col4{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_7b63e_row10_col5,#T_7b63e_row16_col2{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_7b63e_row11_col0{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_7b63e_row11_col1,#T_7b63e_row13_col4{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_7b63e_row11_col4,#T_7b63e_row16_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_7b63e_row12_col4,#T_7b63e_row16_col1{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_7b63e_row12_col5{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_7b63e_row12_col6{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_7b63e_row13_col1{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_7b63e_row13_col3,#T_7b63e_row16_c
# ####Henry Marshallow
#                                  Combined  Batting  Pitching  Baserunning  \
#                    Team
# Henry Marshallow   Pies              15.5      3.8       4.1          2.9
# Montgomery Bullock Crabs             14.8      1.6       6.7          2.4
# Sigmund Castillo   Sunbeams          16.2      3.3       6.4          4.8
# Cell Barajas       Wild Wings        17.1      3.9       6.2          3.3
# Juice Collins      Fridays           16.5      2.8       6.2          4.1
# Silvia Rugrat      Wild Wings        15.3      3.7       6.0          2.4
# Patty Fox          Millennials       15.1      4.6       5.7          1.6
# Mindy Salad        Lovers            16.4      3.0       5.6          2.9
# Sandford Garner    Lovers            17.0      4.4       5.5          3.7
# Inky Rutledge      Lift              13.8      2.2       5.5          3.2
# Penelope Mathews   Garages           17.3      3.1       5.4          4.5
# Zoey Kirchner      Mechanics         15.0      3.2       5.2          4.0
# Lorcan Smaht       Crabs             15.3      3.3       5.2          3.2
# Jacob Winner       Fridays           16.5      3.4       5.1          4.6
# Parker Meng        Worms             14.2      2.3       5.1          3.0
# Eizabeth Elliott   Magic             16.2      3.2       5.0          5.0
# Peanutiel Duffy    Firefighters      17.2      4.8       5.0          3.2
# Elvis Figueroa     Sunbeams          14.1      3.1       5.0          1.8
# Mummy Melcon       Tigers            14.7      3.9       5.0          2.8
# Adalberto Tosser   Crabs             17.1      3.9       4.9          3.9
# King Weatherman    Magic             17.3      3.4       4.9          4.3
#
#                                  Defense
#                    Team
# Henry Marshallow   Pies              4.8
# Montgomery Bullock Crabs             4.0
# Sigmund Castillo   Sunbeams          1.6
# Cell Barajas       Wild Wings        3.6
# Juice Collins      Fridays           3.4
# Silvia Rugrat      Wild Wings        3.1
# Patty Fox          Millennials       3.2
# Mindy Salad        Lovers            4.9
# Sandford Garner    Lovers            3.4
# Inky Rutledge      Lift              2.9
# Penelope Mathews   Garages           4.2
# Zoey Kirchner      Mechanics         2.6
# Lorcan Smaht       Crabs             3.5
# Jacob Winner       Fridays           3.3
# Parker Meng        Worms             3.9
# Eizabeth Elliott   Magic             3.0
# Peanutiel Duffy    Firefighters      4.2
# Elvis Figueroa     Sunbeams          4.3
# Mummy Melcon       Tigers            3.1
# Adalberto Tosser   Crabs             4.3
# King Weatherman    Magic             4.8
# <style  type="text/css" >
# #T_e31ea_row0_col0{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_e31ea_row0_col1{
#             background-color:  #fdc776;
#             color:  #000000;
#         }#T_e31ea_row0_col2,#T_e31ea_row6_col2{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_e31ea_row0_col3{
#             background-color:  #04703b;
#             color:  #f1f1f1;
#         }#T_e31ea_row0_col4,#T_e31ea_row7_col5,#T_e31ea_row12_col2{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_e31ea_row0_col5,#T_e31ea_row8_col2{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_e31ea_row0_col6{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_e31ea_row1_col0,#T_e31ea_row7_col2,#T_e31ea_row10_col4{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_e31ea_row1_col1,#T_e31ea_row1_col5,#T_e31ea_row8_col3,#T_e31ea_row9_col1{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_e31ea_row1_col2,#T_e31ea_row18_col6{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_e31ea_row1_col3,#T_e31ea_row13_col2{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_e31ea_row1_col4{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_e31ea_row1_col6,#T_e31ea_row5_col4{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_e31ea_row2_col0,#T_e31ea_row18_col2{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_e31ea_row2_col1,#T_e31ea_row6_col1{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_e31ea_row2_col2,#T_e31ea_row17_col2{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_e31ea_row2_col3{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_e31ea_row2_col4{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_e31ea_row2_col5{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_e31ea_row2_col6,#T_e31ea_row7_col3,#T_e31ea_row9_col0,#T_e31ea_row10_col2{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_e31ea_row3_col0{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_e31ea_row3_col1,#T_e31ea_row4_col0{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_e31ea_row3_col2{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_e31ea_row3_col3,#T_e31ea_row7_col0,#T_e31ea_row9_col4,#T_e31ea_row11_col2{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_e31ea_row3_col4,#T_e31ea_row11_col0,#T_e31ea_row12_col0{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_e31ea_row3_col5{
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }#T_e31ea_row3_col6,#T_e31ea_row7_col6{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_e31ea_row4_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_e31ea_row4_col2{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_e31ea_row4_col3{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_e31ea_row4_col4,#T_e31ea_row20_col1{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_e31ea_row4_col5{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_e31ea_row4_col6{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_e31ea_row5_col0{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_e31ea_row5_col1{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_e31ea_row5_col2{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_e31ea_row5_col3{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_e31ea_row5_col5,#T_e31ea_row15_col1{
#             background-color:  #16914d;
#             color:  #000000;
#         }#T_e31ea_row5_col6{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_e31ea_row6_col0{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_e31ea_row6_col3{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_e31ea_row6_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_e31ea_row6_col5{
#             background-color:  #fede89;
#             color:  #000000;
#         }#T_e31ea_row6_col6{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_e31ea_row7_col1,#T_e31ea_row18_col0{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_e31ea_row7_col4,#T_e31ea_row15_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_e31ea_row8_col0{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_e31ea_row8_col1{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_e31ea_row8_col4,#T_e31ea_row12_col1{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_e31ea_row8_col5{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_e31ea_row8_col6{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_e31ea_row9_col2{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_e31ea_row9_col3,#T_e31ea_row16_col5{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_e31ea_row9_col5{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_e31ea_row9_col6,#T_e31ea_row10_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_e31ea_row10_col1,#T_e31ea_row13_col6,#T_e31ea_row14_col4,#T_e31ea_row20_col0{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_e31ea_row10_col3{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_e31ea_row10_col5{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_e31ea_row10_col6{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_e31ea_row11_col1{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_e31ea_row11_col3,#T_e31ea_row14_col6{
#             background-color:  #daf08d;
#             color:  #000000;
#         }#T_e31ea_row11_col4,#T_e31ea_row12_col3,#T_e31ea_row14_col2,#T_e31ea_row18_col3{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_e31ea_row11_col5{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_e31ea_row11_col6,#T_e31ea_row20_col3{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_e31ea_row12_col4{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_e31ea_row12_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_e31ea_row12_col6{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_e31ea_row13_col0,#T_e31ea_row16_col2{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_e31ea_row13_col1{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_e31ea_row13_col3{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_e31ea_row13_col4{
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_e31ea_row13_col5{
#             background-color:  #fecc7b;
#             color:  #000000;
#         }#T_e31ea_row14_col0,#T_e31ea_row17_col3,#T_e31ea_row20_col4{
#             background-color:  #b3d

# %% [markdown]
# ### Swap
# **Swap two Players on your Team's Roster.**
#
# This allows switching the position of any two players, including from the shadows. See below for swapping various
# players into different positions.
# **Batting**

# %%
best_batting_shadow = sort_shadows(pies, stat="hitting", num=1, order="best")[0]
best_pitching_shadow = sort_shadows(pies, stat="pitching", num=1, order="best")[0]
bhp = best_hitting_pitcher(real_pies)
bph = best_pitching_hitter(real_pies)
worst_batter = sort_lineup(real_pies, num=1)[0]
worst_pitcher = sort_rotation(real_pies, num=1)[0]

display(Markdown(f"Swapping {worst_batter.name} and {best_batting_shadow.name}"))
display(pandas.DataFrame(swap_players(pies, worst_batter, best_batting_shadow)))

display(Markdown(f"Swapping {worst_batter.name} and {bhp.name}"))
display(pandas.DataFrame(swap_players(pies, worst_batter, bhp)))
# Out:
# Swapping Lang Richardson and Haruta Byrd
#                         Pies
# batting_change      +0.2312%
# pitching_change     +0.0000%
# baserunning_change  -3.4897%
# defense_change      -5.6908%
# Swapping Lang Richardson and Beans McBlase
#                          Pies
# batting_change       +2.1666%
# pitching_change     -20.6512%
# baserunning_change   -2.5181%
# defense_change       +4.3520%

# %% [markdown]
# **Pitching**

# %%
display(Markdown(f"Swapping {worst_pitcher.name} and {best_pitching_shadow.name}"))
display(pandas.DataFrame(swap_players(pies, worst_pitcher, best_pitching_shadow)))

display(Markdown(f"Swapping {worst_pitcher.name} and {bph.name}"))
display(pandas.DataFrame(swap_players(pies, worst_pitcher, bph)))
# Out:
# Swapping Henry Marshallow and Lucy Tokkan
#                         Pies
# batting_change      +0.0000%
# pitching_change     -1.1110%
# baserunning_change  +0.0000%
# defense_change      +0.0000%
# Swapping Henry Marshallow and Jaxon Buckley
#                         Pies
# batting_change      -8.3718%
# pitching_change     +2.2523%
# baserunning_change  -2.8354%
# defense_change      +2.3478%

# %% [markdown]
# ### Move
# **Move a Player on your Team to the desired location on your Roster.**
#
# Move would move a player from any location on the team (including Shadows) to another position, increasing the number
# of players in that position. See below for moving various players into different positions.
#
# **Batting**

# %%
display(Markdown(f"Moving {worst_batter.name} to the Shadows"))
display(pandas.DataFrame(move_player(pies, worst_batter, "shadows")))

display(Markdown(f"Moving {best_batting_shadow.name} to the Lineup"))
display(pandas.DataFrame(move_player(pies, best_batting_shadow, "lineup")))

display(Markdown(f"Moving {bhp.name} to the Lineup"))
display(pandas.DataFrame(move_player(pies, bhp, "lineup")))
# Out:
# Moving Lang Richardson to the Shadows
#                         Pies
# batting_change      +4.2339%
# pitching_change     +0.0000%
# baserunning_change  +0.1489%
# defense_change      -0.1026%
# Moving Haruta Byrd to the Lineup
#                         Pies
# batting_change      -3.0875%
# pitching_change     +0.0000%
# baserunning_change  -3.2178%
# defense_change      -4.9787%
# Moving Beans McBlase to the Lineup
#                         Pies
# batting_change      -1.3672%
# pitching_change     +3.8371%
# baserunning_change  -2.3541%
# defense_change      +3.9482%

# %% [markdown]
# **Pitching**

# %%
display(Markdown(f"Moving {worst_pitcher.name} to the Shadows"))
display(pandas.DataFrame(move_player(pies, worst_pitcher, "shadows")))

display(Markdown(f"Moving {best_pitching_shadow.name} to the Rotation"))
display(pandas.DataFrame(move_player(pies, best_pitching_shadow, "rotation")))

display(Markdown(f"Moving {bph.name} to the Rotation"))
display(pandas.DataFrame(move_player(pies, bph, "rotation")))
# Out:
# Moving Henry Marshallow to the Shadows
#                         Pies
# batting_change      +0.0000%
# pitching_change     +4.3931%
# baserunning_change  +0.0000%
# defense_change      +0.0000%
# Moving Lucy Tokkan to the Rotation
#                         Pies
# batting_change      +0.0000%
# pitching_change     -3.0298%
# baserunning_change  +0.0000%
# defense_change      +0.0000%
# Moving Jaxon Buckley to the Rotation
#                         Pies
# batting_change      -6.0784%
# pitching_change     -0.5073%
# baserunning_change  -0.4025%
# defense_change      +0.1907%

# %% [markdown]
# ### Take
# **Take an Item, repair it, and move it to a Player on your Team.**
#
# This would steal an item from another team and give it to a chosen player on our team. The player receiving the item
# will drop a random item if there are no open item slots. See below for a list of all non-base items held by players in
# the league.

# %%
players = Player.load_all()
carried_items = []
for p in players.values():
    team = getattr(p,"_league_team_id", None)
    if team == pies.id or team is None:
        continue
    carried_items.extend([x for x in p.items if len(x.adjustments) > 1])
carried_items.sort(key=lambda x: len(x.adjustments), reverse=True)
get_item_stats(carried_items, include_wielder=True)
# Out:
#                                                Max Durability  \
# Slimy Frosty Cap of Wisdom                                  4
# Frosty Hot Air Ring                                         4
# Sharp Gravity Holey Glove                                   4
# Aluminum Cool Arm Bat                                       4
# Lucky Travelling Shoes of Wisdom                            4
# Aluminum Noise-Cancelling Bat of Stamina                    4
# Greedy Noise-Cancelling Air Socks                           4
# Slimy Hot Skate Helmet                                      4
# Holey Rubber Sunglasses                                     3
# Greedy Metaphorical Bat                                     3
# Smokey Plant-Based Sunglasses of Intelligence               4
# Underhanded Cool Greedy Sunglasses                          4
# Weird Plant-Based Cap                                       3
# Weird Air Cannon                                            3
# Slimy Hot Skate Helmet                                      4
# Frosty Arm Socks of Intelligence                            4
# Cryogenic Frosty Arm Sunglasses                             4
# Slimy Sharp Ring                                            3
# Slimy Blood Quill                                           3
# Cool Holey Shoes                                            3
# Rubber Skate Bat of Strength                                4
# Rubber Hard Bat                                             3
# Frosty Rubber Sunglasses                                    3
# Metaphorical Ring of Charisma                               3
# Hot Rubber Ring                                             3
# Cool Arm Helmet of the Feast                                4
# Rubber Cap of Wisdom                                        3
# Hot Lucky Ring                                              3
# Lucky Air Bat                                               3
# Sharp Glove of Wisdom                                       3
# Lucky Cryogenic Ring                                        3
# Aluminum Metaphorical Cannon                                3
# Lucky Air Bat                                               3
# Hot Bat of Stamina                                          3
# Mesh Cool Leg Jersey                                        4
# Metaphorical Glove of Intelligence                          3
# Passionate Leg Necklace of Dexterity                        4
# Metaphorical Brambly Concrete Cap                           6
# Frosty Rubber Broom                                         3
# Repeating Cool Socks of Charisma                            4
# Gravity Greedy Fire Eating Socks                            4
# Slimy Careful Repeating Glove                               4
# Actual Blood Bat                                            3
# Fire Eating Weird Bat                                       3
# Underhanded Arm Socks of Intelligence                       4
# Cool Necklace of Wisdom                                     3
# Hard Bat of Intelligence                                    3
# Leg Glove of Stamina                                        3
# Arm Sunglasses of Stamina                                   3
# Aluminum Air Socks                                          3
# Chaotic Arm Sunglasses                                      3
# Plant-Based Bat of Charisma                                 3
# Hearty Air Cap                                              3
# Plant-Based Ring of Dexterity                               3
# Air Necklace of Vitality                                    3
# Aluminum Clutch Arm Sunglasses                              4
# Slimy Leg Bat                                               3
# Aluminum Jersey of Dexterity                                3
# Hearty Smooth Arm Shoes                                     4
# Golden Rubber Helmet                                        3
# Passionate Cap of Charisma                                  3
# Slimy Concrete Bat                                          5
# Clutch Wooden Rock Ring                                     5
# Mesh Cap of Vitality                                        3
# Cryogenic Smokey Shoes                                      3
# Noise-Cancelling Ambitious Blood Cap                        4
# Sharp Rock Helmet                                           4
# Sharp Skate Shoes                                           3
# Mesh Jersey of Vitality                                     3
# Charitable Arm Necklace                                     3
# Hearty Leg Ring                                             3
# Chunky Rubber Jersey                                        3
# Actual Glove of the Famine                                  3
# Weird Cap                                                   2
# Underhanded Necklace of Stamina                             3
# Hard Mesh Socks                                             3
# Actual Limestone Ring                                       3
# Clutch Rubber Glove                                         3
# Golden Smooth Blood Necklace                                4
# Greedy Repeating Glove                                      3
# Passionate Wooden Shoes                                     3
# Hard Head Sunglasses                                        3
# Holey Glove of Fourtitude                                   3
# Cool Passionate Jersey                                      3
# Aluminum Glove of the Famine                                3
# Brambly Glove of Vitality                                   3
# Underhanded Holey Shoes                                     3
# Holey Ambitious Socks                                       3
# Limestone Hard Sunglasses                                   3
# Cool Smokey Ring                                            3
# Wooden Necklace of the Feast                                3
# Chaotic Shoes                                               2
# Fireproof Jersey of Intelligence                            3
# Chunky Plant-Based Ring                                     3
# Glove of Stamina                                            2
# Frosty Concrete Bat                                         5
# Holey Cape                                                  2
# Parasitic Hot Jersey                                        3
# Holey Ring                                                  2
# Rubber Necklace                                             2
# Cool Socks of Blaserunning                                  3
# Slimy Cape                                                  2
# Aluminum Rock Helmet                                        4
# Metaphorical Shoes                                          2
# Underhanded Skate Helmet of the Famine                      4
# Skate Shoes of Intelligence                                 3
# Repeating Hot Phone                                         3
# Jersey of Stamina                                           2
# Hot Shoes of Fourtitude                                     3
# Rubber Socks                                                2
# Rubber Cape                                                 2
# Hearty Noise-Cancelling Cap                                 3
# Charitable Repeating Helmet                                 3
# Greedy Jersey                                               2
# Wooden Rock Cap                                             4
# Frosty Fireproof Glove                                      3
# Necklace of Stamina                                         2
# Travelling Frosty Helmet                                    3
# Underhanded Glove of Vitality                               3
# Inflatable Plastic Bat                                      2
# Cool Concrete Necklace                                      5
# Rubber Bat                                                  2
# Squiddish Blood Glove                                       3
# Repeating Air Cap                                           3
# Golden Ring of Intelligence                                 3
# Underhanded Socks of Wisdom                                 3
# Actual Travelling Jersey                                    3
# Metaphorical Ring                                           2
# Leg Necklace of Vanity                                      3
# Parasitic Hearty Shoes                                      3
# Sharp Bat                                                   2
# Sharp Glove                                                 2
# Smokey Rock Shoes of Subtraction                            5
# Mesh Head Jersey                                            3
# Glove of Stamina                                            2
# Fire Eating Air Jersey                                      3
# Arm Cap of Vanity                                           3
# Sharp Bat                                                   2
# Underhanded Rock Socks of Strength                          5
# Rubber Cannon                                               2
# Ring of Stamina                                             2
# Wooden Concrete Ring                                        5
# Hearty Smooth Necklace                                      3
# Parasitic Ring of Intelligence                              3
# Squiddish Jersey of Wisdom                                  3
# Repeating Blood Cap                                         3
# Cap of Stamina                                              2
# Careful Hard Bat                                            3
# Aluminum Concrete Glove                                     5
# Ambitious Cryogenic Cap                                     3
# Smokey Rock Necklace of Blaserunning                        5
# Metaphorical Bat                                            2
# Chaotic Jersey                                              2
# Socks of Intelligence                                       2
# Cool Socks                                                  2
# Hard Ring                                                   2
# Hearty Shoes                                                2
# Cool Cap                                                    2
# Brambly Necklace of Blaserunning                            3
# Ring of Charisma                                            2
# Limestone Ring of Blaserunning                              3
# Air Ring                                                    2
# Passionate Phone of Fourtitude                              3
# Underhanded Brambly Bat                                     3
# Gravity Arm Bat                                             3
# Socks of Intelligence                                       2
# Wooden Sunglasses                                           2
# Smokey Concrete Phone                                       5
# Bat of Wisdom                                               2
# Hard Glove                                                  2
# Underhanded Leg Necklace                                    3
# Hearty Helmet                                               2
# Air Sunglasses                                              2
# Passionate Chunky Cap                                       3
# Careful Limestone Sunglasses                                3
# Chunky Brambly Jersey                                       3
# Plant-Based Cap                                             2
# Aluminum Sunglasses                                         2
# Noise-Cancelling Arm Bat                                    3
# Spirit Socks                                                2
# Necklace of Charisma                                        2
# Frosty Bat                                                  2
# Brambly Sunglasses of Blaserunning                          3
# Cryogenic Socks                                             2
# Cap of Dexterity                                            2
# Cool Phone                                                  2
# Bat of Vitality                                             2
# Travelling Head Helmet                                      3
# Bat of Vitality                                             2
# Charitable Socks                                            2
# Air Glove                                                   2
# Hearty Socks                                                2
# Helmet of Dexterity                                         2
# Parasitic Leg Bat                                           3
# Cool Helmet                                                 2
# Necklace of Vitality                                        2
# Blood Glove                                                 2
# Underhanded Head Ring                                       3
# Frosty Jersey                                               2
# Cool Helmet                                                 2
# Blood Phone                                                 2
# Hard Cap                                                    2
# Hard Ring                                                   2
# Skate Socks of Strength                                     3
# Cryogenic Helmet                                            2
# Air Ring                                                    2
# Underhanded Limestone Sunglasses                            3
# Helmet of Charisma                                          2
# Air Cannon                                                  2
# Cape of Dexterity                                           2
# Bat of Vitality                                             2
# Travelling Rock Shoes of Blaserunning                       5
# Cool Cap                                                    2
# Shoes of Dexterity                                          2
# Coasting Leg Bat                                            3
# Wooden Socks                                                2
# Hearty Sunglasses                                           2
# Aluminum Cap                                                2
# Careful Bat of Strength                                     3
# Head Shoes of Fourtitude                                    3
# Wooden Ring                                                 2
# Blood Cap                                                   2
# Passionate Concrete Cap                                     5
# Hard Sunglasses                                             2
# Leg Sunglasses of Fourtitude                                3
# Plant-Based Socks                                           2
# Phone of Wisdom                                             2
# Aluminum Bat                                                2
# Hot Bat                                                     2
# Underhanded Limestone Ring                                  3
# Passionate Rock Glove                                       4
# Blood Bat                                                   2
# Spirit Sunglasses                                           2
# Jersey of Charisma                                          2
# Hard Ring                                                   2
# Hard Bat                                                    2
# Hot Cap                                                     2
# Underhanded Passionate Helmet                               3
# Bat of Charisma                                             2
# Hot Ring                                                    2
# Plant-Based Necklace                                        2
# Necklace of Wisdom                                          2
# Travelling Head Jersey                                      3
# Clutch Head Sunglasses                                      3
# Mesh Ring                                                   2
# Mesh Bat                                                    2
# Smokey Necklace                                             2
# Cap of Strength                                             2
# Sunglasses of Strength                                      2
# Leg Glove                                                   2
# Underhanded Rock Helmet                                     4
# Shoes of the Famine                                         2
# Quill of Strength                                           2
# Head Cannon                                                 2
# Arm Cap                                                     2
# Necklace of Vanity                                          2
# Head Phone                                                  2
# Arm Socks                                                   2
# Limestone Helmet                                            2
# Leg Sunglasses                                              2
# Clutch Fire Eating Cap                                      3
# Gravity Concrete Ring                                       5
# Mesh Cap                                                    2
# Bat of the Famine                                           2
# Leg Sunglasses                                              2
# Fireproof Rock Bat                                          4
# Golden Repeating Jersey                                     3
# Force Field of Observation                                  3
# Careful Fireproof Necklace                                  3
# Mesh Shoes                                                  2
# Bat of Strength                                             2
# Parasitic Gravity Jersey                                    3
# Underhanded Shoes of Blaserunning                           3
# Parasitic Bat of Blaserunning                               3
# Head Necklace                                               2
# Leg Broom                                                   2
# Smokey Cannon                                               2
# Squiddish Travelling Jersey                                 3
# Travelling Clutch Jersey                                    3
# Head Cap                                                    2
# Clutch Noise-Cancelling Sunglasses                          3
# Shoes of Strength                                           2
# Glove of Vanity                                             2
# Mesh Jersey                                                 2
# Fire Eating Ring of Fourtitude                              3
# Repeating Golden Sunglasses                                 3
# Squiddish Travelling Socks                                  3
# Clutch Cap of Blaserunning                                  3
# Leg Shoes                                                   2
# Leg Quill                                                   2
# Parasitic Shoes                                             2
# Rock Jersey                                                 3
# Repeating Broom                                             2
# Rock Shoes                                                  3
# Gravity Broom                                               2
# Noise-Cancelling Ring                                       2
# Careful Sunglasses                                          2
# Rock Bat                                                    3
# Rock Bat                                                    3
# Cannon of Fourtitude                                        2
# Helmet of Blaserunning                                      2
# Concrete Cannon                                             4
# Gravity Cap                                                 2
# Sunglasses of Blaserunning                                  2
# Travelling Socks                                            2
# Rock Jersey                                                 3
# Spicy Sunglasses                                            2
# Parasitic Socks                                             2
# Noise-Cancelling Necklace                                   2
# Flickering Socks                                            2
# Concrete Necklace                                           4
# Fireproof Shoes                                             2
# Parasitic Ring                                              2
# Smooth Helmet                                               2
# Shoes of Blaserunning                                       2
# Rock Bat                                                    3
# Fireproof Glove                                             2
# Golden Sunglasses                                           2
# Golden Sunglasses                                           2
# Plastic Helmet                                              1
# Chunky Necklace                                             2
# Fireproof Shoes                                             2
# Underhanded Sunglasses                                      2
# Underhanded Cap                                             2
# Skate Board                                                 2
# Squiddish Ring                                              2
# Rock Socks                                                  3
# Skate Shoes                                                 2
# Noise-Cancelling Cap                                        2
# Paper Cap                                                   1
# Skate Helmet                                                2
# Concrete Helmet                                             4
# Careful Shoes                                               2
# Rock Ring                                                   3
# Rock Bat                                                    3
# Ambitious Helmet                                            2
# Coasting Jersey                                             2
# Rock Shoes                                                  3
# Glass Cap                                                   1
# Chunky Jersey                                               2
# Gravity Helmet                                              2
# Rock Sunglasses                                             3
# Chunky Cap                                                  2
# Rock Sunglasses                                             3
# Chunky Bat                                                  2
# Golden Bat                                                  2
# Fireproof Ring                                              2
# Rock Sunglasses                                             3
# Chunky Necklace                                             2
# Parasitic Jersey                                            2
# Smooth Ring                                                 2
# Glass Necklace                                              1
# Plastic Bat                                                 1
# Ambitious Socks                                             2
# Chunky Jersey                                               2
# Noise-Cancelling Sunglasses                                 2
# Concrete Cannon                                             4
# Chunky Bat                                                  2
# Spicy Sunglasses                                            2
# Clutch Ring                                                 2
# Repeating Socks                                             2
#
#                                                                  Modifications
# Slimy Frosty Cap of Wisdom                                                  []
# Frosty Hot Air Ring                                                         []
# Sharp Gravity Holey Glove                                            [Gravity]
# Aluminum Cool Arm Bat                                                       []
# Lucky Travelling Shoes of Wisdom                                   [Traveling]
# Aluminum Noise-Cancelling Bat of Stamina                          [Soundproof]
# Greedy Noise-Cancelling Air Socks                                 [Soundproof]
# Slimy Hot Skate Helmet                                            [Pro Skater]
# Holey Rubber Sunglasses                                                     []
# Greedy Metaphorical Bat                                                     []
# Smokey Plant-Based Sunglasses of Intelligence                               []
# Underhanded Cool Greedy Sunglasses                               [Underhanded]
# Weird Plant-Based Cap                                                       []
# Weird Air Cannon                                                            []
# Slimy Hot Skate Helmet                                            [Pro Skater]
# Frosty Arm Socks of Intelligence                                            []
# Cryogenic Frosty Arm Sunglasses                                             []
# Slimy Sharp Ring                                                            []
# Slimy Blood Quill                                                           []
# Cool Holey Shoes                                                            []
# Rubber Skate Bat of Strength                                      [Pro Skater]
# Rubber Hard Bat                                                             []
# Frosty Rubber Sunglasses                                                    []
# Metaphorical Ring of Charisma                                               []
# Hot Rubber Ring                                                             []
# Cool Arm Helmet of the Feast                                                []
# Rubber Cap of Wisdom                                                        []
# Hot Lucky Ring                                                              []
# Lucky Air Bat                                                               []
# Sharp Glove of Wisdom                                                       []
# Lucky Cryogenic Ring                                                        []
# Aluminum Metaphorical Cannon                                                []
# Lucky Air Bat                                                               []
# Hot Bat of Stamina                                                          []
# Mesh Cool Leg Jersey                                                        []
# Metaphorical Glove of Intelligence                                          []
# Passionate Leg Necklace of Dexterity                                        []
# Metaphorical Brambly Concrete Cap                                           []
# Frosty Rubber Broom                                                         []
# Repeating Cool Socks of Charisma                                   [Repeating]
# Gravity Greedy Fire Eating Socks                         [Gravity, Fire Eater]
# Slimy Careful Repeating Glove                             [Careful, Repeating]
# Actual Blood Bat                                                            []
# Fire Eating Weird Bat                                             [Fire Eater]
# Underhanded Arm Socks of Intelligence                            [Underhanded]
# Cool Necklace of Wisdom                                                     []
# Hard Bat of Intelligence                                                    []
# Leg Glove of Stamina                                                        []
# Arm Sunglasses of Stamina                                                   []
# Aluminum Air Socks                                                          []
# Chaotic Arm Sunglasses                                                      []
# Plant-Based Bat of Charisma                                                 []
# Hearty Air Cap                                                              []
# Plant-Based Ring of Dexterity                                               []
# Air Necklace of Vitality                                                    []
# Aluminum Clutch Arm Sunglasses                                 [High Pressure]
# Slimy Leg Bat                                                               []
# Aluminum Jersey of Dexterity                                                []
# Hearty Smooth Arm Shoes                                               [Smooth]
# Golden Rubber Helmet                                              [Super Idol]
# Passionate Cap of Charisma                                                  []
# Slimy Concrete Bat                                                          []
# Clutch Wooden Rock Ring                                        [High Pressure]
# Mesh Cap of Vitality                                                        []
# Cryogenic Smokey Shoes                                                      []
# Noise-Cancelling Ambitious Blood Cap                   [Soundproof, Ambitious]
# Sharp Rock Helmet                                                           []
# Sharp Skate Shoes                                                 [Pro Skater]
# Mesh Jersey of Vitality                                                     []
# Charitable Arm Necklace                                                     []
# Hearty Leg Ring                                                             []
# Chunky Rubber Jersey                                                  [Chunky]
# Actual Glove of the Famine                                                  []
# Weird Cap                                                                   []
# Underhanded Necklace of Stamina                                  [Underhanded]
# Hard Mesh Socks                                                             []
# Actual Limestone Ring                                                       []
# Clutch Rubber Glove                                            [High Pressure]
# Golden Smooth Blood Necklace                              [Super Idol, Smooth]
# Greedy Repeating Glove                                             [Repeating]
# Passionate Wooden Shoes                                                     []
# Hard Head Sunglasses                                                        []
# Holey Glove of Fourtitude                                  [The Fourth Strike]
# Cool Passionate Jersey                                                      []
# Aluminum Glove of the Famine                                                []
# Brambly Glove of Vitality                                                   []
# Underhanded Holey Shoes                                          [Underhanded]
# Holey Ambitious Socks                                              [Ambitious]
# Limestone Hard Sunglasses                                                   []
# Cool Smokey Ring                                                            []
# Wooden Necklace of the Feast                                                []
# Chaotic Shoes                                                               []
# Fireproof Jersey of Intelligence                                   [Fireproof]
# Chunky Plant-Based Ring                                               [Chunky]
# Glove of Stamina                                                            []
# Frosty Concrete Bat                                                         []
# Holey Cape                                                                  []
# Parasitic Hot Jersey                                                [Parasite]
# Holey Ring                                                                  []
# Rubber Necklace                                                             []
# Cool Socks of Blaserunning                                      [Blaserunning]
# Slimy Cape                                                                  []
# Aluminum Rock Helmet                                                        []
# Metaphorical Shoes                                                          []
# Underhanded Skate Helmet of the Famine               [Pro Skater, Underhanded]
# Skate Shoes of Intelligence                                       [Pro Skater]
# Repeating Hot Phone                                                [Repeating]
# Jersey of Stamina                                                           []
# Hot Shoes of Fourtitude                                    [The Fourth Strike]
# Rubber Socks                                                                []
# Rubber Cape                                                                 []
# Hearty Noise-Cancelling Cap                                       [Soundproof]
# Charitable Repeating Helmet                                        [Repeating]
# Greedy Jersey                                                               []
# Wooden Rock Cap                                                             []
# Frosty Fireproof Glove                                             [Fireproof]
# Necklace of Stamina                                                         []
# Travelling Frosty Helmet                                           [Traveling]
# Underhanded Glove of Vitality                                    [Underhanded]
# Inflatable Plastic Bat                                                      []
# Cool Concrete Necklace                                                      []
# Rubber Bat                                                                  []
# Squiddish Blood Glove                                              [Squiddish]
# Repeating Air Cap                                                  [Repeating]
# Golden Ring of Intelligence                                       [Super Idol]
# Underhanded Socks of Wisdom                                      [Underhanded]
# Actual Travelling Jersey                                           [Traveling]
# Metaphorical Ring                                                           []
# Leg Necklace of Vanity                                                      []
# Parasitic Hearty Shoes                                              [Parasite]
# Sharp Bat                                                                   []
# Sharp Glove                                                                 []
# Smokey Rock Shoes of Subtraction                                  [Subtractor]
# Mesh Head Jersey                                                            []
# Glove of Stamina                                                            []
# Fire Eating Air Jersey                                            [Fire Eater]
# Arm Cap of Vanity                                                           []
# Sharp Bat                                                                   []
# Underhanded Rock Socks of Strength                               [Underhanded]
# Rubber Cannon                                                               []
# Ring of Stamina                                                             []
# Wooden Concrete Ring                                                        []
# Hearty Smooth Necklace                                                [Smooth]
# Parasitic Ring of Intelligence                                      [Parasite]
# Squiddish Jersey of Wisdom                                         [Squiddish]
# Repeating Blood Cap                                                [Repeating]
# Cap of Stamina                                                              []
# Careful Hard Bat                                                     [Careful]
# Aluminum Concrete Glove                                                     []
# Ambitious Cryogenic Cap                                            [Ambitious]
# Smokey Rock Necklace of Blaserunning                            [Blaserunning]
# Metaphorical Bat                                                            []
# Chaotic Jersey                                                              []
# Socks of Intelligence                                                       []
# Cool Socks                                                                  []
# Hard Ring                                                                   []
# Hearty Shoes                                                                []
# Cool Cap                                                                    []
# Brambly Necklace of Blaserunning                                [Blaserunning]
# Ring of Charisma                                                            []
# Limestone Ring of Blaserunning                                  [Blaserunning]
# Air Ring                                                                    []
# Passionate Phone of Fourtitude                             [The Fourth Strike]
# Underhanded Brambly Bat                                          [Underhanded]
# Gravity Arm Bat                                                      [Gravity]
# Socks of Intelligence                                                       []
# Wooden Sunglasses                                                           []
# Smokey Concrete Phone                                                       []
# Bat of Wisdom                                                               []
# Hard Glove                                                                  []
# Underhanded Leg Necklace                                         [Underhanded]
# Hearty Helmet                                                               []
# Air Sunglasses                                                              []
# Passionate Chunky Cap                                                 [Chunky]
# Careful Limestone Sunglasses                                         [Careful]
# Chunky Brambly Jersey                                                 [Chunky]
# Plant-Based Cap                                                             []
# Aluminum Sunglasses                                                         []
# Noise-Cancelling Arm Bat                                          [Soundproof]
# Spirit Socks                                                                []
# Necklace of Charisma                                                        []
# Frosty Bat                                                                  []
# Brambly Sunglasses of Blaserunning                              [Blaserunning]
# Cryogenic Socks                                                             []
# Cap of Dexterity                                                            []
# Cool Phone                                                                  []
# Bat of Vitality                                                             []
# Travelling Head Helmet                                             [Traveling]
# Bat of Vitality                                                             []
# Charitable Socks                                                            []
# Air Glove                                                                   []
# Hearty Socks                                                                []
# Helmet of Dexterity                                                         []
# Parasitic Leg Bat                                                   [Parasite]
# Cool Helmet                                                                 []
# Necklace of Vitality                                                        []
# Blood Glove                                                                 []
# Underhanded Head Ring                                            [Underhanded]
# Frosty Jersey                                                               []
# Cool Helmet                                                                 []
# Blood Phone                                                                 []
# Hard Cap                                                                    []
# Hard Ring                                                                   []
# Skate Socks of Strength                                           [Pro Skater]
# Cryogenic Helmet                                                            []
# Air Ring                                                                    []
# Underhanded Limestone Sunglasses                                 [Underhanded]
# Helmet of Charisma                                                          []
# Air Cannon                                                                  []
# Cape of Dexterity                                                           []
# Bat of Vitality                                                             []
# Travelling Rock Shoes of Blaserunning                [Blaserunning, Traveling]
# Cool Cap                                                                    []
# Shoes of Dexterity                                                          []
# Coasting Leg Bat                                                    [Coasting]
# Wooden Socks                                                                []
# Hearty Sunglasses                                                           []
# Aluminum Cap                                                                []
# Careful Bat of Strength                                              [Careful]
# Head Shoes of Fourtitude                                   [The Fourth Strike]
# Wooden Ring                                                                 []
# Blood Cap                                                                   []
# Passionate Concrete Cap                                                     []
# Hard Sunglasses                                                             []
# Leg Sunglasses of Fourtitude                               [The Fourth Strike]
# Plant-Based Socks                                                           []
# Phone of Wisdom                                                             []
# Aluminum Bat                                                                []
# Hot Bat                                                                     []
# Underhanded Limestone Ring                                       [Underhanded]
# Passionate Rock Glove                                                       []
# Blood Bat                                                                   []
# Spirit Sunglasses                                                           []
# Jersey of Charisma                                                          []
# Hard Ring                                                                   []
# Hard Bat                                                                    []
# Hot Cap                                                                     []
# Underhanded Passionate Helmet                                    [Underhanded]
# Bat of Charisma                                                             []
# Hot Ring                                                                    []
# Plant-Based Necklace                                                        []
# Necklace of Wisdom                                                          []
# Travelling Head Jersey                                             [Traveling]
# Clutch Head Sunglasses                                         [High Pressure]
# Mesh Ring                                                                   []
# Mesh Bat                                                                    []
# Smokey Necklace                                                             []
# Cap of Strength                                                             []
# Sunglasses of Strength                                                      []
# Leg Glove                                                                   []
# Underhanded Rock Helmet                                          [Underhanded]
# Shoes of the Famine                                                         []
# Quill of Strength                                                           []
# Head Cannon                                                                 []
# Arm Cap                                                                     []
# Necklace of Vanity                                                          []
# Head Phone                                                                  []
# Arm Socks                                                                   []
# Limestone Helmet                                                            []
# Leg Sunglasses                                                              []
# Clutch Fire Eating Cap                             [High Pressure, Fire Eater]
# Gravity Concrete Ring                                                [Gravity]
# Mesh Cap                                                                    []
# Bat of the Famine                                                           []
# Leg Sunglasses                                                              []
# Fireproof Rock Bat                                                 [Fireproof]
# Golden Repeating Jersey                                [Super Idol, Repeating]
# Force Field of Observation                                   [Force, Observed]
# Careful Fireproof Necklace                                [Careful, Fireproof]
# Mesh Shoes                                                                  []
# Bat of Strength                                                             []
# Parasitic Gravity Jersey                                   [Parasite, Gravity]
# Underhanded Shoes of Blaserunning                  [Blaserunning, Underhanded]
# Parasitic Bat of Blaserunning                         [Blaserunning, Parasite]
# Head Necklace                                                               []
# Leg Broom                                                                   []
# Smokey Cannon                                                               []
# Squiddish Travelling Jersey                             [Squiddish, Traveling]
# Travelling Clutch Jersey                            [Traveling, High Pressure]
# Head Cap                                                                    []
# Clutch Noise-Cancelling Sunglasses                 [High Pressure, Soundproof]
# Shoes of Strength                                                           []
# Glove of Vanity                                                             []
# Mesh Jersey                                                                 []
# Fire Eating Ring of Fourtitude                 [The Fourth Strike, Fire Eater]
# Repeating Golden Sunglasses                            [Repeating, Super Idol]
# Squiddish Travelling Socks                              [Squiddish, Traveling]
# Clutch Cap of Blaserunning                       [Blaserunning, High Pressure]
# Leg Shoes                                                                   []
# Leg Quill                                                                   []
# Parasitic Shoes                                                     [Parasite]
# Rock Jersey                                                                 []
# Repeating Broom                                                    [Repeating]
# Rock Shoes                                                                  []
# Gravity Broom                                                        [Gravity]
# Noise-Cancelling Ring                                             [Soundproof]
# Careful Sunglasses                                                   [Careful]
# Rock Bat                                                                    []
# Rock Bat                                                                    []
# Cannon of Fourtitude                                       [The Fourth Strike]
# Helmet of Blaserunning                                          [Blaserunning]
# Concrete Cannon                                                             []
# Gravity Cap                                                          [Gravity]
# Sunglasses of Blaserunning                                      [Blaserunning]
# Travelling Socks                                                   [Traveling]
# Rock Jersey                                                                 []
# Spicy Sunglasses                                                       [Spicy]
# Parasitic Socks                                                     [Parasite]
# Noise-Cancelling Necklace                                         [Soundproof]
# Flickering Socks                                                  [Flickering]
# Concrete Necklace                                                           []
# Fireproof Shoes                                                    [Fireproof]
# Parasitic Ring                                                      [Parasite]
# Smooth Helmet                                                         [Smooth]
# Shoes of Blaserunning                                           [Blaserunning]
# Rock Bat                                                                    []
# Fireproof Glove                                                    [Fireproof]
# Golden Sunglasses                                                 [Super Idol]
# Golden Sunglasses                                                 [Super Idol]
# Plastic Helmet                                                              []
# Chunky Necklace                                                       [Chunky]
# Fireproof Shoes                                                    [Fireproof]
# Underhanded Sunglasses                                           [Underhanded]
# Underhanded Cap                                                  [Underhanded]
# Skate Board                                                       [Pro Skater]
# Squiddish Ring                                                     [Squiddish]
# Rock Socks                                                                  []
# Skate Shoes                                                       [Pro Skater]
# Noise-Cancelling Cap                                              [Soundproof]
# Paper Cap                                                                   []
# Skate Helmet                                                      [Pro Skater]
# Concrete Helmet                                                             []
# Careful Shoes                                                        [Careful]
# Rock Ring                                                                   []
# Rock Bat                                                                    []
# Ambitious Helmet                                                   [Ambitious]
# Coasting Jersey                                                     [Coasting]
# Rock Shoes                                                                  []
# Glass Cap                                                                   []
# Chunky Jersey                                                         [Chunky]
# Gravity Helmet                                                       [Gravity]
# Rock Sunglasses                                                             []
# Chunky Cap                                                            [Chunky]
# Rock Sunglasses                                                             []
# Chunky Bat                                                            [Chunky]
# Golden Bat                                                        [Super Idol]
# Fireproof Ring                                                     [Fireproof]
# Rock Sunglasses                                                             []
# Chunky Necklace                                                       [Chunky]
# Parasitic Jersey                                                    [Parasite]
# Smooth Ring                                                           [Smooth]
# Glass Necklace                                                              []
# Plastic Bat                                                                 []
# Ambitious Socks                                                    [Ambitious]
# Chunky Jersey                                                         [Chunky]
# Noise-Cancelling Sunglasses                                       [Soundproof]
# Concrete Cannon                                                             []
# Chunky Bat                                                            [Chunky]
# Spicy Sunglasses                                                       [Spicy]
# Clutch Ring                                                    [High Pressure]
# Repeating Socks                                                    [Repeating]

# %% [markdown]
# ### Shadow Infuse
# **Boost a random Stat Category of a Player in your Shadows by 20% to 40%.**
#
# See below for how this would affect various team members at the 2 extreme percentages. This will only affect one player.
#
# #### Batting

# %%
display(Markdown("**20% Change**"))
infuse_batting_table, _, _ = improve_team_batting_table(real_pies, 0.20, shadows=True)
display(infuse_batting_table)
display(set_heatmap(get_batting_stlats(improve_team_batting(real_pies, 0.20, shadows=True)), maxVal=1))
# Out:
# **20% Change**
#                     old_batting_stars  new_batting_stars  \
# Adrian Melon                 2.353291           3.451552
# August Obrien                3.408347           4.488341
# Mcfarland Vargas             1.383943           2.686492
# Twofurious Puddles           2.635533           3.759716
# Mummy Cantburn               1.390958           2.681958
# Doginic Burgertoes           2.079285           3.353370
# Nerd Pacheco                 0.270478           1.359404
# Yusef Puddles                2.390547           3.545751
# Sheev Shriffle               3.352957           4.372160
# Adeline Hammer               1.095992           2.454162
# Castillo Logan               1.858396           3.240490
# Bambi Perez                  1.669795           2.718940
# Jesús Rodriguez              1.632851           2.884388
# Jefferson Delacruz           2.978749           3.944315
# Case Lancaster               0.183966           2.432678
# Haruta Byrd                  3.621954           4.642808
# Javier Lotus                 3.413107           4.421931
# Usurper Violet               3.032900           4.085754
# Lucy Tokkan                  2.319057           3.312185
# Stan Schenn                  1.842408           3.117640
#
#                     change_in_batting_stars
# Adrian Melon                       1.098261
# August Obrien                      1.079995
# Mcfarland Vargas                   1.302549
# Twofurious Puddles                 1.124183
# Mummy Cantburn                     1.291000
# Doginic Burgertoes                 1.274085
# Nerd Pacheco                       1.088926
# Yusef Puddles                      1.155204
# Sheev Shriffle                     1.019204
# Adeline Hammer                     1.358170
# Castillo Logan                     1.382094
# Bambi Perez                        1.049145
# Jesús Rodriguez                    1.251537
# Jefferson Delacruz                 0.965566
# Case Lancaster                     2.248712
# Haruta Byrd                        1.020854
# Javier Lotus                       1.008824
# Usurper Violet                     1.052854
# Lucy Tokkan                        0.993128
# Stan Schenn                        1.275232
# <style  type="text/css" >
# #T_40dd1_row0_col0{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_40dd1_row0_col1{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_40dd1_row0_col2{
#             background-color:  #17934e;
#             color:  #000000;
#         }#T_40dd1_row0_col3,#T_40dd1_row1_col2,#T_40dd1_row1_col3,#T_40dd1_row3_col3,#T_40dd1_row3_col4,#T_40dd1_row4_col3,#T_40dd1_row4_col8,#T_40dd1_row5_col2,#T_40dd1_row5_col4,#T_40dd1_row7_col1,#T_40dd1_row7_col8,#T_40dd1_row8_col1,#T_40dd1_row9_col4,#T_40dd1_row11_col4,#T_40dd1_row12_col8,#T_40dd1_row13_col3,#T_40dd1_row15_col2,#T_40dd1_row15_col3,#T_40dd1_row16_col1,#T_40dd1_row16_col3,#T_40dd1_row16_col4,#T_40dd1_row16_col6,#T_40dd1_row16_col8,#T_40dd1_row17_col1,#T_40dd1_row17_col3,#T_40dd1_row17_col4,#T_40dd1_row18_col6,#T_40dd1_row19_col2,#T_40dd1_row19_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_40dd1_row0_col4{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_40dd1_row0_col5{
#             background-color:  #ca2427;
#             color:  #f1f1f1;
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_40dd1_row0_col6{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_40dd1_row0_col7,#T_40dd1_row1_col7,#T_40dd1_row2_col7,#T_40dd1_row3_col7,#T_40dd1_row4_col7,#T_40dd1_row7_col7,#T_40dd1_row10_col5,#T_40dd1_row10_col7,#T_40dd1_row11_col7,#T_40dd1_row12_col5,#T_40dd1_row12_col7,#T_40dd1_row13_col7,#T_40dd1_row14_col5,#T_40dd1_row14_col7,#T_40dd1_row15_col7,#T_40dd1_row16_col5,#T_40dd1_row16_col7,#T_40dd1_row17_col7,#T_40dd1_row19_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_40dd1_row0_col8{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_40dd1_row1_col0{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_40dd1_row1_col1{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_40dd1_row1_col4{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_40dd1_row1_col5{
#             background-color:  #96d268;
#             color:  #000000;
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_40dd1_row1_col6{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_40dd1_row1_col8,#T_40dd1_row18_col0{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_40dd1_row2_col0,#T_40dd1_row4_col0{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_40dd1_row2_col1{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_40dd1_row2_col2,#T_40dd1_row8_col6{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_40dd1_row2_col3,#T_40dd1_row5_col8,#T_40dd1_row11_col3{
#             background-color:  #fdfebc;
#             color:  #000000;
#         }#T_40dd1_row2_col4,#T_40dd1_row5_col1{
#             background-color:  #fed481;
#             color:  #000000;
#         }#T_40dd1_row2_col5{
#             background-color:  #70c164;
#             color:  #000000;
#             background-color:  #f57748;
#             color:  #000000;
#         }#T_40dd1_row2_col6{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_40dd1_row2_col8,#T_40dd1_row3_col0,#T_40dd1_row8_col8{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_40dd1_row3_col1{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_40dd1_row3_col2,#T_40dd1_row8_col4,#T_40dd1_row13_col1{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_40dd1_row3_col5{
#             background-color:  #d3ec87;
#             color:  #000000;
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_40dd1_row3_col6,#T_40dd1_row10_col4{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_40dd1_row3_col8{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_40dd1_row4_col1{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_40dd1_row4_col2{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_40dd1_row4_col4,#T_40dd1_row11_col8{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_40dd1_row4_col5{
#             background-color:  #9bd469;
#             color:  #000000;
#             background-color:  #fba35c;
#             color:  #000000;
#         }#T_40dd1_row4_col6{
#             background-color:  #f57547;
#             color:  #000000;
#         }#T_40dd1_row5_col0{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_40dd1_row5_col3{
#             background-color:  #fdb163;
#             color:  #000000;
#         }#T_40dd1_row5_col5{
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_40dd1_row5_col6{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_40dd1_row5_col7{
#             background-color:  #e8f59f;
#             color:  #000000;
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_40dd1_row6_col0{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_40dd1_row6_col1{
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_40dd1_row6_col2{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_40dd1_row6_col3{
#             background-color:  #f57748;
#             color:  #000000;
#         }#T_40dd1_row6_col4{
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_40dd1_row6_col5{
#             background-color:  #89cc67;
#             color:  #000000;
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_40dd1_row6_col6{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_40dd1_row6_col7{
#             background-color:  #73c264;
#             color:  #000000;
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_40dd1_row6_col8{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_40dd1_row7_col0{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_40dd1_row7_col2{
#             background-color:  #fee797;
#             color:  #000000;
#         }#T_40dd1_row7_col3{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_40dd1_row7_col4{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_40dd1_row7_col5{
#             background-color:  #fee695;
#             color:  #000000;
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_40dd1_row7_col6{
#             background-color:  #fec877;
#             color:  #000000;
#         }#T_40dd1_row8_col0,#T_40dd1_row13_col8{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_40dd1_row8_col2{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_40dd1_row8_col3,#T_40dd1_row10_col8{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_40dd1_row8_col5{
#             background-color:  #fee08b;
#             color:  #000000;
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_40dd1_row8_col7{
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_40dd1_row9_col0{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_40dd1_row9_col1{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_40dd1_row9_col2{

# %%
display(Markdown("**40% Change**"))
infuse_batting_table, _, _ = improve_team_batting_table(real_pies, 0.40, shadows=True)
display(infuse_batting_table)
display(set_heatmap(get_batting_stlats(improve_team_batting(real_pies, 0.40, shadows=True)), maxVal=1))
# Out:
# **40% Change**
#                     old_batting_stars  new_batting_stars  \
# Adrian Melon                 2.353291           4.418199
# August Obrien                3.408347           5.455504
# Mcfarland Vargas             1.383943           3.743373
# Twofurious Puddles           2.635533           4.728474
# Mummy Cantburn               1.390958           3.735507
# Doginic Burgertoes           2.079285           4.391437
# Nerd Pacheco                 0.270478           2.364572
# Yusef Puddles                2.390547           4.582121
# Sheev Shriffle               3.352957           5.332400
# Adeline Hammer               1.095992           3.521267
# Castillo Logan               1.858396           4.213635
# Bambi Perez                  1.669795           3.701664
# Jesús Rodriguez              1.632851           3.908190
# Jefferson Delacruz           2.978749           4.882007
# Case Lancaster               0.183966           3.550183
# Haruta Byrd                  3.621954           5.596436
# Javier Lotus                 3.413107           5.332747
# Usurper Violet               3.032900           5.069921
# Lucy Tokkan                  2.319057           4.273543
# Stan Schenn                  1.842408           4.182018
#
#                     change_in_batting_stars
# Adrian Melon                       2.064908
# August Obrien                      2.047157
# Mcfarland Vargas                   2.359429
# Twofurious Puddles                 2.092941
# Mummy Cantburn                     2.344550
# Doginic Burgertoes                 2.312151
# Nerd Pacheco                       2.094095
# Yusef Puddles                      2.191574
# Sheev Shriffle                     1.979444
# Adeline Hammer                     2.425275
# Castillo Logan                     2.355239
# Bambi Perez                        2.031870
# Jesús Rodriguez                    2.275339
# Jefferson Delacruz                 1.903258
# Case Lancaster                     3.366217
# Haruta Byrd                        1.974482
# Javier Lotus                       1.919640
# Usurper Violet                     2.037021
# Lucy Tokkan                        1.954486
# Stan Schenn                        2.339609
# <style  type="text/css" >
# #T_3e2ea_row0_col0{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_3e2ea_row0_col1{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_3e2ea_row0_col2,#T_3e2ea_row0_col3,#T_3e2ea_row1_col0,#T_3e2ea_row1_col1,#T_3e2ea_row1_col2,#T_3e2ea_row1_col3,#T_3e2ea_row2_col2,#T_3e2ea_row3_col3,#T_3e2ea_row3_col4,#T_3e2ea_row4_col3,#T_3e2ea_row4_col8,#T_3e2ea_row5_col2,#T_3e2ea_row5_col4,#T_3e2ea_row7_col1,#T_3e2ea_row7_col3,#T_3e2ea_row7_col8,#T_3e2ea_row8_col0,#T_3e2ea_row8_col1,#T_3e2ea_row8_col2,#T_3e2ea_row8_col6,#T_3e2ea_row9_col3,#T_3e2ea_row9_col4,#T_3e2ea_row10_col2,#T_3e2ea_row10_col3,#T_3e2ea_row10_col6,#T_3e2ea_row11_col4,#T_3e2ea_row11_col6,#T_3e2ea_row12_col1,#T_3e2ea_row12_col6,#T_3e2ea_row12_col8,#T_3e2ea_row13_col2,#T_3e2ea_row13_col3,#T_3e2ea_row13_col8,#T_3e2ea_row14_col1,#T_3e2ea_row14_col4,#T_3e2ea_row15_col0,#T_3e2ea_row15_col1,#T_3e2ea_row15_col2,#T_3e2ea_row15_col3,#T_3e2ea_row16_col0,#T_3e2ea_row16_col1,#T_3e2ea_row16_col3,#T_3e2ea_row16_col4,#T_3e2ea_row16_col6,#T_3e2ea_row16_col8,#T_3e2ea_row17_col0,#T_3e2ea_row17_col1,#T_3e2ea_row17_col3,#T_3e2ea_row17_col4,#T_3e2ea_row18_col3,#T_3e2ea_row18_col4,#T_3e2ea_row18_col6,#T_3e2ea_row19_col2,#T_3e2ea_row19_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_3e2ea_row0_col4{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_3e2ea_row0_col5,#T_3e2ea_row0_col7,#T_3e2ea_row1_col7,#T_3e2ea_row2_col7,#T_3e2ea_row3_col7,#T_3e2ea_row4_col7,#T_3e2ea_row5_col5,#T_3e2ea_row7_col7,#T_3e2ea_row8_col7,#T_3e2ea_row10_col5,#T_3e2ea_row10_col7,#T_3e2ea_row11_col7,#T_3e2ea_row12_col5,#T_3e2ea_row12_col7,#T_3e2ea_row13_col7,#T_3e2ea_row14_col5,#T_3e2ea_row14_col7,#T_3e2ea_row15_col7,#T_3e2ea_row16_col5,#T_3e2ea_row16_col7,#T_3e2ea_row17_col7,#T_3e2ea_row18_col7,#T_3e2ea_row19_col7{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_3e2ea_row0_col6{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_3e2ea_row0_col8{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_3e2ea_row1_col4{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }#T_3e2ea_row1_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_3e2ea_row1_col6,#T_3e2ea_row8_col8{
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_3e2ea_row1_col8{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_3e2ea_row2_col0,#T_3e2ea_row4_col0{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_3e2ea_row2_col1{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_3e2ea_row2_col3,#T_3e2ea_row14_col0{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_3e2ea_row2_col4,#T_3e2ea_row5_col1{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_3e2ea_row2_col5{
#             background-color:  #dff293;
#             color:  #000000;
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_3e2ea_row2_col6{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_3e2ea_row2_col8{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_3e2ea_row3_col0{
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_3e2ea_row3_col1,#T_3e2ea_row4_col2{
#             background-color:  #05713c;
#             color:  #f1f1f1;
#         }#T_3e2ea_row3_col2,#T_3e2ea_row8_col4,#T_3e2ea_row13_col1{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_3e2ea_row3_col5{
#             background-color:  #fee491;
#             color:  #000000;
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_3e2ea_row3_col6,#T_3e2ea_row10_col4{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_3e2ea_row3_col8{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_3e2ea_row4_col1{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_3e2ea_row4_col4{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_3e2ea_row4_col5{
#             background-color:  #f8fcb6;
#             color:  #000000;
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_3e2ea_row4_col6{
#             background-color:  #fee491;
#             color:  #000000;
#         }#T_3e2ea_row5_col0{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_3e2ea_row5_col3{
#             background-color:  #fdfebc;
#             color:  #000000;
#         }#T_3e2ea_row5_col6{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_3e2ea_row5_col7{
#             background-color:  #fecc7b;
#             color:  #000000;
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_3e2ea_row5_col8,#T_3e2ea_row9_col0,#T_3e2ea_row11_col3{
#             background-color:  #a2d76a;
#             color:  #000000;
#         }#T_3e2ea_row6_col0,#T_3e2ea_row14_col3{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_3e2ea_row6_col1,#T_3e2ea_row9_col1{
#             background-color:  #feeda1;
#             color:  #000000;
#         }#T_3e2ea_row6_col2{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_3e2ea_row6_col3{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_3e2ea_row6_col4{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_3e2ea_row6_col5{
#             background-color:  #eef8a8;
#             color:  #000000;
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_3e2ea_row6_col6{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_3e2ea_row6_col7{
#             background-color:  #e0f295;
#             color:  #000000;
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_3e2ea_row6_col8{
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_3e2ea_row7_col0{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_3e2ea_row7_col2,#T_3e2ea_row8_col3,#T_3e2ea_row10_col8{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_3e2ea_row7_col4{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_3e2ea_row7_col5{
#             background-color:  #f67a49;
#             color:  #000000;
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_3e2ea_row7_col6{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_3e2ea_row8_col5{
#             background-color:  #f46d43;
#             color:  #000000;
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_3e2ea_row9_col2{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_3e2ea_row9_col5{
#             background-color:  #fdbb6c;
#             color:  #000000;
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_3e2ea_row9_col6,#T_3e2ea_row12_col0{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_3e2ea_row9_col7{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#             background-color:  #118848;
#             color:  #000000;
#         }#T_3e2ea_row9_col8{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_3e2ea_row10_col0{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_3e2ea_row10_col1{
#             background-color:  #a7d96b;
#             color:  #000000;

# %% [markdown]
# #### Pitching

# %%
display(Markdown("**20% Change**"))
infuse_pitching_table, _, _ = improve_team_pitching_table(real_pies, 0.20, shadows=True)
display(infuse_pitching_table)
display(set_heatmap(get_pitching_stlats(improve_team_pitching(real_pies, 0.20, shadows=True)), maxVal=1))
# Out:
# **20% Change**
#                     old_pitching_stars  new_pitching_stars  \
# Adrian Melon                  0.939306            2.326798
# August Obrien                 1.045544            2.111234
# Mcfarland Vargas              1.501794            2.676728
# Twofurious Puddles            3.474609            4.620631
# Mummy Cantburn                2.326166            3.450122
# Doginic Burgertoes            1.808231            2.965528
# Nerd Pacheco                  0.334608            1.236132
# Yusef Puddles                 2.508852            3.633514
# Sheev Shriffle                1.942316            3.092375
# Adeline Hammer                0.915392            2.391269
# Castillo Logan                3.022344            4.346669
# Bambi Perez                   0.340030            1.601739
# Jesús Rodriguez               1.281753            2.392194
# Jefferson Delacruz            0.583451            1.708735
# Case Lancaster                3.291826            4.555580
# Haruta Byrd                   2.728771            3.927099
# Javier Lotus                  0.765838            1.813149
# Usurper Violet                3.399637            4.624407
# Lucy Tokkan                   3.896021            5.155549
# Stan Schenn                   0.905803            2.060879
#
#                     change_in_pitching_stars
# Adrian Melon                        1.387492
# August Obrien                       1.065690
# Mcfarland Vargas                    1.174935
# Twofurious Puddles                  1.146021
# Mummy Cantburn                      1.123956
# Doginic Burgertoes                  1.157297
# Nerd Pacheco                        0.901524
# Yusef Puddles                       1.124663
# Sheev Shriffle                      1.150060
# Adeline Hammer                      1.475877
# Castillo Logan                      1.324325
# Bambi Perez                         1.261709
# Jesús Rodriguez                     1.110441
# Jefferson Delacruz                  1.125284
# Case Lancaster                      1.263754
# Haruta Byrd                         1.198328
# Javier Lotus                        1.047310
# Usurper Violet                      1.224770
# Lucy Tokkan                         1.259527
# Stan Schenn                         1.155077
# <style  type="text/css" >
# #T_bada8_row0_col0{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_bada8_row0_col1,#T_bada8_row12_col1{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_bada8_row0_col2,#T_bada8_row1_col3,#T_bada8_row2_col2,#T_bada8_row2_col5,#T_bada8_row3_col1,#T_bada8_row3_col3,#T_bada8_row4_col6,#T_bada8_row5_col3,#T_bada8_row7_col3,#T_bada8_row7_col5,#T_bada8_row8_col2,#T_bada8_row8_col5,#T_bada8_row9_col6,#T_bada8_row10_col1,#T_bada8_row10_col4,#T_bada8_row12_col6,#T_bada8_row14_col1,#T_bada8_row14_col2,#T_bada8_row14_col4,#T_bada8_row14_col5,#T_bada8_row16_col4,#T_bada8_row17_col1,#T_bada8_row17_col3,#T_bada8_row17_col6,#T_bada8_row18_col0,#T_bada8_row18_col1,#T_bada8_row18_col2,#T_bada8_row18_col4,#T_bada8_row19_col3,#T_bada8_row19_col5{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_bada8_row0_col3,#T_bada8_row5_col6{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_bada8_row0_col4,#T_bada8_row10_col5{
#             background-color:  #fca85e;
#             color:  #000000;
#         }#T_bada8_row0_col5,#T_bada8_row15_col0{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_bada8_row0_col6,#T_bada8_row3_col6{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_bada8_row1_col0{
#             background-color:  #fee797;
#             color:  #000000;
#         }#T_bada8_row1_col1{
#             background-color:  #feeb9d;
#             color:  #000000;
#         }#T_bada8_row1_col2,#T_bada8_row8_col1{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_bada8_row1_col4,#T_bada8_row1_col5,#T_bada8_row13_col6{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_bada8_row1_col6{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_bada8_row2_col0{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_bada8_row2_col1,#T_bada8_row14_col3,#T_bada8_row15_col3{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_bada8_row2_col3,#T_bada8_row12_col3,#T_bada8_row19_col1{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_bada8_row2_col4,#T_bada8_row2_col6{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_bada8_row3_col0,#T_bada8_row17_col0{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_bada8_row3_col2{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_bada8_row3_col4{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_bada8_row3_col5{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_bada8_row4_col0,#T_bada8_row16_col5{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_bada8_row4_col1,#T_bada8_row16_col6,#T_bada8_row17_col2{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_bada8_row4_col2,#T_bada8_row5_col1{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_bada8_row4_col3{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_bada8_row4_col4{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_bada8_row4_col5{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_bada8_row5_col0,#T_bada8_row12_col5{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_bada8_row5_col2,#T_bada8_row17_col4{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_bada8_row5_col4{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_bada8_row5_col5,#T_bada8_row9_col5{
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_bada8_row6_col0{
#             background-color:  #f88c51;
#             color:  #000000;
#         }#T_bada8_row6_col1{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_bada8_row6_col2{
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }#T_bada8_row6_col3,#T_bada8_row6_col4{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_bada8_row6_col5{
#             background-color:  #f67c4a;
#             color:  #000000;
#         }#T_bada8_row6_col6,#T_bada8_row9_col2{
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_bada8_row7_col0{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_bada8_row7_col1,#T_bada8_row19_col6{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_bada8_row7_col2,#T_bada8_row11_col2{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_bada8_row7_col4{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_bada8_row7_col6{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_bada8_row8_col0{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_bada8_row8_col3{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_bada8_row8_col4{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_bada8_row8_col6{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_bada8_row9_col0,#T_bada8_row12_col0{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_bada8_row9_col1{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_bada8_row9_col3{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_bada8_row9_col4{
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_bada8_row10_col0{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_bada8_row10_col2,#T_bada8_row12_col2{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_bada8_row10_col3{
#             background-color:  #fece7c;
#             color:  #000000;
#         }#T_bada8_row10_col6{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_bada8_row11_col0{
#             background-color:  #fdb96a;
#             color:  #000000;
#         }#T_bada8_row11_col1{
#             background-color:  #f57748;
#             color:  #000000;
#         }#T_bada8_row11_col3{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_bada8_row11_col4{
#             background-color:  #fdc776;
#             color:  #000000;
#         }#T_bada8_row11_col5{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_bada8_row11_col6{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_bada8_row12_col4,#T_bada8_row13_col2{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_bada8_row13_col0{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_bada8_row13_col1{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_bada8_row13_col3{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_bada8_row13_col4{
#             background-color:  #f47044;
#             color:  #000000;
#         }#T_bada8_row13_col5,#T_bada8_row15_col2{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_bada8_row14_col0{
#             background-color:  #16914d;
#             color:  #000000;
#         }#T_bada8_row14_col6,#T_bada8_row19_col2{
#             background-color:  #fba35c;
#             color:  #000000;
#         }#T_bada8_row15_col1{
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_bada8_row15_col4{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_bada8_row15_col5{

# %%
display(Markdown("**40% Change**"))
infuse_pitching_table, _, _ = improve_team_pitching_table(real_pies, 0.40, shadows=True)
display(infuse_pitching_table)
display(set_heatmap(get_pitching_stlats(improve_team_pitching(real_pies, 0.40, shadows=True)), maxVal=1))
# Out:
# **40% Change**
#                     old_pitching_stars  new_pitching_stars  \
# Adrian Melon                  0.939306            3.556168
# August Obrien                 1.045544            3.219652
# Mcfarland Vargas              1.501794            3.857349
# Twofurious Puddles            3.474609            5.807659
# Mummy Cantburn                2.326166            4.608101
# Doginic Burgertoes            1.808231            4.136959
# Nerd Pacheco                  0.334608            2.240878
# Yusef Puddles                 2.508852            4.799377
# Sheev Shriffle                1.942316            4.265267
# Adeline Hammer                0.915392            3.646409
# Castillo Logan                3.022344            5.610596
# Bambi Perez                   0.340030            2.726327
# Jesús Rodriguez               1.281753            3.530284
# Jefferson Delacruz            0.583451            2.774392
# Case Lancaster                3.291826            5.797771
# Haruta Byrd                   2.728771            5.127135
# Javier Lotus                  0.765838            2.901574
# Usurper Violet                3.399637            5.853598
# Lucy Tokkan                   3.896021            6.411677
# Stan Schenn                   0.905803            3.201042
#
#                     change_in_pitching_stars
# Adrian Melon                        2.616863
# August Obrien                       2.174108
# Mcfarland Vargas                    2.355555
# Twofurious Puddles                  2.333050
# Mummy Cantburn                      2.281935
# Doginic Burgertoes                  2.328728
# Nerd Pacheco                        1.906270
# Yusef Puddles                       2.290526
# Sheev Shriffle                      2.322952
# Adeline Hammer                      2.731017
# Castillo Logan                      2.588252
# Bambi Perez                         2.386297
# Jesús Rodriguez                     2.248531
# Jefferson Delacruz                  2.190941
# Case Lancaster                      2.505946
# Haruta Byrd                         2.398363
# Javier Lotus                        2.135736
# Usurper Violet                      2.453961
# Lucy Tokkan                         2.515656
# Stan Schenn                         2.295240
# <style  type="text/css" >
# #T_26df9_row0_col0,#T_26df9_row5_col4{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_26df9_row0_col1,#T_26df9_row12_col1,#T_26df9_row14_col3{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_26df9_row0_col2,#T_26df9_row0_col6,#T_26df9_row1_col3,#T_26df9_row2_col2,#T_26df9_row2_col5,#T_26df9_row3_col0,#T_26df9_row3_col1,#T_26df9_row3_col2,#T_26df9_row3_col3,#T_26df9_row3_col4,#T_26df9_row3_col6,#T_26df9_row4_col1,#T_26df9_row4_col6,#T_26df9_row5_col3,#T_26df9_row5_col5,#T_26df9_row7_col3,#T_26df9_row7_col5,#T_26df9_row7_col6,#T_26df9_row8_col2,#T_26df9_row8_col5,#T_26df9_row8_col6,#T_26df9_row9_col1,#T_26df9_row9_col5,#T_26df9_row9_col6,#T_26df9_row10_col0,#T_26df9_row10_col1,#T_26df9_row10_col2,#T_26df9_row10_col4,#T_26df9_row12_col2,#T_26df9_row12_col6,#T_26df9_row13_col5,#T_26df9_row14_col0,#T_26df9_row14_col1,#T_26df9_row14_col2,#T_26df9_row14_col4,#T_26df9_row14_col5,#T_26df9_row15_col0,#T_26df9_row15_col1,#T_26df9_row15_col2,#T_26df9_row15_col4,#T_26df9_row15_col5,#T_26df9_row16_col4,#T_26df9_row16_col6,#T_26df9_row17_col0,#T_26df9_row17_col1,#T_26df9_row17_col2,#T_26df9_row17_col3,#T_26df9_row17_col5,#T_26df9_row17_col6,#T_26df9_row18_col0,#T_26df9_row18_col1,#T_26df9_row18_col2,#T_26df9_row18_col4,#T_26df9_row19_col3,#T_26df9_row19_col5{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_26df9_row0_col3,#T_26df9_row5_col6,#T_26df9_row11_col1{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_26df9_row0_col4{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_26df9_row0_col5{
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_26df9_row1_col0{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_26df9_row1_col1,#T_26df9_row4_col3,#T_26df9_row19_col0{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_26df9_row1_col2,#T_26df9_row8_col1{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_26df9_row1_col4,#T_26df9_row13_col6{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_26df9_row1_col5{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_26df9_row1_col6,#T_26df9_row7_col4{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_26df9_row2_col0{
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_26df9_row2_col1,#T_26df9_row12_col4,#T_26df9_row15_col3{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_26df9_row2_col3,#T_26df9_row12_col3,#T_26df9_row19_col1{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_26df9_row2_col4,#T_26df9_row2_col6,#T_26df9_row18_col6{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_26df9_row3_col5{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_26df9_row4_col0{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_26df9_row4_col2,#T_26df9_row5_col1{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_26df9_row4_col4{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_26df9_row4_col5{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_26df9_row5_col0{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_26df9_row5_col2,#T_26df9_row17_col4{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_26df9_row6_col0{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_26df9_row6_col1{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_26df9_row6_col2{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_26df9_row6_col3,#T_26df9_row6_col4{
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_26df9_row6_col5{
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_26df9_row6_col6,#T_26df9_row9_col2{
#             background-color:  #feeda1;
#             color:  #000000;
#         }#T_26df9_row7_col0{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_26df9_row7_col1{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_26df9_row7_col2,#T_26df9_row11_col2{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_26df9_row8_col0{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_26df9_row8_col3{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_26df9_row8_col4{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_26df9_row9_col0{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_26df9_row9_col3{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_26df9_row9_col4{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_26df9_row10_col3{
#             background-color:  #e5f49b;
#             color:  #000000;
#         }#T_26df9_row10_col5{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_26df9_row10_col6{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_26df9_row11_col0{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_26df9_row11_col3{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_26df9_row11_col4{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_26df9_row11_col5{
#             background-color:  #04703b;
#             color:  #f1f1f1;
#         }#T_26df9_row11_col6{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_26df9_row12_col0,#T_26df9_row18_col3{
#             background-color:  #a2d76a;
#             color:  #000000;
#         }#T_26df9_row12_col5{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_26df9_row13_col0{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_26df9_row13_col1{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_26df9_row13_col2{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_26df9_row13_col3{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_26df9_row13_col4{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_26df9_row14_col6,#T_26df9_row19_col2{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_26df9_row15_col6{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_26df9_row16_col0{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_26df9_row16_col1{
#             background-color:  #fdfebc;
#             color:  #000000;
#         }#T_26df9_row16_col2,#T_26df9_row16_col3{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_26df9_row16_col5{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_26df9_row18_col5{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_26df9_row19_col4{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_26df9_row19_col6{
#             background-color:  #08773f;
#             color:  #f1f1f1;
#         }</style><table id="T_26df9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>

# %% [markdown]
# #### Baserunning

# %%
display(Markdown("**20% Change**"))
infuse_baserunning_table, _, _ = improve_team_baserunning_table(real_pies, 0.20, shadows=True)
display(infuse_baserunning_table)
display(set_heatmap(get_baserunning_stlats(improve_team_baserunning(real_pies, 0.20, shadows=True)), maxVal=1))
# Out:
# **20% Change**
#                     old_baserunning_stars  new_baserunning_stars  \
# Adrian Melon                     3.116697               4.145628
# August Obrien                    3.318856               4.398980
# Mcfarland Vargas                 3.783245               4.734596
# Twofurious Puddles               1.817993               2.913054
# Mummy Cantburn                   2.021513               3.133820
# Doginic Burgertoes               1.779564               3.023082
# Nerd Pacheco                     0.553414               1.681272
# Yusef Puddles                    2.938345               3.927098
# Sheev Shriffle                   2.215166               3.254024
# Adeline Hammer                   2.451014               3.433736
# Castillo Logan                   2.497486               3.464649
# Bambi Perez                      2.296481               3.303108
# Jesús Rodriguez                  2.318777               3.358246
# Jefferson Delacruz               3.539071               4.464019
# Case Lancaster                   2.215962               3.275592
# Haruta Byrd                      2.445376               3.562717
# Javier Lotus                     3.306631               4.248220
# Usurper Violet                   2.098233               3.636153
# Lucy Tokkan                      1.301211               2.492205
# Stan Schenn                      1.988408               3.030304
#
#                     change_in_baserunning_stars
# Adrian Melon                           1.028930
# August Obrien                          1.080124
# Mcfarland Vargas                       0.951351
# Twofurious Puddles                     1.095061
# Mummy Cantburn                         1.112307
# Doginic Burgertoes                     1.243518
# Nerd Pacheco                           1.127858
# Yusef Puddles                          0.988753
# Sheev Shriffle                         1.038858
# Adeline Hammer                         0.982722
# Castillo Logan                         0.967163
# Bambi Perez                            1.006627
# Jesús Rodriguez                        1.039469
# Jefferson Delacruz                     0.924948
# Case Lancaster                         1.059631
# Haruta Byrd                            1.117341
# Javier Lotus                           0.941589
# Usurper Violet                         1.537920
# Lucy Tokkan                            1.190994
# Stan Schenn                            1.041896
# <style  type="text/css" >
# #T_8f746_row0_col0,#T_8f746_row7_col1{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_8f746_row0_col1,#T_8f746_row1_col1,#T_8f746_row2_col1,#T_8f746_row2_col3,#T_8f746_row3_col4,#T_8f746_row3_col5,#T_8f746_row4_col2,#T_8f746_row4_col3,#T_8f746_row5_col5,#T_8f746_row7_col3,#T_8f746_row8_col3,#T_8f746_row8_col4,#T_8f746_row9_col4,#T_8f746_row12_col2,#T_8f746_row13_col4,#T_8f746_row14_col5,#T_8f746_row16_col2,#T_8f746_row17_col1,#T_8f746_row17_col2,#T_8f746_row18_col2,#T_8f746_row19_col4{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_8f746_row0_col2,#T_8f746_row16_col3{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_8f746_row0_col3,#T_8f746_row9_col0,#T_8f746_row18_col4{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_8f746_row0_col4,#T_8f746_row11_col5{
#             background-color:  #fed481;
#             color:  #000000;
#         }#T_8f746_row0_col5,#T_8f746_row2_col5{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_8f746_row1_col0{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_8f746_row1_col2{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_8f746_row1_col3{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_8f746_row1_col4,#T_8f746_row2_col4,#T_8f746_row16_col5{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_8f746_row1_col5{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_8f746_row2_col0{
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_8f746_row2_col2{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_8f746_row3_col0,#T_8f746_row7_col5{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_8f746_row3_col1{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_8f746_row3_col2{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_8f746_row3_col3,#T_8f746_row9_col2{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_8f746_row4_col0{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_8f746_row4_col1,#T_8f746_row19_col3{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_8f746_row4_col4{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_8f746_row4_col5{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_8f746_row5_col0{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_8f746_row5_col1{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_8f746_row5_col2{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_8f746_row5_col3,#T_8f746_row8_col2{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_8f746_row5_col4{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_8f746_row6_col0{
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_8f746_row6_col1{
#             background-color:  #fdb96a;
#             color:  #000000;
#         }#T_8f746_row6_col2,#T_8f746_row17_col4{
#             background-color:  #f67c4a;
#             color:  #000000;
#         }#T_8f746_row6_col3{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_8f746_row6_col4,#T_8f746_row12_col5{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_8f746_row6_col5{
#             background-color:  #f88c51;
#             color:  #000000;
#         }#T_8f746_row7_col0{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_8f746_row7_col2,#T_8f746_row12_col4{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_8f746_row7_col4,#T_8f746_row15_col1{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_8f746_row8_col0,#T_8f746_row9_col5{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_8f746_row8_col1{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_8f746_row8_col5,#T_8f746_row14_col1{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_8f746_row9_col1{
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_8f746_row9_col3{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_8f746_row10_col0{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_8f746_row10_col1,#T_8f746_row14_col0{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_8f746_row10_col2{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_8f746_row10_col3{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_8f746_row10_col4{
#             background-color:  #08773f;
#             color:  #f1f1f1;
#         }#T_8f746_row10_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_8f746_row11_col0{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_8f746_row11_col1,#T_8f746_row19_col0{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_8f746_row11_col2,#T_8f746_row15_col2{
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_8f746_row11_col3,#T_8f746_row14_col2,#T_8f746_row19_col2{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_8f746_row11_col4{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_8f746_row12_col0,#T_8f746_row16_col4{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_8f746_row12_col1{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_8f746_row12_col3{
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_8f746_row13_col0,#T_8f746_row13_col3{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }#T_8f746_row13_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_8f746_row13_col2{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_8f746_row13_col5,#T_8f746_row15_col3{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_8f746_row14_col3,#T_8f746_row19_col5{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_8f746_row14_col4,#T_8f746_row18_col1{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_8f746_row15_col0{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_8f746_row15_col4{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_8f746_row15_col5{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_8f746_row16_col0{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_8f746_row16_col1{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_8f746_row17_col0{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_8f746_row17_col3{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_8f746_row17_col5{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_8f746_row18_col0{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_8f746_row18_col3{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_8f746_row18_col5{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_8f746_row19_col1{
#             background-c

# %%
display(Markdown("**40% Change**"))
infuse_baserunning_table, _, _ = improve_team_baserunning_table(real_pies, 0.40, shadows=True)
display(infuse_baserunning_table)
display(set_heatmap(get_baserunning_stlats(improve_team_baserunning(real_pies, 0.40, shadows=True)), maxVal=1))
# Out:
# **40% Change**
#                     old_baserunning_stars  new_baserunning_stars  \
# Adrian Melon                     3.116697               5.097653
# August Obrien                    3.318856               5.368964
# Mcfarland Vargas                 3.783245               5.651652
# Twofurious Puddles               1.817993               3.908728
# Mummy Cantburn                   2.021513               4.128766
# Doginic Burgertoes               1.779564               4.022373
# Nerd Pacheco                     0.553414               2.677492
# Yusef Puddles                    2.938345               4.866021
# Sheev Shriffle                   2.215166               4.224486
# Adeline Hammer                   2.451014               4.374434
# Castillo Logan                   2.497486               4.396789
# Bambi Perez                      2.296481               4.251984
# Jesús Rodriguez                  2.318777               4.321873
# Jefferson Delacruz               3.539071               5.367248
# Case Lancaster                   2.215962               4.241752
# Haruta Byrd                      2.445376               4.533160
# Javier Lotus                     3.306631               5.162189
# Usurper Violet                   2.098233               4.712245
# Lucy Tokkan                      1.301211               3.519499
# Stan Schenn                      1.988408               4.003186
#
#                     change_in_baserunning_stars
# Adrian Melon                           1.980956
# August Obrien                          2.050108
# Mcfarland Vargas                       1.868407
# Twofurious Puddles                     2.090735
# Mummy Cantburn                         2.107253
# Doginic Burgertoes                     2.242810
# Nerd Pacheco                           2.124078
# Yusef Puddles                          1.927676
# Sheev Shriffle                         2.009320
# Adeline Hammer                         1.923420
# Castillo Logan                         1.899303
# Bambi Perez                            1.955503
# Jesús Rodriguez                        2.003096
# Jefferson Delacruz                     1.828177
# Case Lancaster                         2.025790
# Haruta Byrd                            2.087784
# Javier Lotus                           1.855557
# Usurper Violet                         2.614011
# Lucy Tokkan                            2.218287
# Stan Schenn                            2.014778
# <style  type="text/css" >
# #T_e1827_row0_col0,#T_e1827_row0_col1,#T_e1827_row1_col0,#T_e1827_row1_col1,#T_e1827_row1_col3,#T_e1827_row2_col0,#T_e1827_row2_col1,#T_e1827_row2_col3,#T_e1827_row3_col4,#T_e1827_row3_col5,#T_e1827_row4_col2,#T_e1827_row4_col3,#T_e1827_row4_col5,#T_e1827_row5_col3,#T_e1827_row5_col4,#T_e1827_row5_col5,#T_e1827_row7_col1,#T_e1827_row7_col3,#T_e1827_row8_col2,#T_e1827_row8_col3,#T_e1827_row8_col4,#T_e1827_row9_col3,#T_e1827_row9_col4,#T_e1827_row10_col4,#T_e1827_row11_col2,#T_e1827_row12_col2,#T_e1827_row13_col0,#T_e1827_row13_col1,#T_e1827_row13_col2,#T_e1827_row13_col3,#T_e1827_row13_col4,#T_e1827_row13_col5,#T_e1827_row14_col3,#T_e1827_row14_col5,#T_e1827_row15_col2,#T_e1827_row15_col3,#T_e1827_row15_col5,#T_e1827_row16_col0,#T_e1827_row16_col1,#T_e1827_row16_col2,#T_e1827_row17_col1,#T_e1827_row17_col2,#T_e1827_row18_col2,#T_e1827_row18_col3,#T_e1827_row19_col4,#T_e1827_row19_col5{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_e1827_row0_col2,#T_e1827_row16_col3{
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_e1827_row0_col3,#T_e1827_row18_col4{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_e1827_row0_col4,#T_e1827_row11_col5{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_e1827_row0_col5,#T_e1827_row2_col5{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_e1827_row1_col2{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_e1827_row1_col4,#T_e1827_row2_col4,#T_e1827_row10_col0,#T_e1827_row16_col5{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_e1827_row1_col5{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_e1827_row2_col2{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_e1827_row3_col0,#T_e1827_row7_col5,#T_e1827_row10_col2{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_e1827_row3_col1{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_e1827_row3_col2{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_e1827_row3_col3{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_e1827_row4_col0{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_e1827_row4_col1{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_e1827_row4_col4{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_e1827_row5_col0{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_e1827_row5_col1{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_e1827_row5_col2{
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_e1827_row6_col0{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_e1827_row6_col1{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_e1827_row6_col2,#T_e1827_row17_col4{
#             background-color:  #fee797;
#             color:  #000000;
#         }#T_e1827_row6_col3{
#             background-color:  #feeda1;
#             color:  #000000;
#         }#T_e1827_row6_col4,#T_e1827_row12_col5{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_e1827_row6_col5{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_e1827_row7_col0,#T_e1827_row11_col4{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_e1827_row7_col2,#T_e1827_row12_col4{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_e1827_row7_col4,#T_e1827_row15_col1{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_e1827_row8_col0{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_e1827_row8_col1{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_e1827_row8_col5,#T_e1827_row14_col1{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_e1827_row9_col0,#T_e1827_row16_col4{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_e1827_row9_col1{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_e1827_row9_col2{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_e1827_row9_col5,#T_e1827_row11_col0,#T_e1827_row14_col0{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_e1827_row10_col1{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_e1827_row10_col3{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_e1827_row10_col5{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_e1827_row11_col1{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_e1827_row11_col3,#T_e1827_row14_col2,#T_e1827_row19_col2{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_e1827_row12_col0{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_e1827_row12_col1{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_e1827_row12_col3{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_e1827_row14_col4,#T_e1827_row18_col1{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_e1827_row15_col0{
#             background-color:  #17934e;
#             color:  #000000;
#         }#T_e1827_row15_col4{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_e1827_row17_col0{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_e1827_row17_col3{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_e1827_row17_col5{
#             background-color:  #fff2aa;
#             color:  #000000;
#         }#T_e1827_row18_col0{
#             background-color:  #a2d76a;
#             color:  #000000;
#         }#T_e1827_row18_col5{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_e1827_row19_col0{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_e1827_row19_col1{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_e1827_row19_col3{
#             background-color:  #addc6f;
#             color:  #000000;
#         }</style><table id="T_e1827_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Baserunning Rating</th>        <th class="col_heading level0 col1" >Laserlikeness</th>        <th class="col_heading level0 col2" >Continuation</th>        <th class="col_heading level0 col3" >Base Thirst</th>        <th class="col_heading level0 col4" >Indulgence</th>        <th class="col_heading level0 col5" >Ground Friction</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1827_level0_row0" class="row_heading level0 row0" >Adrian Melon</th>
#                         <td id="T_e1827_row0_col0" class="data row0 col0" >1.019531</td>
#                         <td id="T_e1827_row0_col1" class="data row0 col1" >1.240831</td>
#                         <td id="T_e1827_row0_col2" class="data row0 col2" >0.984640</td>
#                         <td id="T_e1827_row0_col3" class="data row0 col3" >0.885051</td>
#                         <td id="T_e1827_row0_col4" class="data row0 col4" >0.576399</td>
#                         <td id="T_e1827_row0_col5" class="data row0 col5" >0.821241</td>
#             </tr>
#             <tr>
#                         <th id="T_e1827_level0_row1" class="row_heading level0 row1" >August Obrien</th>
#                         <td id="T_e1827_row1_col0" class="data row1 col0" >1.0737

# %% [markdown]
# #### Defense

# %%
display(Markdown("**20% Change**"))
infuse_defense_table, _, _ = improve_team_defense_table(real_pies, 0.20, shadows=True)
display(infuse_defense_table)
display(set_heatmap(get_defense_stlats(improve_team_defense(real_pies, 0.20, shadows=True)), maxVal=1))
# Out:
# **20% Change**
#                     old_defense_stars  new_defense_stars  \
# Adrian Melon                 2.664412           3.626229
# August Obrien                2.035102           3.265688
# Mcfarland Vargas             2.071032           3.315858
# Twofurious Puddles           3.610790           4.445614
# Mummy Cantburn               3.289650           4.105055
# Doginic Burgertoes           1.538638           2.876826
# Nerd Pacheco                 0.500829           1.835336
# Yusef Puddles                3.712285           4.522409
# Sheev Shriffle               0.873827           2.631009
# Adeline Hammer               3.312777           4.176898
# Castillo Logan               2.996505           3.928175
# Bambi Perez                  2.859667           3.899858
# Jesús Rodriguez              1.417111           2.952734
# Jefferson Delacruz           3.914262           4.695295
# Case Lancaster               3.176257           4.212016
# Haruta Byrd                  1.671932           3.031379
# Javier Lotus                 3.872915           4.664472
# Usurper Violet               4.036096           4.801531
# Lucy Tokkan                  3.021382           3.880618
# Stan Schenn                  2.521341           3.471260
#
#                     change_in_defense_stars
# Adrian Melon                       0.961817
# August Obrien                      1.230586
# Mcfarland Vargas                   1.244825
# Twofurious Puddles                 0.834824
# Mummy Cantburn                     0.815405
# Doginic Burgertoes                 1.338187
# Nerd Pacheco                       1.334507
# Yusef Puddles                      0.810124
# Sheev Shriffle                     1.757183
# Adeline Hammer                     0.864121
# Castillo Logan                     0.931670
# Bambi Perez                        1.040191
# Jesús Rodriguez                    1.535623
# Jefferson Delacruz                 0.781033
# Case Lancaster                     1.035759
# Haruta Byrd                        1.359447
# Javier Lotus                       0.791557
# Usurper Violet                     0.765435
# Lucy Tokkan                        0.859235
# Stan Schenn                        0.949919
# <style  type="text/css" >
# #T_ba89e_row0_col0{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_ba89e_row0_col1{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_ba89e_row0_col2{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_ba89e_row0_col3,#T_ba89e_row0_col5,#T_ba89e_row1_col3,#T_ba89e_row2_col5,#T_ba89e_row3_col1,#T_ba89e_row3_col2,#T_ba89e_row4_col5,#T_ba89e_row5_col2,#T_ba89e_row7_col2,#T_ba89e_row7_col5,#T_ba89e_row8_col5,#T_ba89e_row9_col3,#T_ba89e_row9_col4,#T_ba89e_row9_col5,#T_ba89e_row10_col5,#T_ba89e_row11_col2,#T_ba89e_row12_col3,#T_ba89e_row12_col4,#T_ba89e_row13_col1,#T_ba89e_row13_col3,#T_ba89e_row13_col5,#T_ba89e_row14_col1,#T_ba89e_row14_col5,#T_ba89e_row16_col2,#T_ba89e_row16_col5,#T_ba89e_row17_col1{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_ba89e_row0_col4,#T_ba89e_row4_col3,#T_ba89e_row7_col1{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_ba89e_row1_col0{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_ba89e_row1_col1,#T_ba89e_row2_col1{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_ba89e_row1_col2{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_ba89e_row1_col4{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_ba89e_row1_col5,#T_ba89e_row3_col4{
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_ba89e_row2_col0,#T_ba89e_row8_col4{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_ba89e_row2_col2{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_ba89e_row2_col3,#T_ba89e_row4_col1{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_ba89e_row2_col4{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_ba89e_row3_col0{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_ba89e_row3_col3,#T_ba89e_row8_col3{
#             background-color:  #fff2aa;
#             color:  #000000;
#         }#T_ba89e_row3_col5{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_ba89e_row4_col0{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_ba89e_row4_col2{
#             background-color:  #daf08d;
#             color:  #000000;
#         }#T_ba89e_row4_col4{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_ba89e_row5_col0{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_ba89e_row5_col1{
#             background-color:  #f88c51;
#             color:  #000000;
#         }#T_ba89e_row5_col3{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_ba89e_row5_col4{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_ba89e_row5_col5{
#             background-color:  #fca85e;
#             color:  #000000;
#         }#T_ba89e_row6_col0{
#             background-color:  #fece7c;
#             color:  #000000;
#         }#T_ba89e_row6_col1,#T_ba89e_row6_col4{
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_ba89e_row6_col2,#T_ba89e_row6_col3{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_ba89e_row6_col5{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_ba89e_row7_col0{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_ba89e_row7_col3{
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_ba89e_row7_col4,#T_ba89e_row14_col0{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_ba89e_row8_col0{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_ba89e_row8_col1{
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_ba89e_row8_col2,#T_ba89e_row12_col5{
#             background-color:  #f47044;
#             color:  #000000;
#         }#T_ba89e_row9_col0{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_ba89e_row9_col1{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_ba89e_row9_col2{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_ba89e_row10_col0{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_ba89e_row10_col1{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_ba89e_row10_col2{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_ba89e_row10_col3{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_ba89e_row10_col4,#T_ba89e_row19_col0{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_ba89e_row11_col0{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_ba89e_row11_col1{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_ba89e_row11_col3{
#             background-color:  #108647;
#             color:  #000000;
#         }#T_ba89e_row11_col4{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_ba89e_row11_col5{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_ba89e_row12_col0{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_ba89e_row12_col1{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_ba89e_row12_col2{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_ba89e_row13_col0{
#             background-color:  #0f8446;
#             color:  #f1f1f1;
#         }#T_ba89e_row13_col2{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_ba89e_row13_col4{
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_ba89e_row14_col2{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_ba89e_row14_col3{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_ba89e_row14_col4{
#             background-color:  #fca55d;
#             color:  #000000;
#         }#T_ba89e_row15_col0{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_ba89e_row15_col1{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_ba89e_row15_col2{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_ba89e_row15_col3{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_ba89e_row15_col4{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_ba89e_row15_col5{
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }#T_ba89e_row16_col0{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_ba89e_row16_col1{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_ba89e_row16_col3{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_ba89e_row16_col4{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_ba89e_row17_col0{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_ba89e_row17_col2,#T_ba89e_row19_col4{
#             background-color:  #0b7d42;
#             color:  #f1f1f1;
#         }#T_ba89e_row17_col3{
#             background-color:  #78c565;
#             color:  #000000;
#         }#T_ba89e_row17_col4{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_ba89e_row17_col5{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }#T_ba89e_row18_col0{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_ba89e_row18_col1{
#             background-col

# %%
display(Markdown("**40% Change**"))
infuse_defense_table, _, _ = improve_team_defense_table(real_pies, 0.40, shadows=True)
display(infuse_defense_table)
display(set_heatmap(get_defense_stlats(improve_team_defense(real_pies, 0.40, shadows=True)), maxVal=1))
# Out:
# **40% Change**
#                     old_defense_stars  new_defense_stars  \
# Adrian Melon                 2.664412           4.442809
# August Obrien                2.035102           4.143706
# Mcfarland Vargas             2.071032           4.198096
# Twofurious Puddles           3.610790           5.189850
# Mummy Cantburn               3.289650           4.849029
# Doginic Burgertoes           1.538638           3.813725
# Nerd Pacheco                 0.500829           2.810050
# Yusef Puddles                3.712285           5.255879
# Sheev Shriffle               0.873827           3.582429
# Adeline Hammer               3.312777           4.942295
# Castillo Logan               2.996505           4.720504
# Bambi Perez                  2.859667           4.721832
# Jesús Rodriguez              1.417111           3.886418
# Jefferson Delacruz           3.914262           5.411357
# Case Lancaster               3.176257           5.020516
# Haruta Byrd                  1.671932           3.908855
# Javier Lotus                 3.872915           5.384160
# Usurper Violet               4.036096           5.508648
# Lucy Tokkan                  3.021382           4.649359
# Stan Schenn                  2.521341           4.282758
#
#                     change_in_defense_stars
# Adrian Melon                       1.778397
# August Obrien                      2.108604
# Mcfarland Vargas                   2.127063
# Twofurious Puddles                 1.579060
# Mummy Cantburn                     1.559380
# Doginic Burgertoes                 2.275087
# Nerd Pacheco                       2.309221
# Yusef Puddles                      1.543594
# Sheev Shriffle                     2.708603
# Adeline Hammer                     1.629518
# Castillo Logan                     1.723999
# Bambi Perez                        1.862165
# Jesús Rodriguez                    2.469307
# Jefferson Delacruz                 1.497095
# Case Lancaster                     1.844260
# Haruta Byrd                        2.236923
# Javier Lotus                       1.511245
# Usurper Violet                     1.472552
# Lucy Tokkan                        1.627977
# Stan Schenn                        1.761417
# <style  type="text/css" >
# #T_6a01b_row0_col0{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_6a01b_row0_col1{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_6a01b_row0_col2{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_6a01b_row0_col3,#T_6a01b_row0_col5,#T_6a01b_row1_col3,#T_6a01b_row1_col5,#T_6a01b_row2_col4,#T_6a01b_row2_col5,#T_6a01b_row3_col0,#T_6a01b_row3_col1,#T_6a01b_row3_col2,#T_6a01b_row3_col4,#T_6a01b_row4_col4,#T_6a01b_row4_col5,#T_6a01b_row5_col2,#T_6a01b_row7_col0,#T_6a01b_row7_col2,#T_6a01b_row7_col4,#T_6a01b_row7_col5,#T_6a01b_row8_col5,#T_6a01b_row9_col3,#T_6a01b_row9_col4,#T_6a01b_row9_col5,#T_6a01b_row10_col1,#T_6a01b_row10_col3,#T_6a01b_row10_col5,#T_6a01b_row11_col1,#T_6a01b_row11_col2,#T_6a01b_row11_col3,#T_6a01b_row12_col3,#T_6a01b_row12_col4,#T_6a01b_row13_col0,#T_6a01b_row13_col1,#T_6a01b_row13_col3,#T_6a01b_row13_col4,#T_6a01b_row13_col5,#T_6a01b_row14_col0,#T_6a01b_row14_col1,#T_6a01b_row14_col2,#T_6a01b_row14_col5,#T_6a01b_row15_col3,#T_6a01b_row16_col0,#T_6a01b_row16_col1,#T_6a01b_row16_col2,#T_6a01b_row16_col3,#T_6a01b_row16_col5,#T_6a01b_row17_col0,#T_6a01b_row17_col1,#T_6a01b_row17_col2,#T_6a01b_row17_col5,#T_6a01b_row18_col1,#T_6a01b_row19_col4{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_6a01b_row0_col4,#T_6a01b_row4_col3,#T_6a01b_row7_col1{
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_6a01b_row1_col0{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_6a01b_row1_col1,#T_6a01b_row2_col1{
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_6a01b_row1_col2{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_6a01b_row1_col4{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_6a01b_row2_col0,#T_6a01b_row17_col4{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_6a01b_row2_col2{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_6a01b_row2_col3,#T_6a01b_row4_col1,#T_6a01b_row9_col0{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_6a01b_row3_col3,#T_6a01b_row14_col3{
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_6a01b_row3_col5{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_6a01b_row4_col0{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_6a01b_row4_col2{
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_6a01b_row5_col0{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_6a01b_row5_col1{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_6a01b_row5_col3{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_6a01b_row5_col4{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_6a01b_row5_col5,#T_6a01b_row12_col2{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_6a01b_row6_col0{
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_6a01b_row6_col1{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_6a01b_row6_col2,#T_6a01b_row6_col3{
#             background-color:  #fff0a6;
#             color:  #000000;
#         }#T_6a01b_row6_col4{
#             background-color:  #feeb9d;
#             color:  #000000;
#         }#T_6a01b_row6_col5{
#             background-color:  #fee797;
#             color:  #000000;
#         }#T_6a01b_row7_col3,#T_6a01b_row8_col0,#T_6a01b_row18_col5{
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_6a01b_row8_col1{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_6a01b_row8_col2,#T_6a01b_row12_col5{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_6a01b_row8_col3{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_6a01b_row8_col4{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_6a01b_row9_col1,#T_6a01b_row10_col4{
#             background-color:  #1e9a51;
#             color:  #000000;
#         }#T_6a01b_row9_col2{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_6a01b_row10_col0,#T_6a01b_row11_col0{
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_6a01b_row10_col2{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_6a01b_row11_col4{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_6a01b_row11_col5{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_6a01b_row12_col0{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_6a01b_row12_col1{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_6a01b_row13_col2{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_6a01b_row14_col4{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_6a01b_row15_col0{
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_6a01b_row15_col1{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_6a01b_row15_col2{
#             background-color:  #4bb05c;
#             color:  #000000;
#         }#T_6a01b_row15_col4{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_6a01b_row15_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_6a01b_row16_col4{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_6a01b_row17_col3{
#             background-color:  #06733d;
#             color:  #f1f1f1;
#         }#T_6a01b_row18_col0,#T_6a01b_row19_col3{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_6a01b_row18_col2{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_6a01b_row18_col3{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_6a01b_row18_col4{
#             background-color:  #1b9950;
#             color:  #000000;
#         }#T_6a01b_row19_col0{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_6a01b_row19_col1{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_6a01b_row19_col2{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_6a01b_row19_col5{
#             background-color:  #7ac665;
#             color:  #000000;
#         }</style><table id="T_6a01b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Defense Rating</th>        <th class="col_heading level0 col1" >Omniscience</th>        <th class="col_heading level0 col2" >Tenaciousness</th>        <th class="col_heading level0 col3" >Watchfulness</th>        <th class="col_heading level0 col4" >Anticapitalism</th>        <th class="col_heading level0 col5" >Chasiness</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a01b_level0_row0" class="row_heading level0 row0" >Adrian Melon</th>
#                         <td id="T_6a01b_row0_col0" class="data row0 col0" >0.888562</td>
#                         <td id="T_6a01b_row0_col1" class="data row0 col1" >0.588840</td>
#                         <td id="T_6a01b_row0_col2" class="data row0 col2" >0.743662</td>
#                         <td id="T_6a01b_row0_col3" class="data row0 col3" >1.305908</td>
#                         <td id="T_6a01b_row0_col4" class="data row0 col4" >0.916713</td>
#                         <td id="T_6a01b_row0_col5" class="data row0 col5" >1.336550</td>
#             </tr>
#             <tr>
#                         <th id="T_

# %% [markdown]
# ### Shadow Revoke
# **Revoke a Player from your Team's Shadows.**
#
# This would remove a player from our shadows by moving them to another team, without providing a replacement.

# %% [markdown]
# ### Reform
# **Re-roll an eligible Permanent Modification for a Player on your Team.**
#
# Below is a list of all players with modifications that could be rerolled. It would be better to reroll modifications
# with negative effects.

# %%
mod_players = [x for x in pies.lineup + pies.rotation if len(x.perm_attr) > 0]
mod_list = pandas.DataFrame()
for player in mod_players:
    data = pandas.Series({"mods": [x.title for x in player.perm_attr if x.id not in UNREFORMED_MODS]}, name=player.name)
    if len(data["mods"]) == 0:
        continue
    mod_list = mod_list.append(data)
mod_list
# Out:
#                                                mods
# Beasley Day                            [Minimalist]
# Huber Frumple                              [Seeker]
# Ruslan Greatness                  [Friend of Crows]
# Jaxon Buckley                          [Fire Eater]
# Peanut Holloway           [Honey Roasted, Negative]
# Beans McBlase     [Siphon, Spicy, Perk, Slow Build]
# Henry Marshallow                       [Maximalist]

# %% [markdown]
# ### Magnify
# **Magnify a Player on your Team. Runs batted in or allowed by this Player are multiplied.**
#
# See below for amount of runs batted in/allowed for each player in the previous season.

# %%
table = get_batting_stats(pies.lineup, season=20)
table.filter(items=["runs_batted_in"])
# Out:
#                   runs_batted_in
# Eduardo Woodman        65.000000
# Beasley Day            70.100001
# Huber Frumple         102.300000
# Ruslan Greatness       95.500000
# Jaxon Buckley          96.400000
# Lang Richardson        67.500000
# Peanut Holloway        68.700001

# %%
table = get_pitching_stats(pies.rotation, season=20)
table.filter(items=["runs_allowed"])
# Out:
#                   runs_allowed
# Tiana Takahashi          103.0
# Henry Marshallow         106.0

# %% [markdown]
# ___
# ## Blessings
#
# Blessings are selected by raffle across all teams. Each blessing will be awarded to one random team, where teams with
# more votes are more likely to be selected.

# %% [markdown]
# ### Play to Find Out
#
# **All Players in your Team's Rotation will become Heist Experts.**
#
# The effect of being a Heist Expert is unknown. It presumably makes players better at stealing items/runs from Secret
# Tunnels.

# %% [markdown]
# ### Trader
#
# **A Random Player in your Team's Lineup will become a Trader.**
#
# The effect of Trader is unknown.

# %% [markdown]
# ### Soul Food
#
# **Add 99 Soul to a random Player on your Team's Active Roster.**
#
# Soul increases the length of Soulscreams and provides 2 eDensity per-soul. For Negative players this will make the
# eDensity more negative. See below for the roster's current soul amounts.

# %%
print(f"Team eDensity change from {pies.e_density} to {pies.e_density + 2*99}")
x = pandas.DataFrame()
for p in pies.lineup + pies.rotation:
    x = x.append(pandas.Series({"Current Soul": p.soul, "Current eDensity": p.e_density}, name=p.name))
x
# Out:
# Team eDensity change from 1383.5010507342554 to 1581.5010507342554
#                   Current Soul  Current eDensity
# Eduardo Woodman            4.0         28.078355
# Beasley Day                7.0         38.872168
# Huber Frumple              7.0         34.851497
# Ruslan Greatness           4.0         34.632055
# Jaxon Buckley              7.0         47.686846
# Lang Richardson            6.0         29.275389
# Peanut Holloway            3.0        -22.987620
# Doc Anice                  9.0         39.817150
# Tiana Takahashi            4.0         31.234012
# Beans McBlase              4.0         57.852417
# Henry Marshallow           5.0         31.752575

# %% [markdown]
# ### Big Head Mode
#
# **Magnify and Ego Boost an Ego-less Player on your Team's Active Roster.**
#
# Magnify will multiply the runs scored/allowed, Ego Boost will cause them to not get swept away in flooding, but
# increases their eDensity and brings them closer to being Vaulted. See below for list of players this could hit.

# %%
players = pies.lineup + pies.rotation
ego = has_mods(players, ["EGO1", "EGO2", "EGO3", "EGO4"])
get_stars([x for x in players if x not in ego])
# Out:
#                   Combined  Batting  Pitching  Baserunning  Defense
# Eduardo Woodman       14.3      5.6       1.8          3.7      3.3
# Beasley Day           17.8      5.4       4.1          4.4      3.9
# Huber Frumple         14.9      4.8       2.4          4.4      3.4
# Ruslan Greatness      19.0      4.8       4.1          5.1      5.1
# Lang Richardson       12.3      3.5       1.0          3.8      3.9
# Peanut Holloway       12.1      4.5       1.5          2.4      3.7
# Doc Anice             15.6      4.4       3.7          3.2      4.3
# Tiana Takahashi       16.6      2.7       5.3          4.0      4.6
# Beans McBlase         17.0      4.4       4.1          2.8      5.7
# Henry Marshallow      15.5      3.8       4.1          2.9      4.8

# %% [markdown]
# ### Shadow Brooms Supply Run
#
# **All Players in your Team's Shadows with an available Item slot will open a Generic Broom Crate.**
#
# For reference, these items boost the following:
#
# | Item Type  | Attributes | Stat |
# | ---------- | ---------- | ---- |
# | Broom      | +Divinity  | Batting |
#
# This would provide Generic Sunglasses or Helmets to the following players:

# %%
free_items = has_item_slots(pies.shadows)
get_stars(free_items)
# Out:
#                     Combined  Batting  Pitching  Baserunning  Defense
# Adrian Melon             9.1      2.4       0.9          3.1      2.7
# August Obrien            9.8      3.4       1.0          3.3      2.0
# Mcfarland Vargas         8.7      1.4       1.5          3.8      2.1
# Twofurious Puddles      11.5      2.6       3.5          1.8      3.6
# Mummy Cantburn           9.0      1.4       2.3          2.0      3.3
# Doginic Burgertoes       7.2      2.1       1.8          1.8      1.5
# Nerd Pacheco             1.7      0.3       0.3          0.6      0.5
# Yusef Puddles           11.6      2.4       2.5          2.9      3.7
# Sheev Shriffle           8.4      3.4       1.9          2.2      0.9
# Adeline Hammer           7.8      1.1       0.9          2.5      3.3
# Castillo Logan          10.4      1.9       3.0          2.5      3.0
# Bambi Perez              7.2      1.7       0.3          2.3      2.9
# Jesús Rodriguez          6.7      1.6       1.3          2.3      1.4
# Jefferson Delacruz      11.0      3.0       0.6          3.5      3.9
# Case Lancaster           8.9      0.2       3.3          2.2      3.2
# Haruta Byrd             10.5      3.6       2.7          2.4      1.7
# Javier Lotus            11.4      3.4       0.8          3.3      3.9
# Stan Schenn              7.3      1.8       0.9          2.0      2.5

# %% [markdown]
# ### Shadow Evolution
#
# **Every Player in your Team's Shadows will Advance.**
#
# An Advanced player will gain one evolution level, increasing their minimum star level by one for all stats and raising
# their stars to the minimum if they are lower than that. It also allows players to hold an additional item.

# %% [markdown]
# ### Strong Armed
#
# **Move the Best Defender in your Team's Rotation to a random spot in your Team's Lineup.**
#
# This would move the following player to our lineup.

# %%
temp_pies = pies.rotation.copy()
temp_pies.sort(key=lambda x: x.get_defense_rating(), reverse=True)
display(get_stars(temp_pies[0]))
display(set_heatmap(get_batting_stlats([temp_pies[0]] + pies.lineup), maxVal=1.0))
display(pandas.DataFrame(move_player(pies, temp_pies[0], "lineup")))
# Out:
#                Combined  Batting  Pitching  Baserunning  Defense
# Beans McBlase      17.0      4.4       4.1          2.8      5.7
# <style  type="text/css" >
# #T_c1061_row0_col0{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_c1061_row0_col1{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_c1061_row0_col2,#T_c1061_row0_col3,#T_c1061_row1_col0,#T_c1061_row1_col1,#T_c1061_row1_col2,#T_c1061_row1_col8,#T_c1061_row2_col0,#T_c1061_row2_col1,#T_c1061_row2_col2,#T_c1061_row2_col8,#T_c1061_row3_col2,#T_c1061_row3_col3,#T_c1061_row3_col4,#T_c1061_row3_col8,#T_c1061_row4_col2,#T_c1061_row4_col3,#T_c1061_row4_col4,#T_c1061_row4_col6,#T_c1061_row5_col0,#T_c1061_row5_col1,#T_c1061_row5_col2,#T_c1061_row5_col3,#T_c1061_row5_col4,#T_c1061_row5_col6,#T_c1061_row5_col8,#T_c1061_row7_col2,#T_c1061_row7_col3,#T_c1061_row7_col4,#T_c1061_row7_col8,#T_c1061_row8_col1,#T_c1061_row8_col6,#T_c1061_row8_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_c1061_row0_col4{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_c1061_row0_col5,#T_c1061_row0_col7,#T_c1061_row1_col7,#T_c1061_row2_col7,#T_c1061_row3_col7,#T_c1061_row4_col5,#T_c1061_row4_col7,#T_c1061_row5_col5,#T_c1061_row5_col7,#T_c1061_row6_col7,#T_c1061_row7_col5,#T_c1061_row8_col5{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_c1061_row0_col6,#T_c1061_row1_col4{
#             background-color:  #2aa054;
#             color:  #000000;
#         }#T_c1061_row0_col8{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_c1061_row1_col3{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_c1061_row1_col5{
#             background-color:  #fba35c;
#             color:  #000000;
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_c1061_row1_col6{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_c1061_row2_col3{
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_c1061_row2_col4{
#             background-color:  #148e4b;
#             color:  #000000;
#         }#T_c1061_row2_col5{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#             background-color:  #097940;
#             color:  #f1f1f1;
#         }#T_c1061_row2_col6{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_c1061_row3_col0,#T_c1061_row8_col3{
#             background-color:  #0a7b41;
#             color:  #f1f1f1;
#         }#T_c1061_row3_col1{
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_c1061_row3_col5{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_c1061_row3_col6{
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_c1061_row4_col0{
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_c1061_row4_col1{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_c1061_row4_col8{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_c1061_row6_col0{
#             background-color:  #a2d76a;
#             color:  #000000;
#         }#T_c1061_row6_col1{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_c1061_row6_col2{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_c1061_row6_col3{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_c1061_row6_col4,#T_c1061_row8_col4{
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }#T_c1061_row6_col5{
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_c1061_row6_col6{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_c1061_row6_col8{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_c1061_row7_col0{
#             background-color:  #199750;
#             color:  #000000;
#         }#T_c1061_row7_col1{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_c1061_row7_col6{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_c1061_row7_col7{
#             background-color:  #9bd469;
#             color:  #000000;
#             background-color:  #fba35c;
#             color:  #000000;
#         }#T_c1061_row8_col0{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_c1061_row8_col2{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_c1061_row8_col7{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#             background-color:  #16914d;
#             color:  #000000;
#         }</style><table id="T_c1061_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Batting Rating</th>        <th class="col_heading level0 col1" >Thwackability</th>        <th class="col_heading level0 col2" >Divinity</th>        <th class="col_heading level0 col3" >Musclitude</th>        <th class="col_heading level0 col4" >Moxie</th>        <th class="col_heading level0 col5" >Patheticism</th>        <th class="col_heading level0 col6" >Martyrdom</th>        <th class="col_heading level0 col7" >Tragicness</th>        <th class="col_heading level0 col8" >Buoyancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1061_level0_row0" class="row_heading level0 row0" >Beans McBlase</th>
#                         <td id="T_c1061_row0_col0" class="data row0 col0" >0.879223</td>
#                         <td id="T_c1061_row0_col1" class="data row0 col1" >0.589986</td>
#                         <td id="T_c1061_row0_col2" class="data row0 col2" >1.132586</td>
#                         <td id="T_c1061_row0_col3" class="data row0 col3" >1.462367</td>
#                         <td id="T_c1061_row0_col4" class="data row0 col4" >0.836372</td>
#                         <td id="T_c1061_row0_col5" class="data row0 col5" >0.001000</td>
#                         <td id="T_c1061_row0_col6" class="data row0 col6" >0.875609</td>
#                         <td id="T_c1061_row0_col7" class="data row0 col7" >0.001000</td>
#                         <td id="T_c1061_row0_col8" class="data row0 col8" >0.491591</td>
#             </tr>
#             <tr>
#                         <th id="T_c1061_level0_row1" class="row_heading level0 row1" >Eduardo Woodman</th>
#                         <td id="T_c1061_row1_col0" class="data row1 col0" >1.126442</td>
#                         <td id="T_c1061_row1_col1" class="data row1 col1" >1.345315</td>
#                         <td id="T_c1061_row1_col2" class="data row1 col2" >1.152985</td>
#                         <td id="T_c1061_row1_col3" class="data row1 col3" >0.970888</td>
#                         <td id="T_c1061_row1_col4" class="data row1 col4" >0.876160</td>
#                         <td id="T_c1061_row1_col5" class="data row1 col5" >0.283687</td>
#                         <td id="T_c1061_row1_col6" class="data row1 col6" >0.749895</td>
#                         <td id="T_c1061_row1_col7" class="data row1 col7" >0.001000</td>
#                         <td id="T_c1061_row1_col8" class="data row1 col8" >1.025183</td>
#             </tr>
#             <tr>
#                         <th id="T_c1061_level0_row2" class="row_heading level0 row2" >Beasley Day</th>
#                         <td id="T_c1061_row2_col0" class="data row2 col0" >1.072655</td>
#                         <td id="T_c1061_row2_col1" class="data row2 col1" >1.213448</td>
#                         <td id="T_c1061_row2_col2" class="data row2 col2" >1.089350</td>
#                         <td id="T_c1061_row2_col3" class="data row2 col3" >0.794653</td>
#                         <td id="T_c1061_row2_col4" class="data row2 col4" >0.919026</td>
#                         Pies
# batting_change      -1.3672%
# pitching_change     +3.8371%
# baserunning_change  -2.3541%
# defense_change      +3.9482%

# %% [markdown]
# ### Liability
#
# **Move the Worst Defender in your Team's Lineup to a random spot in your Team's Rotation.**
#
# This would move the following player to our rotation.

# %%
temp_pies = pies.lineup.copy()
temp_pies.sort(key=lambda x: x.get_defense_rating())
display(get_stars(temp_pies[0]))
display(set_heatmap(get_pitching_stlats([temp_pies[0]] + pies.rotation), maxVal=1.0))
display(pandas.DataFrame(move_player(pies, temp_pies[0], "rotation")))
# Out:
#                  Combined  Batting  Pitching  Baserunning  Defense
# Eduardo Woodman      14.3      5.6       1.8          3.7      3.3
# <style  type="text/css" >
# #T_c2094_row0_col0,#T_c2094_row1_col4{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_c2094_row0_col1{
#             background-color:  #fdc574;
#             color:  #000000;
#         }#T_c2094_row0_col2{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_c2094_row0_col3{
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_c2094_row0_col4,#T_c2094_row1_col0,#T_c2094_row1_col1,#T_c2094_row1_col2,#T_c2094_row1_col3,#T_c2094_row1_col6,#T_c2094_row2_col3,#T_c2094_row3_col2,#T_c2094_row3_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_c2094_row0_col5{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_c2094_row0_col6{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_c2094_row1_col5{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_c2094_row2_col0{
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_c2094_row2_col1{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_c2094_row2_col2{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_c2094_row2_col4{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_c2094_row2_col5{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_c2094_row2_col6{
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }#T_c2094_row3_col0{
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_c2094_row3_col1{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_c2094_row3_col4{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_c2094_row3_col5{
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_c2094_row3_col6{
#             background-color:  #18954f;
#             color:  #000000;
#         }</style><table id="T_c2094_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pitching Rating</th>        <th class="col_heading level0 col1" >Unthwackability</th>        <th class="col_heading level0 col2" >Ruthlessness</th>        <th class="col_heading level0 col3" >Overpowerment</th>        <th class="col_heading level0 col4" >Shakespearianism</th>        <th class="col_heading level0 col5" >Coldness</th>        <th class="col_heading level0 col6" >Suppression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2094_level0_row0" class="row_heading level0 row0" >Eduardo Woodman</th>
#                         <td id="T_c2094_row0_col0" class="data row0 col0" >0.358480</td>
#                         <td id="T_c2094_row0_col1" class="data row0 col1" >0.347357</td>
#                         <td id="T_c2094_row0_col2" class="data row0 col2" >0.295959</td>
#                         <td id="T_c2094_row0_col3" class="data row0 col3" >0.947036</td>
#                         <td id="T_c2094_row0_col4" class="data row0 col4" >1.067106</td>
#                         <td id="T_c2094_row0_col5" class="data row0 col5" >0.711794</td>
#                         <td id="T_c2094_row0_col6" class="data row0 col6" >0.516003</td>
#             </tr>
#             <tr>
#                         <th id="T_c2094_level0_row1" class="row_heading level0 row1" >Tiana Takahashi</th>
#                         <td id="T_c2094_row1_col0" class="data row1 col0" >1.064998</td>
#                         <td id="T_c2094_row1_col1" class="data row1 col1" >1.142441</td>
#                         <td id="T_c2094_row1_col2" class="data row1 col2" >1.215111</td>
#                         <td id="T_c2094_row1_col3" class="data row1 col3" >1.182198</td>
#                         <td id="T_c2094_row1_col4" class="data row1 col4" >0.356126</td>
#                         <td id="T_c2094_row1_col5" class="data row1 col5" >0.872711</td>
#                         <td id="T_c2094_row1_col6" class="data row1 col6" >1.199716</td>
#             </tr>
#             <tr>
#                         <th id="T_c2094_level0_row2" class="row_heading level0 row2" >Beans McBlase</th>
#                         <td id="T_c2094_row2_col0" class="data row2 col0" >0.823652</td>
#                         <td id="T_c2094_row2_col1" class="data row2 col1" >0.930253</td>
#                         <td id="T_c2094_row2_col2" class="data row2 col2" >0.740418</td>
#                         <td id="T_c2094_row2_col3" class="data row2 col3" >1.131235</td>
#                         <td id="T_c2094_row2_col4" class="data row2 col4" >0.732166</td>
#                         <td id="T_c2094_row2_col5" class="data row2 col5" >0.368422</td>
#                         <td id="T_c2094_row2_col6" class="data row2 col6" >0.970233</td>
#             </tr>
#             <tr>
#                         <th id="T_c2094_level0_row3" class="row_heading level0 row3" >Henry Marshallow</th>
#                         <td id="T_c2094_row3_col0" class="data row3 col0" >0.812533</td>
#                         <td id="T_c2094_row3_col1" class="data row3 col1" >0.523573</td>
#                         <td id="T_c2094_row3_col2" class="data row3 col2" >1.209625</td>
#                         <td id="T_c2094_row3_col3" class="data row3 col3" >1.470785</td>
#                         <td id="T_c2094_row3_col4" class="data row3 col4" >0.867855</td>
#                         <td id="T_c2094_row3_col5" class="data row3 col5" >0.856246</td>
#                         <td id="T_c2094_row3_col6" class="data row3 col6" >0.905731</td>
#             </tr>
#     </tbody></table>
#                          Pies
# batting_change       -1.7739%
# pitching_change     -13.5479%
# baserunning_change   +0.6518%
# defense_change       +1.8872%

# %% [markdown]
# ### Cinnamon Challenges
#
# **Improve the Cinnamon of your Team's Active Roster by 1% to 8%.**
#
# **Improve the Cinnamon of your Team's Shadows by 1% to 16%.**
#
# Cinnamon defines the maximum value of Vibes, and increases the point value of Skate Tricks. See below for player change.

# %%
display(Markdown("**Worst Case**"))
table = pandas.DataFrame()
for player in pies.lineup + pies.rotation:
    p = player.simulated_copy(buffs={"cinnamon": 0.01})
    table = table.append(pandas.Series({"Cinnamon": p.cinnamon}, name=p.name))
display(table)
table = pandas.DataFrame()
for player in pies.shadows:
    p = player.simulated_copy(buffs={"cinnamon": 0.01})
    table = table.append(pandas.Series({"Cinnamon": p.cinnamon}, name=p.name))
display(table)
# Out:
# **Worst Case**
#                   Cinnamon
# Eduardo Woodman   0.370430
# Beasley Day       0.461014
# Huber Frumple     0.520537
# Ruslan Greatness  1.521111
# Jaxon Buckley     0.882527
# Lang Richardson   0.876226
# Peanut Holloway   0.460870
# Doc Anice         1.143956
# Tiana Takahashi   1.219840
# Beans McBlase     1.249029
# Henry Marshallow  1.138399
#                     Cinnamon
# Adrian Melon        0.028660
# August Obrien       0.255564
# Mcfarland Vargas    0.576792
# Twofurious Puddles  0.213907
# Mummy Cantburn      0.640642
# Doginic Burgertoes  0.016476
# Nerd Pacheco        0.639273
# Yusef Puddles       0.310060
# Sheev Shriffle      0.659169
# Adeline Hammer      0.031289
# Castillo Logan      0.984901
# Bambi Perez         0.949913
# Jesús Rodriguez     0.373713
# Jefferson Delacruz  0.877765
# Case Lancaster      0.461336
# Haruta Byrd         0.299570
# Javier Lotus        0.104580
# Usurper Violet      0.734500
# Lucy Tokkan         0.906861
# Stan Schenn         0.696792

# %%
display(Markdown("**Best Case**"))
table = pandas.DataFrame()
for player in pies.lineup + pies.rotation:
    p = player.simulated_copy(buffs={"cinnamon": 0.08})
    table = table.append(pandas.Series({"Cinnamon": p.cinnamon}, name=p.name))
display(table)
table = pandas.DataFrame()
for player in pies.shadows:
    p = player.simulated_copy(buffs={"cinnamon": 0.16})
    table = table.append(pandas.Series({"Cinnamon": p.cinnamon}, name=p.name))
display(table)
# Out:
# **Best Case**
#                   Cinnamon
# Eduardo Woodman   0.440430
# Beasley Day       0.531014
# Huber Frumple     0.590537
# Ruslan Greatness  1.591111
# Jaxon Buckley     0.952527
# Lang Richardson   0.946226
# Peanut Holloway   0.530870
# Doc Anice         1.213956
# Tiana Takahashi   1.289840
# Beans McBlase     1.319029
# Henry Marshallow  1.208399
#                     Cinnamon
# Adrian Melon        0.178660
# August Obrien       0.405564
# Mcfarland Vargas    0.726792
# Twofurious Puddles  0.363907
# Mummy Cantburn      0.790642
# Doginic Burgertoes  0.166476
# Nerd Pacheco        0.789273
# Yusef Puddles       0.460060
# Sheev Shriffle      0.809169
# Adeline Hammer      0.181289
# Castillo Logan      1.134901
# Bambi Perez         1.099913
# Jesús Rodriguez     0.523713
# Jefferson Delacruz  1.027765
# Case Lancaster      0.611336
# Haruta Byrd         0.449570
# Javier Lotus        0.254580
# Usurper Violet      0.884500
# Lucy Tokkan         1.056861
# Stan Schenn         0.846792

# %% [markdown]
# ### Pressure Cookers
#
# **Improve the Pressurization of your Team's Active Roster by 1% to 8%.**
#
# **Improve the Pressurization of your Team's Shadows by 1% to 16%.**
#
# Pressurization defines the minimum value of Vibes, so a high pressurization is bad. See below for player change.

# %%
display(Markdown("**Worst Case**"))
table = pandas.DataFrame()
for player in pies.lineup + pies.rotation:
    p = player.simulated_copy(buffs={"pressurization": 0.01})
    table = table.append(pandas.Series({"Pressurization": p.pressurization}, name=p.name))
display(table)
table = pandas.DataFrame()
for player in pies.shadows:
    p = player.simulated_copy(buffs={"pressurization": 0.01})
    table = table.append(pandas.Series({"Pressurization": p.pressurization}, name=p.name))
display(table)
# Out:
# **Worst Case**
#                   Pressurization
# Eduardo Woodman         0.321011
# Beasley Day             0.295454
# Huber Frumple           0.079679
# Ruslan Greatness        0.987745
# Jaxon Buckley           0.533724
# Lang Richardson         0.964206
# Peanut Holloway         0.297529
# Doc Anice               0.117642
# Tiana Takahashi         0.233659
# Beans McBlase           0.581698
# Henry Marshallow        0.720975
#                     Pressurization
# Adrian Melon              0.857159
# August Obrien             0.347008
# Mcfarland Vargas          0.529056
# Twofurious Puddles        0.072728
# Mummy Cantburn            0.750421
# Doginic Burgertoes        0.935385
# Nerd Pacheco              0.027249
# Yusef Puddles             0.836226
# Sheev Shriffle            0.601528
# Adeline Hammer            0.290005
# Castillo Logan            0.346410
# Bambi Perez               0.078625
# Jesús Rodriguez           0.891724
# Jefferson Delacruz        0.062505
# Case Lancaster            0.223947
# Haruta Byrd               0.284502
# Javier Lotus              0.519103
# Usurper Violet            0.049315
# Lucy Tokkan               0.717546
# Stan Schenn               0.469140

# %%
display(Markdown("**Best Case**"))
table = pandas.DataFrame()
for player in pies.lineup + pies.rotation:
    p = player.simulated_copy(buffs={"pressurization": 0.08})
    table = table.append(pandas.Series({"Pressurization": p.pressurization}, name=p.name))
display(table)
table = pandas.DataFrame()
for player in pies.shadows:
    p = player.simulated_copy(buffs={"pressurization": 0.16})
    table = table.append(pandas.Series({"Pressurization": p.pressurization}, name=p.name))
display(table)
# Out:
# **Best Case**
#                   Pressurization
# Eduardo Woodman         0.391011
# Beasley Day             0.365454
# Huber Frumple           0.149679
# Ruslan Greatness        1.057745
# Jaxon Buckley           0.603724
# Lang Richardson         1.034206
# Peanut Holloway         0.367529
# Doc Anice               0.187642
# Tiana Takahashi         0.303659
# Beans McBlase           0.651698
# Henry Marshallow        0.790975
#                     Pressurization
# Adrian Melon              1.007159
# August Obrien             0.497008
# Mcfarland Vargas          0.679056
# Twofurious Puddles        0.222728
# Mummy Cantburn            0.900421
# Doginic Burgertoes        1.085385
# Nerd Pacheco              0.177249
# Yusef Puddles             0.986226
# Sheev Shriffle            0.751528
# Adeline Hammer            0.440005
# Castillo Logan            0.496410
# Bambi Perez               0.228625
# Jesús Rodriguez           1.041724
# Jefferson Delacruz        0.212505
# Case Lancaster            0.373947
# Haruta Byrd               0.434502
# Javier Lotus              0.669103
# Usurper Violet            0.199315
# Lucy Tokkan               0.867546
# Stan Schenn               0.619140

# %% [markdown]
# ### Gaudy
#
# **A random Player on your Team will play better in Ballparks with more Modifications.**
#
# See below for list of Stadiums and their number of modifications.

# %%
stadiums = Stadium.load_all()
table = pandas.DataFrame()
for s in stadiums.values():
    table = table.append(pandas.Series({"Number of Mods": len(s.mods)}, name=s.team_id.nickname))
table.sort_values(by="Number of Mods")
# Out:
#                Number of Mods
# Steaks                    4.0
# Lovers                    6.0
# Breath Mints              7.0
# Wild Wings                7.0
# Jazz Hands                7.0
# Fridays                   7.0
# Worms                     7.0
# Firefighters              8.0
# Crabs                     8.0
# Millennials               8.0
# Pies                      8.0
# Dale                      8.0
# Sunbeams                  8.0
# Garages                   9.0
# Tigers                    9.0
# Moist Talkers             9.0
# Shoe Thieves              9.0
# Magic                     9.0
# Lift                      9.0
# Spies                    10.0
# Georgias                 10.0
# Tacos                    10.0
# Flowers                  10.0
# Mechanics                10.0

# %% [markdown]
# ### Cluttered
#
# **A random Player on your Team will play better in Filthier Ballparks.**
#
# See below for list of Filthiest Stadiums.

# %%
table = pandas.DataFrame()
for s in stadiums.values():
    table = table.append(pandas.Series({"Filthiness": s.filthiness}, name=s.team_id.nickname))
table = table.sort_values(by="Filthiness")
set_heatmap(table, maxVal=1)
# Out:
# <style  type="text/css" >
# #T_a9899_row0_col0{
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }#T_a9899_row1_col0{
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#         }#T_a9899_row2_col0{
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_a9899_row3_col0{
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_a9899_row4_col0{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_a9899_row5_col0{
#             background-color:  #ef633f;
#             color:  #000000;
#         }#T_a9899_row6_col0{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_a9899_row7_col0{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_a9899_row8_col0{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_a9899_row9_col0{
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_a9899_row10_col0{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_a9899_row11_col0{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_a9899_row12_col0,#T_a9899_row13_col0{
#             background-color:  #fa9656;
#             color:  #000000;
#         }#T_a9899_row14_col0{
#             background-color:  #fa9857;
#             color:  #000000;
#         }#T_a9899_row15_col0{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_a9899_row16_col0{
#             background-color:  #fca55d;
#             color:  #000000;
#         }#T_a9899_row17_col0,#T_a9899_row18_col0{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_a9899_row19_col0{
#             background-color:  #fdbd6d;
#             color:  #000000;
#         }#T_a9899_row20_col0{
#             background-color:  #fecc7b;
#             color:  #000000;
#         }#T_a9899_row21_col0{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_a9899_row22_col0{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_a9899_row23_col0{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }</style><table id="T_a9899_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Filthiness</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9899_level0_row0" class="row_heading level0 row0" >Steaks</th>
#                         <td id="T_a9899_row0_col0" class="data row0 col0" >0.046938</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row1" class="row_heading level0 row1" >Tacos</th>
#                         <td id="T_a9899_row1_col0" class="data row1 col0" >0.063045</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row2" class="row_heading level0 row2" >Sunbeams</th>
#                         <td id="T_a9899_row2_col0" class="data row2 col0" >0.148393</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row3" class="row_heading level0 row3" >Moist Talkers</th>
#                         <td id="T_a9899_row3_col0" class="data row3 col0" >0.150211</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row4" class="row_heading level0 row4" >Garages</th>
#                         <td id="T_a9899_row4_col0" class="data row4 col0" >0.173777</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row5" class="row_heading level0 row5" >Georgias</th>
#                         <td id="T_a9899_row5_col0" class="data row5 col0" >0.185068</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row6" class="row_heading level0 row6" >Crabs</th>
#                         <td id="T_a9899_row6_col0" class="data row6 col0" >0.202882</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row7" class="row_heading level0 row7" >Shoe Thieves</th>
#                         <td id="T_a9899_row7_col0" class="data row7 col0" >0.220202</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row8" class="row_heading level0 row8" >Breath Mints</th>
#                         <td id="T_a9899_row8_col0" class="data row8 col0" >0.228173</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row9" class="row_heading level0 row9" >Magic</th>
#                         <td id="T_a9899_row9_col0" class="data row9 col0" >0.233000</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row10" class="row_heading level0 row10" >Mechanics</th>
#                         <td id="T_a9899_row10_col0" class="data row10 col0" >0.242252</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row11" class="row_heading level0 row11" >Flowers</th>
#                         <td id="T_a9899_row11_col0" class="data row11 col0" >0.259020</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row12" class="row_heading level0 row12" >Jazz Hands</th>
#                         <td id="T_a9899_row12_col0" class="data row12 col0" >0.262304</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row13" class="row_heading level0 row13" >Lift</th>
#                         <td id="T_a9899_row13_col0" class="data row13 col0" >0.265619</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row14" class="row_heading level0 row14" >Lovers</th>
#                         <td id="T_a9899_row14_col0" class="data row14 col0" >0.266474</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row15" class="row_heading level0 row15" >Wild Wings</th>
#                         <td id="T_a9899_row15_col0" class="data row15 col0" >0.279598</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row16" class="row_heading level0 row16" >Firefighters</th>
#                         <td id="T_a9899_row16_col0" class="data row16 col0" >0.288318</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row17" class="row_heading level0 row17" >Fridays</th>
#                         <td id="T_a9899_row17_col0" class="data row17 col0" >0.297206</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row18" class="row_heading level0 row18" >Millennials</th>
#                         <td id="T_a9899_row18_col0" class="data row18 col0" >0.299113</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row19" class="row_heading level0 row19" >Dale</th>
#                         <td id="T_a9899_row19_col0" class="data row19 col0" >0.331797</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row20" class="row_heading level0 row20" >Pies</th>
#                         <td id="T_a9899_row20_col0" class="data row20 col0" >0.363015</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row21" class="row_heading level0 row21" >Spies</th>
#                         <td id="T_a9899_row21_col0" class="data row21 col0" >0.386518</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row22" class="row_heading level0 row22" >Tigers</th>
#                         <td id="T_a9899_row22_col0" class="data row22 col0" >0.420452</td>
#             </tr>
#             <tr>
#                         <th id="T_a9899_level0_row23" class="row_heading level0 row23" >Worms</th>
#                         <td id="T_a9899_row23_col0" class="data row23 col0" >0.640745</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Recruit Ego
#
# **Recruit a random Player with Ego to your Team's Active Roster.**
#
# Players with Ego cannot be swept off base during flooding, have increased eDensity, and are closer to being Vaulted. See
# below for list of all players that have any level of Ego.

# %%
egos = has_mods(all_active, ['EGO1', 'EGO2', 'EGO3', 'EGO4'])
get_stars(egos, include_team=True)
# Out:
#                                   Combined  Batting  Pitching  Baserunning  \
#                      Team
# Gerund Pantheocide   Lift             17.8      5.7       4.1          3.4
# Baby Doyle           Jazz Hands       17.0      5.5       2.9          3.7
# Nicholas Mora        Tigers           13.4      4.1       1.8          3.6
# Paula Turnip         Tigers           13.5      4.3       1.3          4.3
# Sexton Wheerer       Tacos            13.2      3.5       2.8          2.5
# Mcdowell Mason       Tacos            18.0      4.8       2.9          5.0
# Rat Mason            Tacos            10.2      5.0       1.3          2.4
# Jaylen Hotdogfingers Flowers          11.6      2.7       2.7          1.1
# Nagomi Nava          Sunbeams         17.6      6.3       3.0          4.9
# Commissioner Vapor   Spies            20.5      6.4       4.5          5.5
# H-t-ie-d S-z-ki      Millennials      18.8      4.3       4.3          4.7
# Jessica Telephone    Steaks           14.9      4.2       3.9          4.3
# Don Mitchell         Fridays          24.7      6.0       6.8          6.9
# Beck Whitney         Fridays          23.3      6.8       5.0          6.5
# James Mora           Magic            18.2      4.7       4.4          3.8
# Wyatt Glover         Magic            18.3      4.5       4.3          5.3
# Adalberto Tosser     Crabs            17.1      3.9       4.9          3.9
#
#                                   Defense
#                      Team
# Gerund Pantheocide   Lift             4.6
# Baby Doyle           Jazz Hands       4.8
# Nicholas Mora        Tigers           3.9
# Paula Turnip         Tigers           3.6
# Sexton Wheerer       Tacos            4.5
# Mcdowell Mason       Tacos            5.2
# Rat Mason            Tacos            1.5
# Jaylen Hotdogfingers Flowers          5.1
# Nagomi Nava          Sunbeams         3.5
# Commissioner Vapor   Spies            4.1
# H-t-ie-d S-z-ki      Millennials      5.4
# Jessica Telephone    Steaks           2.5
# Don Mitchell         Fridays          5.0
# Beck Whitney         Fridays          5.0
# James Mora           Magic            5.3
# Wyatt Glover         Magic            4.3
# Adalberto Tosser     Crabs            4.3

# %% [markdown]
# ### Double Negative
#
# **Recruit 2 random Negatives to your Team's Active Roster.**
#
# Players with Negative have negative eDensity. See below for a list of all players with Negative.

# %%
negatives = has_mods(all_active, 'NEGATIVE')
get_stars(negatives, include_team=True)
# Out:
#                                     Combined  Batting  Pitching  Baserunning  \
#                      Team
# --sef --ne-t----     Lift               15.2      4.6       2.4          4.1
# Elwin McGhee         Lift               13.4      3.5       2.1          4.7
# Rylan O'Lantern      Lift               11.9      1.7       2.6          2.8
# Walton Sports        Jazz Hands         17.0      2.6       4.9          4.2
# Mikan Hammer         Jazz Hands         11.4      2.2       1.6          3.8
# August Sky           Jazz Hands         14.8      4.7       4.3          2.7
# Socks Maybe          Firefighters        9.5      4.2       1.6          1.8
# Justice Spoon        Firefighters       10.0      3.4       2.9          0.2
# Gita Sparrow         Firefighters       11.8      3.6       2.6          2.7
# Peanutiel Duffy      Firefighters       17.2      4.8       5.0          3.2
# Isaac Johnson        Firefighters       17.4      3.3       2.8          4.3
# Dudley Mueller       Tigers             16.2      5.4       3.1          3.3
# Randy Castillo       Tigers             10.1      2.5       1.8          3.3
# Hiroto Wilcox        Tigers             11.2      2.9       2.4          2.2
# Evelton McBlase II   Wild Wings         12.2      2.1       3.0          3.2
# Erin Jesaulenko      Georgias           13.0      1.5       4.9          2.3
# Caleb Novak          Dale               10.0      2.1       2.8          1.6
# Jaylen Hotdogfingers Flowers            11.6      2.7       2.7          1.1
# Comfort Septemberish Sunbeams           13.7      4.9       1.2          4.9
# Nandy Fantastic      Millennials        14.6      3.9       2.7          4.6
# H-t-ie-d S-z-ki      Millennials        18.8      4.3       4.3          4.7
# Anathema Elemefayo   Millennials        11.8      2.2       3.8          2.2
# Sandie Carver        Millennials        14.2      4.1       4.5          3.2
# Jessica Telephone    Steaks             14.9      4.2       3.9          4.3
# Lotus Mango          Garages            14.7      4.9       3.4          3.1
# Arturo Huerta        Garages            18.9      4.2       5.3          5.5
# Mira Lemma           Mechanics          15.6      4.7       3.2          3.6
# Christian Combs      Mechanics          17.6      4.3       4.7          3.7
# Kelvin Drumsolo      Mechanics          13.4      3.5       2.4          4.5
# Greer Lott           Moist Talkers      19.0      3.9       6.2          3.9
# Amos Melon           Moist Talkers      13.5      3.6       3.9          2.1
# Avila Guzman         Crabs              16.1      4.8       1.6          5.5
#
#                                     Defense
#                      Team
# --sef --ne-t----     Lift               4.1
# Elwin McGhee         Lift               3.2
# Rylan O'Lantern      Lift               4.8
# Walton Sports        Jazz Hands         5.4
# Mikan Hammer         Jazz Hands         3.8
# August Sky           Jazz Hands         3.0
# Socks Maybe          Firefighters       1.9
# Justice Spoon        Firefighters       3.6
# Gita Sparrow         Firefighters       2.8
# Peanutiel Duffy      Firefighters       4.2
# Isaac Johnson        Firefighters       7.0
# Dudley Mueller       Tigers             4.5
# Randy Castillo       Tigers             2.5
# Hiroto Wilcox        Tigers             3.8
# Evelton McBlase II   Wild Wings         3.9
# Erin Jesaulenko      Georgias           4.2
# Caleb Novak          Dale               3.6
# Jaylen Hotdogfingers Flowers            5.1
# Comfort Septemberish Sunbeams           2.6
# Nandy Fantastic      Millennials        3.4
# H-t-ie-d S-z-ki      Millennials        5.4
# Anathema Elemefayo   Millennials        3.6
# Sandie Carver        Millennials        2.4
# Jessica Telephone    Steaks             2.5
# Lotus Mango          Garages            3.3
# Arturo Huerta        Garages            3.9
# Mira Lemma           Mechanics          4.0
# Christian Combs      Mechanics          4.9
# Kelvin Drumsolo      Mechanics          3.0
# Greer Lott           Moist Talkers      5.0
# Amos Melon           Moist Talkers      4.0
# Avila Guzman         Crabs              4.4

# %% [markdown]
# ### Alternate Trusts
#
# **Call the Negative Alternates (maintaining Star count) for 3 random Players in your Team's Lineup.**
#
# **Call the Negative Alternates (maintaining Star count) for 2 random Players in your Team's Rotation.**
#
# **Call the Negative Alternates (maintaining Star count) for 5 random Players on your Team's Active Roster.**
#
# **Call the Negative Alternates (maintaining Star count) for your entire Team's Shadows.**
#
#
# These blessings turn players into Alternates, rerolling their stats but maintaining their Combined Star total. They will
# also become Negative, making their eDensity negative. The resulting stats are random. See below for combined star totals
# of all Pies.

# %%
display(get_stars(pies.lineup + pies.rotation))
display(get_stars(pies.shadows))
# Out:
#                   Combined  Batting  Pitching  Baserunning  Defense
# Eduardo Woodman       14.3      5.6       1.8          3.7      3.3
# Beasley Day           17.8      5.4       4.1          4.4      3.9
# Huber Frumple         14.9      4.8       2.4          4.4      3.4
# Ruslan Greatness      19.0      4.8       4.1          5.1      5.1
# Jaxon Buckley         19.4      7.1       4.4          4.0      3.8
# Lang Richardson       12.3      3.5       1.0          3.8      3.9
# Peanut Holloway       12.1      4.5       1.5          2.4      3.7
# Doc Anice             15.6      4.4       3.7          3.2      4.3
# Tiana Takahashi       16.6      2.7       5.3          4.0      4.6
# Beans McBlase         17.0      4.4       4.1          2.8      5.7
# Henry Marshallow      15.5      3.8       4.1          2.9      4.8
#                     Combined  Batting  Pitching  Baserunning  Defense
# Adrian Melon             9.1      2.4       0.9          3.1      2.7
# August Obrien            9.8      3.4       1.0          3.3      2.0
# Mcfarland Vargas         8.7      1.4       1.5          3.8      2.1
# Twofurious Puddles      11.5      2.6       3.5          1.8      3.6
# Mummy Cantburn           9.0      1.4       2.3          2.0      3.3
# Doginic Burgertoes       7.2      2.1       1.8          1.8      1.5
# Nerd Pacheco             1.7      0.3       0.3          0.6      0.5
# Yusef Puddles           11.6      2.4       2.5          2.9      3.7
# Sheev Shriffle           8.4      3.4       1.9          2.2      0.9
# Adeline Hammer           7.8      1.1       0.9          2.5      3.3
# Castillo Logan          10.4      1.9       3.0          2.5      3.0
# Bambi Perez              7.2      1.7       0.3          2.3      2.9
# Jesús Rodriguez          6.7      1.6       1.3          2.3      1.4
# Jefferson Delacruz      11.0      3.0       0.6          3.5      3.9
# Case Lancaster           8.9      0.2       3.3          2.2      3.2
# Haruta Byrd             10.5      3.6       2.7          2.4      1.7
# Javier Lotus            11.4      3.4       0.8          3.3      3.9
# Usurper Violet          12.6      3.0       3.4          2.1      4.0
# Lucy Tokkan             10.5      2.3       3.9          1.3      3.0
# Stan Schenn              7.3      1.8       0.9          2.0      2.5

# %% [markdown]
# ### Complete 180
#
# **Flip the eDensity of the most eDense Player in your Team's Rotation.**
#
# See below for analysis.

# %%
tmp_pies = pies.rotation.copy()
tmp_pies.sort(key=lambda x: x.e_density, reverse=True)
print(f"Flip the eDensity of {tmp_pies[0].name}, from {tmp_pies[0].e_density} to {-tmp_pies[0].e_density}.")
print(f"Team eDensity change from {pies.e_density} to {pies.e_density - 2*tmp_pies[0].e_density}")
# Out:
# Flip the eDensity of Beans McBlase, from 57.8524172595741 to -57.8524172595741.
# Team eDensity change from 1383.5010507342554 to 1267.7962162151073

# %% [markdown]
# ### Heads over Tails
#
# **Flip the eDensity of the most eDense Player in your Team's Lineup.**
#
# See below for analysis.

# %%
tmp_pies = pies.lineup.copy()
tmp_pies.sort(key=lambda x: x.e_density, reverse=True)
print(f"Flip the eDensity of {tmp_pies[0].name}, from {tmp_pies[0].e_density} to {-tmp_pies[0].e_density}.")
print(f"Team eDensity change from {pies.e_density} to {pies.e_density - 2*tmp_pies[0].e_density}")
# Out:
# Flip the eDensity of Jaxon Buckley, from 47.686846067178365 to -47.686846067178365.
# Team eDensity change from 1383.5010507342554 to 1288.1273585998986

# %% [markdown]
# ### Darkside Flip
#
# **Flip the eDensity of your Team's entire Shadows.**
#
# See below for analysis.

# %%
x = pandas.DataFrame()
sum = 0
for p in pies.shadows:
    x = x.append(pandas.Series({"Current eDensity": p.e_density}, name=p.name))
    sum += p.e_density
print(f"Team eDensity change from {pies.e_density} to {pies.e_density - 2*sum}")
display(x)
# Out:
# Team eDensity change from 1383.5010507342554 to 376.62528947019143
#                     Current eDensity
# Adrian Melon               30.703189
# August Obrien              27.730988
# Mcfarland Vargas           22.236020
# Twofurious Puddles         24.154495
# Mummy Cantburn             16.639602
# Doginic Burgertoes         28.088006
# Nerd Pacheco               10.323060
# Yusef Puddles              32.170040
# Sheev Shriffle             29.737970
# Adeline Hammer             22.885246
# Castillo Logan             30.524623
# Bambi Perez                14.032362
# Jesús Rodriguez            19.310689
# Jefferson Delacruz         19.421745
# Case Lancaster             24.415214
# Haruta Byrd                32.655247
# Javier Lotus               33.901888
# Usurper Violet             25.593612
# Lucy Tokkan                30.752740
# Stan Schenn                28.161144

# %% [markdown]
# ### Immovable Object
#
# **Flip the eDensity of the most eDense Player on your Team's entire Roster.**
#
# See below for analysis.

# %%
tmp_pies = pies.lineup + pies.rotation
tmp_pies.sort(key=lambda x: x.e_density, reverse=True)
print(f"Flip the eDensity of {tmp_pies[0].name}, from {tmp_pies[0].e_density} to {-tmp_pies[0].e_density}.")
print(f"Team eDensity change from {pies.e_density} to {pies.e_density - 2*tmp_pies[0].e_density}")
# Out:
# Flip the eDensity of Beans McBlase, from 57.8524172595741 to -57.8524172595741.
# Team eDensity change from 1383.5010507342554 to 1267.7962162151073

# %% [markdown]
# ---
# ## Appendix
# * [Description of Attributes](https://www.blaseball.wiki/w/Player_Attributes)
# * [Stlat Viewer](https://blaseballplayers.netlify.app/team/PHIL)
# * [Historical Player Graphs](http://yoori.space/hloroscopes/)
